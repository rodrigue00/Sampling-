# %%
import numpy as np
import pandas as pd
import json
import optuna
import pickle
import os
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier
from sklearn.mixture import GaussianMixture

# %%
# Charger la configuration depuis config.json
with open("config.json", "r") as config_file:
    config = json.load(config_file)

file_path = config["file_path"]
model_save_path = config["model_save_path"]

# %%
# Charger le dataset CSV avec gestion des erreurs
df = pd.read_csv(file_path)
print(" Données chargées avec succès.")
# Out:
#  Données chargées avec succès.

# %%
# Supprimer des lignes avec la classe Virginica
df = df[df['species'].isin(['setosa', 'versicolor'])]
df['species'].replace({'versicolor': 0}, inplace=True)
df['species'].replace({'setosa': 1}, inplace=True)

# %%
# Définition de la colonne cible
target_column = config["target_column"]
if target_column not in df.columns:
    raise ValueError(f" La colonne cible '{target_column}' est absente des données.")

print(f" Colonne cible définie : {target_column}")
# Out:
#  Colonne cible définie : species

# %%
# Utilisation des paramètres définis dans config.json
def gmm_sampling(df, target_column, config):
    n_components_range = config['gmm']['n_components_range']
    covariance_types = config['gmm']['covariance_types']
    reduction_rate = config['sampling']['fraction']
   

    # Séparation des features et de la cible
    X = df.drop(columns=[target_column])
    y = df[target_column]

    # Calcul du nombre total de points à générer
    total_samples = int(len(X) * reduction_rate)

    # Fonction pour optimiser le GMM et générer des échantillons
    def generate_samples(category):
        X_cat = X[y == category]
        best_bic, best_gmm = np.inf, None
        for n in n_components_range:
            for cov_type in covariance_types:
                gmm = GaussianMixture(n_components=n, covariance_type=cov_type)
                gmm.fit(X_cat)
                bic = gmm.bic(X_cat)
                if bic < best_bic:
                    best_bic, best_gmm = bic, gmm
        n_samples = total_samples // len(np.unique(y))
        X_generated, _ = best_gmm.sample(n_samples)
        return np.round(X_generated, 1), np.full(n_samples, category)

    # Génération des échantillons pour chaque catégorie
    X_new, y_new = [], []
    for category in np.unique(y):
        X_cat, y_cat = generate_samples(category)
        X_new.append(X_cat)
        y_new.append(y_cat)

    # Concaténation des échantillons générés
    X_new = np.vstack(X_new)
    y_new = np.hstack(y_new)

    # Création du DataFrame final
    column_names = list(X.columns) + [target_column]
    df_new = pd.DataFrame(X_new, columns=column_names[:-1])
    df_new[target_column] = y_new

    return df_new

# %%
# Initialisation du DataFrame pour stocker les résultats
columns = [
    "Itération", "Échantillonnage", "Modèle", "Paramètres Initiaux",
    "Accuracy Avant", "F1-score Avant", "Paramètres Optimisés",
    "Accuracy Après", "F1-score Après"
]
results_df = pd.DataFrame(columns=columns)

# %%
def afficher_donnees(df_sampled, target_column, sampling_type, iteration):
    print(f"\n📊 Données générées ({sampling_type}) - Itération {iteration} :")
    print(f" - Nombre total d'échantillons : {df_sampled.shape[0]}")
    print(f" - Nombre de features : {df_sampled.shape[1] - 1}")
    print(f" - Répartition des catégories :")
    print(df_sampled[target_column].value_counts())

    print("\n📝 Aperçu des 5 premières lignes :")
    print(df_sampled.head(5))

    print("\n📑 Affichage complet des données générées :")
    print(df_sampled.to_string(index=False))
    print("\n" + "-"*80 + "\n")

# %%
# Exécuter 30 itérations
for iteration in tqdm(range(1, 3), desc=" Itérations en cours"):
    print(f"\n Exécution de l'itération {iteration}...\n")

    # Appliquer le sampling si activé
    if config["sampling"]["enabled"]:
        sampling_type = config["sampling"].get("sampling_type", "random")

        # Si le sampling type est GMM, appliquer le sampling GMM
        if sampling_type == "gmm":
            df_sampled = gmm_sampling(df, target_column, config)
            sampling_status = "Oui (GMM)"
            print(f" Échantillonnage GMM activé.")
        
        # Si le sampling type est Random, utiliser Pandas sample()
        elif sampling_type == "random":
            fraction = config["sampling"]["fraction"]
            df_sampled = df.sample(frac=fraction)
            sampling_status = "Oui (Random)"
            print(f" Échantillonnage aléatoire activé : {fraction*100:.1f}% des données utilisées.")
        
        # Si le type est inconnu, lever une erreur
        else:
            raise ValueError(f" Type d'échantillonnage inconnu : '{sampling_type}'")

        #  Appel de la fonction d'affichage des données générées 
        afficher_donnees(df_sampled, target_column, sampling_type, iteration)


    else:
        # Si le sampling est désactivé, utiliser le dataset original
        df_sampled = df
        sampling_status = "Non"
        print(" Aucun échantillonnage appliqué, utilisation des données complètes.")

    # Séparation des données en train/test
    test_size = config["train_test_split"]["test_size"]
    X = df_sampled.drop(columns=[target_column])
    y = df_sampled[target_column]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

    # Remplacer X_test et y_test par les données d'origine
    X_test = df.drop(columns=[target_column])
    y_test = df[target_column]

    print(f"\n Données séparées : {100 * (1 - test_size):.0f}% entraînement, {100 * test_size:.0f}% test.")

    # Initialiser les modèles
    models = {}
    for model_name, model_params in config["models"].items():
        if model_params["enabled"]:
            if model_name == "Decision Tree":
                models[model_name] = DecisionTreeClassifier(max_depth=model_params["max_depth"])
            elif model_name == "Random Forest":
                models[model_name] = RandomForestClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"],
                )
            elif model_name == "SVM":
                models[model_name] = SVC(C=model_params["C"], kernel=model_params["kernel"])
            elif model_name == "Neural Network":
                models[model_name] = MLPClassifier(
                    hidden_layer_sizes=tuple(model_params["hidden_layer_sizes"]),
                    learning_rate_init=model_params["learning_rate_init"],
                    max_iter=500,
                    
                )
            elif model_name == "XGBoost":
                models[model_name] = XGBClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"],
                    learning_rate=model_params["learning_rate"], 
                )

    # Entraînement et évaluation des modèles
    for model_name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        accuracy_before = accuracy_score(y_test, y_pred)
        f1_before = f1_score(y_test, y_pred, average="weighted")
        
        print(f"\n Résultats du modèle '{model_name}' avant optimisation :")
        print(f"   - Accuracy: {accuracy_before:.4f}")
        print(f"   - F1-score: {f1_before:.4f}")


        best_params = {}
        best_model = model
        accuracy_after, f1_after = "Non optimisé", "Non optimisé"

        # Optimisation avec Optuna
        if config["use_optuna"]:
            def objective(trial):
                if model_name == "Decision Tree":
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = DecisionTreeClassifier(max_depth=max_depth )
                elif model_name == "Random Forest":
                    n_estimators = trial.suggest_int("n_estimators", 10, 200)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
                elif model_name == "SVM":
                    C = trial.suggest_loguniform("C", 0.1, 10)
                    kernel = trial.suggest_categorical("kernel", ["linear", "rbf", "poly"])
                    model_opt = SVC(C=C, kernel=kernel)
                elif model_name == "Neural Network":
                    hidden_layer_sizes = trial.suggest_categorical("hidden_layer_sizes", [(50,), (100,), (50, 50)])
                    learning_rate_init = trial.suggest_loguniform("learning_rate_init", 0.0001, 0.1)
                    model_opt = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, learning_rate_init=learning_rate_init, max_iter=500)
                elif model_name == "XGBoost":
                    n_estimators = trial.suggest_int("n_estimators", 50, 500)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
                    model_opt = XGBClassifier(n_estimators=n_estimators, max_depth=max_depth, learning_rate=learning_rate)

                model_opt.fit(X_train, y_train)
            
                y_pred_opt = model_opt.predict(X_test)
                return accuracy_score(y_test, y_pred_opt)

            study = optuna.create_study(direction="maximize")
            study.optimize(objective, n_trials=config["n_trials"])

            best_params = study.best_trial.params
            print(f"\n Meilleurs paramètres trouvés pour '{model_name}' : {best_params}")

            # Réentraînement avec les meilleurs paramètres
            if config["retrain_with_best_params"]:
                best_model = model.__class__(**best_params)
                best_model.fit(X_train, y_train)
                y_pred_opt = best_model.predict(X_test)
                accuracy_after = accuracy_score(y_test, y_pred_opt)
                f1_after = f1_score(y_test, y_pred_opt, average="weighted")
                
            print(f"\n Modèle après optimisation ({model_name}):")
            print(f"   - Accuracy: {accuracy_after}")
            print(f"   - F1-score: {f1_after}")

            # Sauvegarde du meilleur modèle
            if config["save_best_model"]:
                model_filename = f"best_model_{model_name}.pkl"
                with open(model_filename, "wb") as f:
                    pickle.dump(best_model, f)
                print(f" Modèle '{model_name}' sauvegardé sous '{model_filename}'.")

        # Stockage des résultats
        results_df = pd.concat([results_df, pd.DataFrame([{
            "Itération": iteration,
            "Échantillonnage": sampling_status,
            "Modèle": model_name,
            "Paramètres Initiaux": {param: value for param, value in model.get_params().items() if param in model_params},
            "Accuracy Avant": accuracy_before,
            "F1-score Avant": f1_before,
            "Paramètres Optimisés": best_params,
            "Accuracy Après": accuracy_after,
            "F1-score Après": f1_after
        }])], ignore_index=True)

# Sauvegarde des résultats
# Définition du chemin du fichier Excel
excel_path = "resultats_iterations.xlsx"

# Vérifier si le fichier existe
if os.path.exists(excel_path):
    # Ajouter les nouveaux résultats sans charger les anciens
    with pd.ExcelWriter(excel_path, mode='a', if_sheet_exists='overlay') as writer:
        results_df.to_excel(writer, index=False, header=False, startrow=writer.sheets['Sheet1'].max_row)
else:
    # Si le fichier n'existe pas, on crée un nouveau fichier avec les nouveaux résultats
    results_df.to_excel(excel_path, index=False)

print("\n📊 Les nouveaux résultats ont été ajoutés dans 'resultats_iterations.xlsx'.")

# Réinitialisation du DataFrame après la sauvegarde (conserve les colonnes, supprime les lignes)
results_df.drop(results_df.index, inplace=True)
# Out:
#  Itérations en cours:   0%|          | 0/2 [00:00<?, ?it/s][I 2025-02-25 17:03:13,772] A new study created in memory with name: no-name-fb84536a-ab83-401d-aa9e-0f5757a3cba9
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:13,878] Trial 0 finished with value: 0.95 and parameters: {'n_estimators': 294, 'max_depth': 3, 'learning_rate': 0.09041823341970917}. Best is trial 0 with value: 0.95.
#  Exécution de l'itération 1...
#
#  Échantillonnage aléatoire activé : 20.0% des données utilisées.
#
# 📊 Données générées (random) - Itération 1 :
#  - Nombre total d'échantillons : 20
#  - Nombre de features : 4
#  - Répartition des catégories :
# species
# 1    11
# 0     9
# Name: count, dtype: int64
#
# 📝 Aperçu des 5 premières lignes :
#     sepal_length  sepal_width  petal_length  petal_width  species
# 98           5.1          2.5           3.0          1.1        0
# 6            4.6          3.4           1.4          0.3        1
# 77           6.7          3.0           5.0          1.7        0
# 33           5.5          4.2           1.4          0.2        1
# 1            4.9          3.0           1.4          0.2        1
#
# 📑 Affichage complet des données générées :
#  sepal_length  sepal_width  petal_length  petal_width  species
#           5.1          2.5           3.0          1.1        0
#           4.6          3.4           1.4          0.3        1
#           6.7          3.0           5.0          1.7        0
#           5.5          4.2           1.4          0.2        1
#           4.9          3.0           1.4          0.2        1
#           4.6          3.6           1.0          0.2        1
#           4.4          3.0           1.3          0.2        1
#           5.1          3.5           1.4          0.2        1
#           5.7          3.8           1.7          0.3        1
#           5.6          2.9           3.6          1.3        0
#           6.0          2.7           5.1          1.6        0
#           6.2          2.9           4.3          1.3        0
#           5.2          3.4           1.4          0.2        1
#           4.8          3.4           1.9          0.2        1
#           6.2          2.2           4.5          1.5        0
#           6.0          2.9           4.5          1.5        0
#           5.6          3.0           4.1          1.3        0
#           5.1          3.8           1.9          0.4        1
#           4.8          3.0           1.4          0.1        1
#           5.7          3.0           4.2          1.2        0
#
# --------------------------------------------------------------------------------
#
#
#  Données séparées : 80% entraînement, 20% test.
#
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy: 0.9500
#    - F1-score: 0.9499
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:13,960] Trial 1 finished with value: 0.95 and parameters: {'n_estimators': 217, 'max_depth': 19, 'learning_rate': 0.2369757696667695}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:14,052] Trial 2 finished with value: 0.95 and parameters: {'n_estimators': 207, 'max_depth': 4, 'learning_rate': 0.2644486578627495}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:14,226] Trial 3 finished with value: 0.95 and parameters: {'n_estimators': 461, 'max_depth': 8, 'learning_rate': 0.010740127088481191}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:14,328] Trial 4 finished with value: 0.95 and parameters: {'n_estimators': 215, 'max_depth': 15, 'learning_rate': 0.0759264114504675}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:14,406] Trial 5 finished with value: 0.95 and parameters: {'n_estimators': 126, 'max_depth': 8, 'learning_rate': 0.17321768848321492}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:14,556] Trial 6 finished with value: 0.95 and parameters: {'n_estimators': 399, 'max_depth': 2, 'learning_rate': 0.16417439542158035}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:14,715] Trial 7 finished with value: 0.95 and parameters: {'n_estimators': 467, 'max_depth': 14, 'learning_rate': 0.09444461774810704}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:14,757] Trial 8 finished with value: 0.95 and parameters: {'n_estimators': 62, 'max_depth': 18, 'learning_rate': 0.16306954575821944}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:14,908] Trial 9 finished with value: 0.95 and parameters: {'n_estimators': 442, 'max_depth': 8, 'learning_rate': 0.13912629710464158}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:15,079] Trial 10 finished with value: 0.95 and parameters: {'n_estimators': 346, 'max_depth': 5, 'learning_rate': 0.02989377978171568}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:15,225] Trial 11 finished with value: 0.95 and parameters: {'n_estimators': 295, 'max_depth': 20, 'learning_rate': 0.04331148037282072}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:15,358] Trial 12 finished with value: 0.95 and parameters: {'n_estimators': 230, 'max_depth': 13, 'learning_rate': 0.26896561579278655}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:15,524] Trial 13 finished with value: 0.95 and parameters: {'n_estimators': 313, 'max_depth': 11, 'learning_rate': 0.02875734330159309}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:15,632] Trial 14 finished with value: 0.95 and parameters: {'n_estimators': 152, 'max_depth': 17, 'learning_rate': 0.06715417963102148}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:15,787] Trial 15 finished with value: 0.95 and parameters: {'n_estimators': 350, 'max_depth': 11, 'learning_rate': 0.12311109076871374}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:15,918] Trial 16 finished with value: 0.95 and parameters: {'n_estimators': 246, 'max_depth': 20, 'learning_rate': 0.04234135697711642}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:16,026] Trial 17 finished with value: 0.95 and parameters: {'n_estimators': 154, 'max_depth': 2, 'learning_rate': 0.28509667601002986}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:16,381] Trial 18 finished with value: 0.95 and parameters: {'n_estimators': 275, 'max_depth': 5, 'learning_rate': 0.01495390443433026}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:16,580] Trial 19 finished with value: 0.95 and parameters: {'n_estimators': 386, 'max_depth': 17, 'learning_rate': 0.10866001136729168}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:16,672] Trial 20 finished with value: 0.95 and parameters: {'n_estimators': 73, 'max_depth': 10, 'learning_rate': 0.19067426386345032}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:16,793] Trial 21 finished with value: 0.95 and parameters: {'n_estimators': 194, 'max_depth': 5, 'learning_rate': 0.22972261839384572}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:17,105] Trial 22 finished with value: 0.95 and parameters: {'n_estimators': 185, 'max_depth': 4, 'learning_rate': 0.21774251107266454}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:17,274] Trial 23 finished with value: 0.95 and parameters: {'n_estimators': 270, 'max_depth': 3, 'learning_rate': 0.273639894935583}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:17,378] Trial 24 finished with value: 0.95 and parameters: {'n_estimators': 109, 'max_depth': 6, 'learning_rate': 0.08951568092365521}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:17,511] Trial 25 finished with value: 0.95 and parameters: {'n_estimators': 239, 'max_depth': 7, 'learning_rate': 0.05873131415153741}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:17,667] Trial 26 finished with value: 0.95 and parameters: {'n_estimators': 322, 'max_depth': 10, 'learning_rate': 0.13348975756274142}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:17,782] Trial 27 finished with value: 0.95 and parameters: {'n_estimators': 181, 'max_depth': 4, 'learning_rate': 0.2225391905992971}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:17,930] Trial 28 finished with value: 0.95 and parameters: {'n_estimators': 262, 'max_depth': 2, 'learning_rate': 0.02023275655491632}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:18,069] Trial 29 finished with value: 0.95 and parameters: {'n_estimators': 209, 'max_depth': 7, 'learning_rate': 0.010975628852705801}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:18,180] Trial 30 finished with value: 0.95 and parameters: {'n_estimators': 158, 'max_depth': 13, 'learning_rate': 0.04933638259783951}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:18,407] Trial 31 finished with value: 0.95 and parameters: {'n_estimators': 486, 'max_depth': 9, 'learning_rate': 0.02694691892342832}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:18,600] Trial 32 finished with value: 0.95 and parameters: {'n_estimators': 423, 'max_depth': 4, 'learning_rate': 0.08095007257144027}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:18,707] Trial 33 finished with value: 0.95 and parameters: {'n_estimators': 107, 'max_depth': 6, 'learning_rate': 0.010066764527938815}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:18,867] Trial 34 finished with value: 0.95 and parameters: {'n_estimators': 370, 'max_depth': 8, 'learning_rate': 0.17790302449644518}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:19,010] Trial 35 finished with value: 0.95 and parameters: {'n_estimators': 214, 'max_depth': 15, 'learning_rate': 0.016217302902252862}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:19,245] Trial 36 finished with value: 0.95 and parameters: {'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.14269320202511954}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:19,452] Trial 37 finished with value: 0.95 and parameters: {'n_estimators': 427, 'max_depth': 12, 'learning_rate': 0.10591621774353398}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:19,612] Trial 38 finished with value: 0.95 and parameters: {'n_estimators': 301, 'max_depth': 7, 'learning_rate': 0.06943869338287416}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:19,821] Trial 39 finished with value: 0.95 and parameters: {'n_estimators': 459, 'max_depth': 3, 'learning_rate': 0.034915047249265176}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:19,992] Trial 40 finished with value: 0.95 and parameters: {'n_estimators': 338, 'max_depth': 9, 'learning_rate': 0.18561882683032987}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:20,129] Trial 41 finished with value: 0.95 and parameters: {'n_estimators': 222, 'max_depth': 15, 'learning_rate': 0.07830369371623708}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:20,249] Trial 42 finished with value: 0.95 and parameters: {'n_estimators': 138, 'max_depth': 19, 'learning_rate': 0.05896810541453463}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:20,408] Trial 43 finished with value: 0.95 and parameters: {'n_estimators': 248, 'max_depth': 16, 'learning_rate': 0.14433895090072565}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:20,580] Trial 44 finished with value: 0.95 and parameters: {'n_estimators': 283, 'max_depth': 18, 'learning_rate': 0.10852318339663074}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:20,715] Trial 45 finished with value: 0.95 and parameters: {'n_estimators': 173, 'max_depth': 13, 'learning_rate': 0.04752250363295871}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:20,856] Trial 46 finished with value: 0.95 and parameters: {'n_estimators': 198, 'max_depth': 19, 'learning_rate': 0.29821982841637135}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:21,002] Trial 47 finished with value: 0.95 and parameters: {'n_estimators': 232, 'max_depth': 16, 'learning_rate': 0.03691214186509552}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:21,155] Trial 48 finished with value: 0.95 and parameters: {'n_estimators': 255, 'max_depth': 20, 'learning_rate': 0.023017606002632477}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:21,261] Trial 49 finished with value: 0.95 and parameters: {'n_estimators': 126, 'max_depth': 14, 'learning_rate': 0.15515784398052918}. Best is trial 0 with value: 0.95.
#  Itérations en cours:  50%|█████     | 1/2 [00:07<00:07,  7.68s/it]
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 294, 'max_depth': 3, 'learning_rate': 0.09041823341970917}
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy: 0.95
#    - F1-score: 0.949874686716792
#  Modèle 'XGBoost' sauvegardé sous 'best_model_XGBoost.pkl'.
#
#  Exécution de l'itération 2...
#
#  Échantillonnage aléatoire activé : 20.0% des données utilisées.
#
# 📊 Données générées (random) - Itération 2 :
#  - Nombre total d'échantillons : 20
#  - Nombre de features : 4
#  - Répartition des catégories :
# species
# 1    11
# 0     9
# Name: count, dtype: int64
#
# 📝 Aperçu des 5 premières lignes :
#     sepal_length  sepal_width  petal_length  petal_width  species
# 81           5.5          2.4           3.7          1.0        0
# 59           5.2          2.7           3.9          1.4        0
# 28           5.2          3.4           1.4          0.2        1
# 16           5.4          3.9           1.3          0.4        1
# 95           5.7          3.0           4.2          1.2        0
#
# 📑 Affichage complet des données générées :
#  sepal_length  sepal_width  petal_length  petal_width  species
#           5.5          2.4           3.7          1.0        0
#           5.2          2.7           3.9          1.4        0
#           5.2          3.4           1.4          0.2        1
#           5.4          3.9           1.3          0.4        1
#           5.7          3.0           4.2          1.2        0
#           5.4          3.4           1.5          0.4        1
#           5.1          3.8           1.6          0.2        1
#           4.4          3.0           1.3          0.2        1
#           5.1          2.5           3.0          1.1        0
#           5.1          3.8           1.5          0.3        1
#           5.0          3.0           1.6          0.2        1
#           4.8          3.0           1.4          0.3        1
#           6.6          2.9           4.6          1.3        0
#           7.0          3.2           4.7          1.4        0
#           6.7          3.0           5.0          1.7        0
#           6.1          2.8           4.0          1.3        0
#           4.4          3.2           1.3          0.2        1
#           5.7          2.9           4.2          1.3        0
#           5.1          3.8           1.9          0.4        1
#           4.8          3.0           1.4          0.1        1
#
# --------------------------------------------------------------------------------
#
#
#  Données séparées : 80% entraînement, 20% test.
# [I 2025-02-25 17:03:21,472] A new study created in memory with name: no-name-29d5dd58-802a-43f5-981a-f828565feabd
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:21,610] Trial 0 finished with value: 0.92 and parameters: {'n_estimators': 396, 'max_depth': 8, 'learning_rate': 0.09694695703910032}. Best is trial 0 with value: 0.92.
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy: 0.9200
#    - F1-score: 0.9195
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:21,810] Trial 1 finished with value: 0.92 and parameters: {'n_estimators': 470, 'max_depth': 19, 'learning_rate': 0.05561864885862283}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:21,878] Trial 2 finished with value: 0.92 and parameters: {'n_estimators': 73, 'max_depth': 4, 'learning_rate': 0.2823097293718266}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:22,014] Trial 3 finished with value: 0.92 and parameters: {'n_estimators': 230, 'max_depth': 15, 'learning_rate': 0.11317463843065954}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:22,106] Trial 4 finished with value: 0.92 and parameters: {'n_estimators': 175, 'max_depth': 2, 'learning_rate': 0.07766535747817592}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:22,298] Trial 5 finished with value: 0.92 and parameters: {'n_estimators': 434, 'max_depth': 8, 'learning_rate': 0.035451340619112655}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:22,342] Trial 6 finished with value: 0.92 and parameters: {'n_estimators': 70, 'max_depth': 13, 'learning_rate': 0.14500555834174694}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:22,424] Trial 7 finished with value: 0.92 and parameters: {'n_estimators': 164, 'max_depth': 12, 'learning_rate': 0.01791593923015012}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:22,639] Trial 8 finished with value: 0.92 and parameters: {'n_estimators': 408, 'max_depth': 2, 'learning_rate': 0.09608817164459246}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:22,839] Trial 9 finished with value: 0.92 and parameters: {'n_estimators': 383, 'max_depth': 2, 'learning_rate': 0.09917810128327272}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:23,011] Trial 10 finished with value: 0.92 and parameters: {'n_estimators': 328, 'max_depth': 7, 'learning_rate': 0.011662813085450962}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:23,262] Trial 11 finished with value: 0.92 and parameters: {'n_estimators': 489, 'max_depth': 19, 'learning_rate': 0.03878922651321297}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:23,511] Trial 12 finished with value: 0.92 and parameters: {'n_estimators': 500, 'max_depth': 17, 'learning_rate': 0.04823357837799757}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:23,746] Trial 13 finished with value: 0.92 and parameters: {'n_estimators': 326, 'max_depth': 10, 'learning_rate': 0.2067252909497247}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:23,909] Trial 14 finished with value: 0.92 and parameters: {'n_estimators': 357, 'max_depth': 19, 'learning_rate': 0.02523070701830521}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:24,145] Trial 15 finished with value: 0.92 and parameters: {'n_estimators': 444, 'max_depth': 7, 'learning_rate': 0.06376555908288906}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:24,284] Trial 16 finished with value: 0.92 and parameters: {'n_estimators': 280, 'max_depth': 14, 'learning_rate': 0.17820998980228986}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:24,501] Trial 17 finished with value: 0.92 and parameters: {'n_estimators': 451, 'max_depth': 10, 'learning_rate': 0.0526176223052628}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:24,727] Trial 18 finished with value: 0.92 and parameters: {'n_estimators': 274, 'max_depth': 16, 'learning_rate': 0.02485081251118259}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:24,917] Trial 19 finished with value: 0.92 and parameters: {'n_estimators': 395, 'max_depth': 5, 'learning_rate': 0.07237794285598813}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:25,153] Trial 20 finished with value: 0.92 and parameters: {'n_estimators': 466, 'max_depth': 20, 'learning_rate': 0.1305536007257409}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:25,269] Trial 21 finished with value: 0.92 and parameters: {'n_estimators': 55, 'max_depth': 5, 'learning_rate': 0.24609041728703754}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:25,582] Trial 22 finished with value: 0.92 and parameters: {'n_estimators': 112, 'max_depth': 4, 'learning_rate': 0.17203902571205404}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:26,017] Trial 23 finished with value: 0.92 and parameters: {'n_estimators': 202, 'max_depth': 9, 'learning_rate': 0.28303404195488774}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:26,268] Trial 24 finished with value: 0.92 and parameters: {'n_estimators': 118, 'max_depth': 6, 'learning_rate': 0.08341355914808109}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:26,557] Trial 25 finished with value: 0.92 and parameters: {'n_estimators': 272, 'max_depth': 11, 'learning_rate': 0.03955812123587061}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:26,963] Trial 26 finished with value: 0.92 and parameters: {'n_estimators': 329, 'max_depth': 4, 'learning_rate': 0.025433725537718183}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:27,151] Trial 27 finished with value: 0.92 and parameters: {'n_estimators': 419, 'max_depth': 8, 'learning_rate': 0.059203849883680645}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:27,309] Trial 28 finished with value: 0.92 and parameters: {'n_estimators': 356, 'max_depth': 4, 'learning_rate': 0.21633417735725755}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:27,444] Trial 29 finished with value: 0.92 and parameters: {'n_estimators': 239, 'max_depth': 15, 'learning_rate': 0.12444285851343154}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:27,638] Trial 30 finished with value: 0.92 and parameters: {'n_estimators': 469, 'max_depth': 17, 'learning_rate': 0.1543528240332389}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:27,750] Trial 31 finished with value: 0.92 and parameters: {'n_estimators': 177, 'max_depth': 18, 'learning_rate': 0.10256520244524732}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:27,874] Trial 32 finished with value: 0.92 and parameters: {'n_estimators': 226, 'max_depth': 14, 'learning_rate': 0.07742923377696047}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:27,977] Trial 33 finished with value: 0.92 and parameters: {'n_estimators': 133, 'max_depth': 12, 'learning_rate': 0.11568693786178418}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:28,092] Trial 34 finished with value: 0.92 and parameters: {'n_estimators': 150, 'max_depth': 16, 'learning_rate': 0.047026019349980866}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:28,185] Trial 35 finished with value: 0.92 and parameters: {'n_estimators': 95, 'max_depth': 13, 'learning_rate': 0.2872633392007125}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:28,353] Trial 36 finished with value: 0.92 and parameters: {'n_estimators': 376, 'max_depth': 3, 'learning_rate': 0.032617624615722415}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:28,533] Trial 37 finished with value: 0.92 and parameters: {'n_estimators': 423, 'max_depth': 20, 'learning_rate': 0.08776100144366397}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:28,630] Trial 38 finished with value: 0.92 and parameters: {'n_estimators': 85, 'max_depth': 8, 'learning_rate': 0.06399239138677006}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:28,788] Trial 39 finished with value: 0.92 and parameters: {'n_estimators': 307, 'max_depth': 12, 'learning_rate': 0.10345088591243211}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:28,925] Trial 40 finished with value: 0.92 and parameters: {'n_estimators': 248, 'max_depth': 2, 'learning_rate': 0.1583644115584818}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:29,047] Trial 41 finished with value: 0.92 and parameters: {'n_estimators': 194, 'max_depth': 2, 'learning_rate': 0.07194842864974658}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:29,182] Trial 42 finished with value: 0.92 and parameters: {'n_estimators': 217, 'max_depth': 3, 'learning_rate': 0.043525048746794574}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:29,312] Trial 43 finished with value: 0.92 and parameters: {'n_estimators': 160, 'max_depth': 7, 'learning_rate': 0.012385675063986721}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:29,395] Trial 44 finished with value: 0.92 and parameters: {'n_estimators': 50, 'max_depth': 6, 'learning_rate': 0.09105861667127804}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:29,517] Trial 45 finished with value: 0.92 and parameters: {'n_estimators': 181, 'max_depth': 3, 'learning_rate': 0.055418796890094525}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:29,670] Trial 46 finished with value: 0.92 and parameters: {'n_estimators': 303, 'max_depth': 18, 'learning_rate': 0.13616347351135163}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:29,881] Trial 47 finished with value: 0.92 and parameters: {'n_estimators': 484, 'max_depth': 10, 'learning_rate': 0.19794384302700493}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:30,078] Trial 48 finished with value: 0.92 and parameters: {'n_estimators': 443, 'max_depth': 5, 'learning_rate': 0.11555396068345798}. Best is trial 0 with value: 0.92.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27068\1699450276.py:112: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-02-25 17:03:30,237] Trial 49 finished with value: 0.92 and parameters: {'n_estimators': 252, 'max_depth': 14, 'learning_rate': 0.03282995886368805}. Best is trial 0 with value: 0.92.
#  Itérations en cours: 100%|██████████| 2/2 [00:16<00:00,  8.35s/it]
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 396, 'max_depth': 8, 'learning_rate': 0.09694695703910032}
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy: 0.92
#    - F1-score: 0.9194847020933977
#  Modèle 'XGBoost' sauvegardé sous 'best_model_XGBoost.pkl'.
#
# 📊 Les nouveaux résultats ont été ajoutés dans 'resultats_iterations.xlsx'.

# %%
import numpy as np
import pandas as pd
import json
import optuna
import pickle
import os
import time
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier


# Import sécurisé de gmm_sampling
try:
    from sampling.gmm_sampling import gmm_sampling
    print(" gmm_sampling importé avec succès.")
except ModuleNotFoundError:
    raise ImportError(" Impossible d'importer gmm_sampling. Vérifiez le chemin du fichier.")

# Charger la configuration depuis config.json
with open("config.json", "r") as config_file:
    config = json.load(config_file)

file_path = config["file_path"]
model_save_path = config["model_save_path"]
num_iterations = config.get("num_iterations", 30)  #  Nombre d'itérations

# Charger le dataset CSV avec gestion des erreurs
df = pd.read_csv(file_path)
print(" Données chargées avec succès.")

# Définition de la colonne cible
target_column = config["target_column"]
if target_column not in df.columns:
    raise ValueError(f" La colonne cible '{target_column}' est absente des données.")

print(f" Colonne cible définie : {target_column}")


# Initialisation du DataFrame pour stocker les résultats
columns = [
    "Itération", "Échantillonnage","Temps Sampling (s)","Pourcentage Entraînement", "Nombre Entraînement", "Pourcentage Test",
     "Nombre Test", "Modèle", "Paramètres Initiaux",  "Temps Entraînement Avant (s)", "Accuracy Avant", "F1-score Avant", "Temps Entraînement Après (s)",
    "Paramètres Optimisés", "Accuracy Après", "F1-score Après"
]
results_df = pd.DataFrame(columns=columns)


# Exécuter 30 itérations
for iteration in tqdm(range(1, num_iterations  + 1), desc=" Itérations en cours"):
    print(f"\n Exécution de l'itération {iteration}...\n")

    start_sampling_time = time.time()  # Début du chronométrage du sampling

    # Appliquer le sampling si activé
    if config["sampling"]["enabled"]:
        # Si le sampling type est GMM, appliquer le sampling GMM
        if config["sampling"]["gmm"]["enabled"]:
            df_sampled = gmm_sampling(df, target_column, config)
            sampling_status = "Oui (GMM)"
            print(f" Échantillonnage GMM activé.")
        
        # Si le sampling type est Random, utiliser Pandas sample()
        elif config["sampling"]["random"]["enabled"]:
            fraction = config["sampling"]["fraction"]
            df_sampled = df.sample(frac=fraction)
            sampling_status = "Oui (Random)"
            print(f" Échantillonnage aléatoire activé : {fraction*100:.1f}% des données utilisées.")
        
        # Si le type est inconnu, lever une erreur
        else:
            raise ValueError(f" Type d'échantillonnage inconnu : '{sampling_type}'")

    else:
        # Si le sampling est désactivé, utiliser le dataset original
        df_sampled = df
        sampling_status = "Non"
        print(" Aucun échantillonnage appliqué, utilisation des données complètes.")
        
    sampling_time = round(time.time() - start_sampling_time , 2) # Calcul du temps pris par le sampling



    # Séparation des données en train/test sur l'échantillon
    test_size = config["train_test_split"]["test_size"]
    X = df_sampled.drop(columns=[target_column])
    y = df_sampled[target_column]
    X_train, X_test_sampled, y_train, y_test_sampled = train_test_split(X, y, test_size=test_size)
    
    # Sélectionner 20% des données d'origine pour tester
    #df_test_original = df.sample(frac=test_size, random_state=42)
    #X_test = df_test_original.drop(columns=[target_column])
    #y_test = df_test_original[target_column]

     # Sélectionner 20% des données d'origine en fonction des données échantillonnées
    original_test_fraction = test_size * len(df_sampled) / len(df)
    df_test_original = df.sample(frac=original_test_fraction, random_state=42)
    X_test = df_test_original.drop(columns=[target_column])
    y_test = df_test_original[target_column] 


    print(f"\n Pourcentage Entraînement : {100 * (1 - test_size):.0f}% ({len(X_train)} données)")
    print(f" Pourcentage Test (données échantillonnées) : {test_size * 100:.0f}% ({len(X_test_sampled)} données)")
    print(f" Pourcentage Test (données d'origine) : {test_size * 100:.0f}% ({len(X_test)} données)")    

    
    train_percent = (len(X_train) / len(df_sampled)) * 100
    test_percent = (len(X_test) / len(df_sampled)) * 100

    print(f"\n Pourcentage Entraînement : {train_percent:.2f}%")
    print(f" Pourcentage Test  : {test_percent:.2f}%")

    # Initialiser les modèles
    models = {}
    for model_name, model_params in config["models"].items():
        if model_params["enabled"]:
            if model_name == "Decision Tree":
                models[model_name] = DecisionTreeClassifier(max_depth=model_params["max_depth"])
            elif model_name == "Random Forest":
                models[model_name] = RandomForestClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"]
                )
            elif model_name == "SVM":
                models[model_name] = SVC(C=model_params["C"], kernel=model_params["kernel"])
            elif model_name == "Neural Network":
                models[model_name] = MLPClassifier(
                    hidden_layer_sizes=tuple(model_params["hidden_layer_sizes"]),
                    learning_rate_init=model_params["learning_rate_init"],
                    max_iter=500
                )
            elif model_name == "XGBoost":
                models[model_name] = XGBClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"],
                    learning_rate=model_params["learning_rate"]    
                )

    # Entraînement et évaluation des modèles
    for model_name, model in models.items():
        start_train_time = time.time()  # Début du chronométrage de l'entraînement avant optimisation
        model.fit(X_train, y_train)
        train_time_before = round(time.time() - start_train_time , 2)  # Temps pris pour l'entraînement avant optimisation
        y_pred = model.predict(X_test)
        accuracy_before = accuracy_score(y_test, y_pred)
        f1_before = f1_score(y_test, y_pred, average="weighted")
        
        print(f"\n Résultats du modèle '{model_name}' avant optimisation :")
        print(f"   - Accuracy: {accuracy_before:.4f}")
        print(f"   - F1-score: {f1_before:.4f}")


        best_params = {}
        best_model = model
        accuracy_after, f1_after = "Non optimisé", "Non optimisé"

        # Optimisation avec Optuna
        if config["use_optuna"]:
            def objective(trial):
                if model_name == "Decision Tree":
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = DecisionTreeClassifier(max_depth=max_depth)
                elif model_name == "Random Forest":
                    n_estimators = trial.suggest_int("n_estimators", 10, 200)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
                elif model_name == "SVM":
                    C = trial.suggest_loguniform("C", 0.1, 10)
                    kernel = trial.suggest_categorical("kernel", ["linear", "rbf", "poly"])
                    model_opt = SVC(C=C, kernel=kernel)
                elif model_name == "Neural Network":
                    hidden_layer_sizes = trial.suggest_categorical("hidden_layer_sizes", [(50,), (100,), (50, 50)])
                    learning_rate_init = trial.suggest_loguniform("learning_rate_init", 0.0001, 0.1)
                    model_opt = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, learning_rate_init=learning_rate_init, max_iter=500)
                elif model_name == "XGBoost":
                    n_estimators = trial.suggest_int("n_estimators", 50, 500)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
                    model_opt = XGBClassifier(n_estimators=n_estimators, max_depth=max_depth, learning_rate=learning_rate)

                model_opt.fit(X_train, y_train)
                y_pred_opt = model_opt.predict(X_test)
                return accuracy_score(y_test, y_pred_opt)

            study = optuna.create_study(direction="maximize")
            study.optimize(objective, n_trials=config["n_trials"])

            best_params = study.best_trial.params
            print(f"\n Meilleurs paramètres trouvés pour '{model_name}' : {best_params}")

            # Réentraînement avec les meilleurs paramètres
            if config["retrain_with_best_params"]:
                start_train_time_after = time.time()  # Début du chronométrage de l'entraînement après optimisation
                best_model = model.__class__(**best_params)
                best_model.fit(X_train, y_train)
                train_time_after = round(time.time() - start_train_time_after, 2) # Temps pris pour l'entraînement après optimisation
                y_pred_opt = best_model.predict(X_test)
                accuracy_after = accuracy_score(y_test, y_pred_opt)
                f1_after = f1_score(y_test, y_pred_opt, average="weighted")
                
            print(f"\n Modèle après optimisation ({model_name}):")
            print(f"   - Accuracy: {accuracy_after}")
            print(f"   - F1-score: {f1_after}")

            # Sauvegarde du meilleur modèle
            if config["save_best_model"]:
                model_filename = f"best_model_{model_name}.pkl"
                with open(model_filename, "wb") as f:
                    pickle.dump(best_model, f)
                print(f" Modèle '{model_name}' sauvegardé sous '{model_filename}'.")

        # Stockage des résultats
        results_df = pd.concat([results_df, pd.DataFrame([{
            "Itération": iteration,
            "Échantillonnage": sampling_status,
            "Tps Sampling": sampling_time,
            "Entrain %": train_percent,
            "Nbre Entrain": num_train,
            "Test %": test_percent,
            "Nbre Test": num_test,
            "Modèle": model_name,
            "Paramètres Initiaux": {param: value for param, value in model.get_params().items() if param in model_params},
            "Tps Entrain Avant": train_time_before,
            "Accuracy Avant": accuracy_before,
            "F1-score Avant": f1_before,
            "Tps Entrain Après": train_time_after,
            "Paramètres Optimisés": best_params,
            "Accuracy Après": accuracy_after,
            "F1-score Après": f1_after
        }])], ignore_index=True)

# Sauvegarde des résultats
# Définition du chemin du fichier Excel
excel_path = f"resultats_{model_name}_{sampling_status}_{os.path.basename(file_path).split('.')[0]}.xlsx"

# Vérifier si le fichier existe
if os.path.exists(excel_path):
    # Ajouter les nouveaux résultats sans charger les anciens
    with pd.ExcelWriter(excel_path, mode='a', if_sheet_exists='overlay') as writer:
        results_df.to_excel(writer, index=False, header=False, startrow=writer.sheets['Sheet1'].max_row)
else:
    # Si le fichier n'existe pas, on crée un nouveau fichier avec les nouveaux résultats
    results_df.to_excel(excel_path, index=False)

print("\n Les nouveaux résultats sont disponible")

# Réinitialisation du DataFrame après la sauvegarde (conserve les colonnes, supprime les lignes)
results_df.drop(results_df.index, inplace=True)
# Out:
#  gmm_sampling importé avec succès.
#  Données chargées avec succès.
#  Colonne cible définie : species
#  Itérations en cours:   0%|          | 0/2 [00:00<?, ?it/s]
#  Exécution de l'itération 1...
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# [I 2025-03-10 16:41:48,285] A new study created in memory with name: no-name-379e94ce-4638-473f-a95b-aa763b7877d0
#  Échantillonnage GMM activé.
#
#  Pourcentage Entraînement : 80% (16 données)
#  Pourcentage Test (données échantillonnées) : 20% (4 données)
#  Pourcentage Test (données d'origine) : 20% (4 données)
#
#  Pourcentage Entraînement : 80.00%
#  Pourcentage Test (données échantillonnées) : 20.00%
#
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy: 1.0000
#    - F1-score: 1.0000
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:48,459] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 386, 'max_depth': 5, 'learning_rate': 0.10544821082166667}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:48,527] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 143, 'max_depth': 8, 'learning_rate': 0.19124782242461094}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:48,633] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 110, 'max_depth': 2, 'learning_rate': 0.015139480600632724}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:48,866] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 244, 'max_depth': 6, 'learning_rate': 0.011658892780488815}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:48,976] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 425, 'max_depth': 9, 'learning_rate': 0.014549424469085623}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:49,020] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 52, 'max_depth': 11, 'learning_rate': 0.08245438049759023}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:49,164] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 365, 'max_depth': 7, 'learning_rate': 0.030427117290646098}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:49,209] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 66, 'max_depth': 5, 'learning_rate': 0.22911379533792253}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:49,309] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 262, 'max_depth': 20, 'learning_rate': 0.09939438344969544}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:49,379] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 174, 'max_depth': 14, 'learning_rate': 0.05214892700824582}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:49,614] Trial 10 finished with value: 1.0 and parameters: {'n_estimators': 480, 'max_depth': 2, 'learning_rate': 0.11464990333824406}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:49,916] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 346, 'max_depth': 14, 'learning_rate': 0.29577246211023683}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:50,044] Trial 12 finished with value: 1.0 and parameters: {'n_estimators': 174, 'max_depth': 9, 'learning_rate': 0.15868070022523925}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:50,250] Trial 13 finished with value: 1.0 and parameters: {'n_estimators': 340, 'max_depth': 4, 'learning_rate': 0.049759560751706934}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:50,378] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 196, 'max_depth': 13, 'learning_rate': 0.16184018792511665}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:50,574] Trial 15 finished with value: 1.0 and parameters: {'n_estimators': 416, 'max_depth': 9, 'learning_rate': 0.16844492224355898}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:50,733] Trial 16 finished with value: 1.0 and parameters: {'n_estimators': 303, 'max_depth': 17, 'learning_rate': 0.07402928342450997}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:50,845] Trial 17 finished with value: 1.0 and parameters: {'n_estimators': 118, 'max_depth': 7, 'learning_rate': 0.03385475695772449}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:51,039] Trial 18 finished with value: 1.0 and parameters: {'n_estimators': 466, 'max_depth': 4, 'learning_rate': 0.1288578715286999}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:51,163] Trial 19 finished with value: 1.0 and parameters: {'n_estimators': 224, 'max_depth': 12, 'learning_rate': 0.256643072009081}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:51,312] Trial 20 finished with value: 1.0 and parameters: {'n_estimators': 302, 'max_depth': 8, 'learning_rate': 0.06972489166415709}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:51,423] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 115, 'max_depth': 2, 'learning_rate': 0.02427064565891923}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:51,552] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 118, 'max_depth': 3, 'learning_rate': 0.017397987668629617}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:51,685] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 151, 'max_depth': 6, 'learning_rate': 0.19177154317855713}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:51,794] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 86, 'max_depth': 4, 'learning_rate': 0.037678073702052096}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:51,937] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 210, 'max_depth': 2, 'learning_rate': 0.023030877147385772}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:52,126] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 395, 'max_depth': 5, 'learning_rate': 0.09727050350255795}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:52,245] Trial 27 finished with value: 1.0 and parameters: {'n_estimators': 139, 'max_depth': 11, 'learning_rate': 0.1343868815912406}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:52,426] Trial 28 finished with value: 1.0 and parameters: {'n_estimators': 275, 'max_depth': 6, 'learning_rate': 0.01077567892750933}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:52,524] Trial 29 finished with value: 1.0 and parameters: {'n_estimators': 80, 'max_depth': 7, 'learning_rate': 0.05907021941768996}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:52,717] Trial 30 finished with value: 1.0 and parameters: {'n_estimators': 238, 'max_depth': 3, 'learning_rate': 0.014502765339253636}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:52,864] Trial 31 finished with value: 1.0 and parameters: {'n_estimators': 174, 'max_depth': 10, 'learning_rate': 0.010937486974070676}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:53,113] Trial 32 finished with value: 1.0 and parameters: {'n_estimators': 455, 'max_depth': 5, 'learning_rate': 0.013312197321929422}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:53,347] Trial 33 finished with value: 1.0 and parameters: {'n_estimators': 254, 'max_depth': 8, 'learning_rate': 0.021013532871959166}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:53,534] Trial 34 finished with value: 1.0 and parameters: {'n_estimators': 301, 'max_depth': 6, 'learning_rate': 0.019131323281612232}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:53,799] Trial 35 finished with value: 1.0 and parameters: {'n_estimators': 389, 'max_depth': 8, 'learning_rate': 0.013006545392382482}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:53,893] Trial 36 finished with value: 1.0 and parameters: {'n_estimators': 52, 'max_depth': 3, 'learning_rate': 0.22568796052408838}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:54,079] Trial 37 finished with value: 1.0 and parameters: {'n_estimators': 96, 'max_depth': 10, 'learning_rate': 0.0442650411945845}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:54,206] Trial 38 finished with value: 1.0 and parameters: {'n_estimators': 150, 'max_depth': 5, 'learning_rate': 0.11269768042768452}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:54,343] Trial 39 finished with value: 1.0 and parameters: {'n_estimators': 199, 'max_depth': 7, 'learning_rate': 0.02790128950647555}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:54,546] Trial 40 finished with value: 1.0 and parameters: {'n_estimators': 336, 'max_depth': 4, 'learning_rate': 0.01729444167182481}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:54,835] Trial 41 finished with value: 1.0 and parameters: {'n_estimators': 419, 'max_depth': 9, 'learning_rate': 0.014763310064199026}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:55,150] Trial 42 finished with value: 1.0 and parameters: {'n_estimators': 445, 'max_depth': 10, 'learning_rate': 0.010423078591356532}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:55,427] Trial 43 finished with value: 1.0 and parameters: {'n_estimators': 376, 'max_depth': 6, 'learning_rate': 0.012031450073049316}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:55,685] Trial 44 finished with value: 1.0 and parameters: {'n_estimators': 354, 'max_depth': 12, 'learning_rate': 0.015187638070922346}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:55,946] Trial 45 finished with value: 1.0 and parameters: {'n_estimators': 428, 'max_depth': 15, 'learning_rate': 0.085380307192517}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:56,283] Trial 46 finished with value: 1.0 and parameters: {'n_estimators': 489, 'max_depth': 20, 'learning_rate': 0.290434088378283}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:56,467] Trial 47 finished with value: 1.0 and parameters: {'n_estimators': 317, 'max_depth': 9, 'learning_rate': 0.19343806171882297}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:56,601] Trial 48 finished with value: 1.0 and parameters: {'n_estimators': 167, 'max_depth': 7, 'learning_rate': 0.13501653032050392}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:41:56,779] Trial 49 finished with value: 1.0 and parameters: {'n_estimators': 278, 'max_depth': 4, 'learning_rate': 0.017394799095567598}. Best is trial 0 with value: 1.0.
#  Itérations en cours:  50%|█████     | 1/2 [00:15<00:15, 15.89s/it]
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 386, 'max_depth': 5, 'learning_rate': 0.10544821082166667}
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy: 1.0
#    - F1-score: 1.0
#  Modèle 'XGBoost' sauvegardé sous 'best_model_XGBoost.pkl'.
#
#  Exécution de l'itération 2...
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yando\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:08,286] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 93, 'max_depth': 6, 'learning_rate': 0.08848072232613477}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:08,389] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 108, 'max_depth': 9, 'learning_rate': 0.13872093698275748}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:08,491] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 86, 'max_depth': 14, 'learning_rate': 0.06660244976206244}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:08,625] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 155, 'max_depth': 3, 'learning_rate': 0.12215508256377264}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:08,797] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 224, 'max_depth': 6, 'learning_rate': 0.044570116620428396}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:08,908] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 110, 'max_depth': 8, 'learning_rate': 0.10293000807685566}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:09,027] Trial 27 finished with value: 1.0 and parameters: {'n_estimators': 165, 'max_depth': 10, 'learning_rate': 0.18799643144887057}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:09,120] Trial 28 finished with value: 1.0 and parameters: {'n_estimators': 57, 'max_depth': 7, 'learning_rate': 0.01469429035822775}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:09,321] Trial 29 finished with value: 1.0 and parameters: {'n_estimators': 271, 'max_depth': 7, 'learning_rate': 0.03297601038954738}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:09,471] Trial 30 finished with value: 1.0 and parameters: {'n_estimators': 134, 'max_depth': 11, 'learning_rate': 0.018068249084083856}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:09,808] Trial 31 finished with value: 1.0 and parameters: {'n_estimators': 409, 'max_depth': 6, 'learning_rate': 0.013487771586126142}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:10,152] Trial 32 finished with value: 1.0 and parameters: {'n_estimators': 487, 'max_depth': 8, 'learning_rate': 0.011732887667132322}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:10,362] Trial 33 finished with value: 1.0 and parameters: {'n_estimators': 392, 'max_depth': 4, 'learning_rate': 0.016886384415570152}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:10,754] Trial 34 finished with value: 1.0 and parameters: {'n_estimators': 447, 'max_depth': 10, 'learning_rate': 0.025064676873554258}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:11,055] Trial 35 finished with value: 1.0 and parameters: {'n_estimators': 316, 'max_depth': 7, 'learning_rate': 0.044477065161418736}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:11,226] Trial 36 finished with value: 1.0 and parameters: {'n_estimators': 129, 'max_depth': 9, 'learning_rate': 0.012639274295714598}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:11,654] Trial 37 finished with value: 1.0 and parameters: {'n_estimators': 247, 'max_depth': 5, 'learning_rate': 0.03030417779278775}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:11,844] Trial 38 finished with value: 1.0 and parameters: {'n_estimators': 364, 'max_depth': 16, 'learning_rate': 0.17147179615249858}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:12,255] Trial 39 finished with value: 1.0 and parameters: {'n_estimators': 463, 'max_depth': 11, 'learning_rate': 0.07490833057842199}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:12,443] Trial 40 finished with value: 1.0 and parameters: {'n_estimators': 201, 'max_depth': 14, 'learning_rate': 0.0209631504999402}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:12,617] Trial 41 finished with value: 1.0 and parameters: {'n_estimators': 124, 'max_depth': 12, 'learning_rate': 0.03784742226847256}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:12,790] Trial 42 finished with value: 1.0 and parameters: {'n_estimators': 76, 'max_depth': 8, 'learning_rate': 0.028113786863980212}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:13,070] Trial 43 finished with value: 1.0 and parameters: {'n_estimators': 278, 'max_depth': 13, 'learning_rate': 0.29222250652324583}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:13,269] Trial 44 finished with value: 1.0 and parameters: {'n_estimators': 97, 'max_depth': 10, 'learning_rate': 0.019412984265602236}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:13,558] Trial 45 finished with value: 1.0 and parameters: {'n_estimators': 246, 'max_depth': 20, 'learning_rate': 0.05604356447725519}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:13,740] Trial 46 finished with value: 1.0 and parameters: {'n_estimators': 167, 'max_depth': 16, 'learning_rate': 0.024483316357951423}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:13,907] Trial 47 finished with value: 1.0 and parameters: {'n_estimators': 201, 'max_depth': 9, 'learning_rate': 0.03703488390284513}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:14,066] Trial 48 finished with value: 1.0 and parameters: {'n_estimators': 143, 'max_depth': 5, 'learning_rate': 0.01524322541047969}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_27044\4100538021.py:183: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-10 16:42:14,279] Trial 49 finished with value: 1.0 and parameters: {'n_estimators': 118, 'max_depth': 18, 'learning_rate': 0.01025369213580234}. Best is trial 0 with value: 1.0.
#  Itérations en cours: 100%|██████████| 2/2 [00:33<00:00, 16.69s/it]
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 214, 'max_depth': 16, 'learning_rate': 0.023099889091621386}
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy: 1.0
#    - F1-score: 1.0
#  Modèle 'XGBoost' sauvegardé sous 'best_model_XGBoost.pkl'.
#
# 📊 Les nouveaux résultats ont été ajoutés dans 'resultats_iterations.xlsx'.

# %%
import numpy as np
import pandas as pd
import json
import optuna
import pickle
import os
import time
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier


# Import sécurisé de gmm_sampling
try:
    from sampling.gmm_sampling import gmm_sampling
except ModuleNotFoundError:
    raise ImportError(" Impossible d'importer gmm_sampling. Vérifiez le chemin du fichier.")

# Import sécurisé de ddbs_sampling
try:
    from sampling.ddbs_sampling import diversified_distance_based_sampling
except ModuleNotFoundError:
    raise ImportError("Impossible d'importer ddbs_sampling. Vérifiez le chemin du fichier.")


# Charger la configuration depuis config.json
with open("config.json", "r") as config_file:
    config = json.load(config_file)

file_path = config["file_path"]
model_save_path = config["model_save_path"]
num_iterations = config.get("num_iterations", 2)  #  Nombre d'itérations

# Charger le dataset CSV avec gestion des erreurs
df = pd.read_csv(file_path)
print(" Données chargées avec succès.")

# Définition de la colonne cible
target_column = config["target_column"]
if target_column not in df.columns:
    raise ValueError(f" La colonne cible '{target_column}' est absente des données.")

print(f" Colonne cible définie : {target_column}")

# Initialisation du DataFrame pour stocker les résultats
columns = [
    "Itération", "Échantillonnage","Tps Sampling","Entrain %", "Nbre Entrain", "Test %", "Nbre Test", "Modèle", "Paramètres Initiaux",
    "Tps Entrain Avant", "Accuracy Avant","F1-score Avant", "Tps Entrain Après", "Paramètres Optimisés", "Accuracy Après", "F1-score Après"    
]
results_df = pd.DataFrame(columns=columns)

# Exécuter 30 itérations

for iteration in tqdm(range(1, num_iterations  + 1), desc=" Itérations en cours"):
    print(f"\n Exécution de l'itération {iteration}...\n")

     # Séparation des données en Train/Test avant sampling
    test_size = config["train_test_split"]["test_size"]
    X = df.drop(columns=[target_column])
    y = df[target_column]

    # Division des données
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

    # Récupérer le nombre d'échantillons avant sampling
    num_train = len(X_train)
    num_test = len(X_test) 

    #  Affichage de la répartition des données avant échantillonnage
    print(f"\nSéparation des données AVANT échantillonnage :")
    print(f" - Train: {num_train} échantillons ({(1 - test_size) * 100:.1f}%)")
    print(f" - Test: {num_test} échantillons ({test_size * 100:.1f}%)")

    
    #  Appliquer le sampling UNIQUEMENT sur les données d'entraînement
    start_sampling_time = time.time()
    
    # Appliquer le sampling si activé
    if config["sampling"]["enabled"]:
        # Si le sampling type est GMM, appliquer le sampling GMM
        if config["sampling"]["gmm"]["enabled"]:
            df_train_sampled = gmm_sampling(pd.concat([X_train, y_train], axis=1), target_column, config)
            X_train_sampled = df_train_sampled.drop(columns=[target_column])
            y_train_sampled = df_train_sampled[target_column]
            sampling_status = "Oui (GMM)"
            print("Échantillonnage GMM appliqué")
        
        # Si le sampling type est Random, utiliser Pandas sample()
        elif config["sampling"]["random"]["enabled"]:
            fraction = config["sampling"]["fraction"]
            sampled_indices = X_train.sample(frac=fraction).index
            X_train_sampled, y_train_sampled = X_train.loc[sampled_indices], y_train.loc[sampled_indices]
            sampling_status = "Oui (Random)"
            print(f" Échantillonnage aléatoire activé : {fraction*100:.1f}% des données utilisées.")
        
        # Si le sampling type est ddbs, utiliser Pandas sample()    
        elif config["sampling"]["ddbs"]["enabled"]:
            df_train_sampled = diversified_distance_based_sampling(pd.concat([X_train, y_train], axis=1), target_column, config)
            X_train_sampled = df_train_sampled.drop(columns=[target_column])
            y_train_sampled = df_train_sampled[target_column]
            sampling_status = f"Oui (DDBS - {config['sampling']['ddbs']['distance_metric']}, {config['sampling']['ddbs']['distribution_type']})"
            print("Échantillonnage DDBS appliqué.")
        
        # Si le type est inconnu, lever une erreur
        else:
            raise ValueError(f" Type d'échantillonnage inconnu : '{sampling_type}'")

    else:
        # Si le sampling est désactivé, utiliser le dataset original
        X_train_sampled, y_train_sampled = X_train, y_train
        sampling_status = "Non"
        print(" Aucun échantillonnage appliqué, utilisation des données complètes.")

    # Calcul du temps pris pour le sampling
    sampling_time = round(time.time() - start_sampling_time , 2) # Calcul du temps pris par le sampling
    print(f"\n Temps samping  : {sampling_time}.")
    
    #  Mise à jour du nombre d'échantillons après sampling
    num_train_sampled = len(X_train_sampled)
    num_test_sampled = len(X_test) # Le test set reste inchangé

    print(f"\nDonnées après échantillonnage (Train) : {num_train_sampled} échantillons.")
    print(f"Données de test non modifiées : {num_test_sampled} échantillons.")
    
    # Calcul du pourcentage des données après échantillonnage
    train_percent = (len(X_train_sampled) / len(df)) * 100
    test_percent = (len(X_test) / len(df)) * 100
    
    print(f"\n Pourcentage Entraînement : {train_percent:.2f}%")
    print(f" Pourcentage Test : {test_percent:.2f}%")

    # Initialiser les modèles
    models = {}
    for model_name, model_params in config["models"].items():
        if model_params["enabled"]:
            if model_name == "Decision Tree":
                models[model_name] = DecisionTreeClassifier(max_depth=model_params["max_depth"])
            elif model_name == "Random Forest":
                models[model_name] = RandomForestClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"]
                )
            elif model_name == "SVM":
                models[model_name] = SVC(C=model_params["C"], kernel=model_params["kernel"])
            elif model_name == "Neural Network":
                models[model_name] = MLPClassifier(
                    hidden_layer_sizes=tuple(model_params["hidden_layer_sizes"]),
                    learning_rate_init=model_params["learning_rate_init"],
                    max_iter=500
                )
            elif model_name == "XGBoost":
                models[model_name] = XGBClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"],
                    learning_rate=model_params["learning_rate"]    
                )

    # Entraînement et évaluation des modèles
    for model_name, model in models.items():
        start_train_time = time.time()  # Début du chronométrage de l'entraînement avant optimisation
        model.fit(X_train, y_train)
        train_time_before = round(time.time() - start_train_time , 2)  # Temps pris pour l'entraînement avant optimisation
        y_pred = model.predict(X_test)
        accuracy_before = accuracy_score(y_test, y_pred)
        f1_before = f1_score(y_test, y_pred, average="weighted")
        
        print(f"\n Résultats du modèle '{model_name}' avant optimisation :")
        print(f"   - Accuracy: {accuracy_before:.4f}")
        print(f"   - F1-score: {f1_before:.4f}")

        best_params = {}
        best_model = model
        accuracy_after, f1_after = "Non optimisé", "Non optimisé"

        # Optimisation avec Optuna
        if config["use_optuna"]:
            def objective(trial):
                if model_name == "Decision Tree":
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = DecisionTreeClassifier(max_depth=max_depth)
                elif model_name == "Random Forest":
                    n_estimators = trial.suggest_int("n_estimators", 10, 200)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
                elif model_name == "SVM":
                    C = trial.suggest_loguniform("C", 0.1, 10)
                    kernel = trial.suggest_categorical("kernel", ["linear", "rbf", "poly"])
                    model_opt = SVC(C=C, kernel=kernel)
                elif model_name == "Neural Network":
                    hidden_layer_sizes = trial.suggest_categorical("hidden_layer_sizes", [(50,), (100,), (50, 50)])
                    learning_rate_init = trial.suggest_loguniform("learning_rate_init", 0.0001, 0.1)
                    model_opt = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, learning_rate_init=learning_rate_init, max_iter=500)
                elif model_name == "XGBoost":
                    n_estimators = trial.suggest_int("n_estimators", 50, 500)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
                    model_opt = XGBClassifier(n_estimators=n_estimators, max_depth=max_depth, learning_rate=learning_rate)

                model_opt.fit(X_train, y_train)
                y_pred_opt = model_opt.predict(X_test)
                return accuracy_score(y_test, y_pred_opt)

            study = optuna.create_study(direction="maximize")
            study.optimize(objective, n_trials=config["n_trials"])

            best_params = study.best_trial.params
            print(f"\n Meilleurs paramètres trouvés pour '{model_name}' : {best_params}")

            # Réentraînement avec les meilleurs paramètres
            if config["retrain_with_best_params"]:
                start_train_time_after = time.time()  # Début du chronométrage de l'entraînement après optimisation
                best_model = model.__class__(**best_params)
                best_model.fit(X_train, y_train)
                train_time_after = round(time.time() - start_train_time_after, 2) # Temps pris pour l'entraînement après optimisation
                y_pred_opt = best_model.predict(X_test)
                accuracy_after = accuracy_score(y_test, y_pred_opt)
                f1_after = f1_score(y_test, y_pred_opt, average="weighted")
                
            print(f"\n Modèle après optimisation ({model_name}):")
            print(f"   - Accuracy: {accuracy_after}")
            print(f"   - F1-score: {f1_after}")

            # Sauvegarde du meilleur modèle
            if config["save_best_model"]:
                model_filename = f"best_model_{model_name}.pkl"
                with open(model_filename, "wb") as f:
                    pickle.dump(best_model, f)
                print(f" Modèle '{model_name}' sauvegardé sous '{model_filename}'.")

        # Stockage des résultats
        results_df = pd.concat([results_df, pd.DataFrame([{
            "Itération": iteration,
            "Échantillonnage": sampling_status,
            "Tps Sampling": sampling_time,
            "Entrain %": train_percent,
            "Nbre Entrain": num_train,
            "Test %": test_percent,
            "Nbre Test": num_test,
            "Modèle": model_name,
            "Paramètres Initiaux": {param: value for param, value in model.get_params().items() if param in model_params},
            "Tps Entrain Avant": train_time_before,
            "Accuracy Avant": accuracy_before,
            "F1-score Avant": f1_before,
            "Tps Entrain Après": train_time_after,
            "Paramètres Optimisés": best_params,
            "Accuracy Après": accuracy_after,
            "F1-score Après": f1_after
        }])], ignore_index=True)

# Sauvegarde des résultats
# Définition du chemin du fichier Excel
excel_path = f"resultats_{model_name}_{sampling_status}_{os.path.basename(file_path).split('.')[0]}.xlsx"

# Vérifier si le fichier existe
if os.path.exists(excel_path):
    # Ajouter les nouveaux résultats sans charger les anciens
    with pd.ExcelWriter(excel_path, mode='a', if_sheet_exists='overlay') as writer:
        results_df.to_excel(writer, index=False, header=False, startrow=writer.sheets['Sheet1'].max_row)
else:
    # Si le fichier n'existe pas, on crée un nouveau fichier avec les nouveaux résultats
    results_df.to_excel(excel_path, index=False)

print("\n Les nouveaux résultats sont disponible")

# Réinitialisation du DataFrame après la sauvegarde (conserve les colonnes, supprime les lignes)
results_df.drop(results_df.index, inplace=True)
# Out:
#  Données chargées avec succès.
#  Colonne cible définie : species
#  Itérations en cours:   0%|          | 0/2 [00:00<?, ?it/s][I 2025-03-17 22:24:15,549] A new study created in memory with name: no-name-4ad20a3b-e384-41f4-b046-2ae292862b09
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:15,602] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 85, 'max_depth': 10, 'learning_rate': 0.27775729051945225}. Best is trial 0 with value: 1.0.
#  Exécution de l'itération 1...
#
#
# Séparation des données AVANT échantillonnage :
#  - Train: 80 échantillons (80.0%)
#  - Test: 20 échantillons (20.0%)
# Échantillonnage DDBS appliqué.
#
#  Temps samping  : 0.02.
#
# Données après échantillonnage (Train) : 15 échantillons.
# Données de test non modifiées : 20 échantillons.
#
#  Pourcentage Entraînement : 15.00%
#  Pourcentage Test : 20.00%
#
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy: 1.0000
#    - F1-score: 1.0000
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:15,761] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 468, 'max_depth': 16, 'learning_rate': 0.07131055337852513}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:15,886] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 324, 'max_depth': 10, 'learning_rate': 0.010285621191906838}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:15,942] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 183, 'max_depth': 16, 'learning_rate': 0.24093682006239814}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:16,012] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 358, 'max_depth': 4, 'learning_rate': 0.26612127817069586}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:16,085] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 399, 'max_depth': 3, 'learning_rate': 0.24601588393699916}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:16,147] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 263, 'max_depth': 4, 'learning_rate': 0.04340032182083213}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:16,186] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 95, 'max_depth': 12, 'learning_rate': 0.08477373333498509}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:16,267] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 356, 'max_depth': 18, 'learning_rate': 0.015369806457566687}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:16,315] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 165, 'max_depth': 7, 'learning_rate': 0.017617262472741705}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:16,367] Trial 10 finished with value: 1.0 and parameters: {'n_estimators': 54, 'max_depth': 11, 'learning_rate': 0.12427448917278289}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:16,512] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 454, 'max_depth': 14, 'learning_rate': 0.03940413850193774}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:16,633] Trial 12 finished with value: 1.0 and parameters: {'n_estimators': 489, 'max_depth': 20, 'learning_rate': 0.10001851451204775}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:16,711] Trial 13 finished with value: 1.0 and parameters: {'n_estimators': 236, 'max_depth': 8, 'learning_rate': 0.06448068246263672}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:16,785] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 140, 'max_depth': 15, 'learning_rate': 0.17114048088421283}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:16,876] Trial 15 finished with value: 1.0 and parameters: {'n_estimators': 206, 'max_depth': 8, 'learning_rate': 0.02851406739996167}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:16,960] Trial 16 finished with value: 1.0 and parameters: {'n_estimators': 301, 'max_depth': 13, 'learning_rate': 0.16681215571976094}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:17,062] Trial 17 finished with value: 1.0 and parameters: {'n_estimators': 425, 'max_depth': 17, 'learning_rate': 0.1507093164924286}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:17,130] Trial 18 finished with value: 1.0 and parameters: {'n_estimators': 117, 'max_depth': 20, 'learning_rate': 0.061280933411889324}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:17,365] Trial 19 finished with value: 1.0 and parameters: {'n_estimators': 241, 'max_depth': 10, 'learning_rate': 0.0311358080978862}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:17,415] Trial 20 finished with value: 1.0 and parameters: {'n_estimators': 55, 'max_depth': 6, 'learning_rate': 0.10525421630168758}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:17,508] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 320, 'max_depth': 10, 'learning_rate': 0.022947485774925766}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:17,631] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 484, 'max_depth': 9, 'learning_rate': 0.014623313932524185}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:17,758] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 378, 'max_depth': 12, 'learning_rate': 0.011007310693707665}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:17,848] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 292, 'max_depth': 14, 'learning_rate': 0.04417803173418958}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:17,974] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 424, 'max_depth': 6, 'learning_rate': 0.010198254696228613}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:18,139] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 331, 'max_depth': 11, 'learning_rate': 0.07876292597925609}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:18,287] Trial 27 finished with value: 1.0 and parameters: {'n_estimators': 207, 'max_depth': 18, 'learning_rate': 0.022621835924207138}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:18,513] Trial 28 finished with value: 1.0 and parameters: {'n_estimators': 456, 'max_depth': 13, 'learning_rate': 0.2007106272945944}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:18,774] Trial 29 finished with value: 1.0 and parameters: {'n_estimators': 267, 'max_depth': 15, 'learning_rate': 0.13412367409201767}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:18,914] Trial 30 finished with value: 1.0 and parameters: {'n_estimators': 172, 'max_depth': 9, 'learning_rate': 0.21381554612842885}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:19,041] Trial 31 finished with value: 1.0 and parameters: {'n_estimators': 92, 'max_depth': 16, 'learning_rate': 0.28296251797455063}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:19,148] Trial 32 finished with value: 1.0 and parameters: {'n_estimators': 180, 'max_depth': 18, 'learning_rate': 0.2990675926232657}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:19,246] Trial 33 finished with value: 1.0 and parameters: {'n_estimators': 131, 'max_depth': 16, 'learning_rate': 0.2321432744554255}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:19,344] Trial 34 finished with value: 1.0 and parameters: {'n_estimators': 81, 'max_depth': 4, 'learning_rate': 0.05230777945417491}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:19,502] Trial 35 finished with value: 1.0 and parameters: {'n_estimators': 370, 'max_depth': 12, 'learning_rate': 0.19584988730535838}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:19,652] Trial 36 finished with value: 1.0 and parameters: {'n_estimators': 341, 'max_depth': 2, 'learning_rate': 0.2520889017591076}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:19,845] Trial 37 finished with value: 1.0 and parameters: {'n_estimators': 404, 'max_depth': 19, 'learning_rate': 0.10911279611030432}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:19,992] Trial 38 finished with value: 1.0 and parameters: {'n_estimators': 151, 'max_depth': 10, 'learning_rate': 0.012754078261605347}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:20,139] Trial 39 finished with value: 1.0 and parameters: {'n_estimators': 204, 'max_depth': 13, 'learning_rate': 0.08160833674962194}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:20,337] Trial 40 finished with value: 1.0 and parameters: {'n_estimators': 242, 'max_depth': 16, 'learning_rate': 0.037723103656562465}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:20,531] Trial 41 finished with value: 1.0 and parameters: {'n_estimators': 289, 'max_depth': 4, 'learning_rate': 0.2480435270540737}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:20,745] Trial 42 finished with value: 1.0 and parameters: {'n_estimators': 388, 'max_depth': 6, 'learning_rate': 0.18394971453098605}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:20,916] Trial 43 finished with value: 1.0 and parameters: {'n_estimators': 317, 'max_depth': 7, 'learning_rate': 0.15166068929706614}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:21,117] Trial 44 finished with value: 1.0 and parameters: {'n_estimators': 359, 'max_depth': 2, 'learning_rate': 0.2648608206354898}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:21,332] Trial 45 finished with value: 1.0 and parameters: {'n_estimators': 462, 'max_depth': 5, 'learning_rate': 0.1325246984016331}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:21,501] Trial 46 finished with value: 1.0 and parameters: {'n_estimators': 410, 'max_depth': 8, 'learning_rate': 0.23400481477837215}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:21,611] Trial 47 finished with value: 1.0 and parameters: {'n_estimators': 113, 'max_depth': 14, 'learning_rate': 0.01870869304752874}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:21,738] Trial 48 finished with value: 1.0 and parameters: {'n_estimators': 224, 'max_depth': 11, 'learning_rate': 0.16753765687156913}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:21,940] Trial 49 finished with value: 1.0 and parameters: {'n_estimators': 498, 'max_depth': 17, 'learning_rate': 0.06791269757406948}. Best is trial 0 with value: 1.0.
#  Itérations en cours:  50%|█████     | 1/2 [00:06<00:06,  6.54s/it][I 2025-03-17 22:24:22,083] A new study created in memory with name: no-name-9b695ec3-04ae-47e2-8063-ad1385ce3f80
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 85, 'max_depth': 10, 'learning_rate': 0.27775729051945225}
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy: 1.0
#    - F1-score: 1.0
#  Modèle 'XGBoost' sauvegardé sous 'best_model_XGBoost.pkl'.
#
#  Exécution de l'itération 2...
#
#
# Séparation des données AVANT échantillonnage :
#  - Train: 80 échantillons (80.0%)
#  - Test: 20 échantillons (20.0%)
# Échantillonnage DDBS appliqué.
#
#  Temps samping  : 0.01.
#
# Données après échantillonnage (Train) : 15 échantillons.
# Données de test non modifiées : 20 échantillons.
#
#  Pourcentage Entraînement : 15.00%
#  Pourcentage Test : 20.00%
#
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy: 1.0000
#    - F1-score: 1.0000
# [I 2025-03-17 22:24:22,245] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 453, 'max_depth': 11, 'learning_rate': 0.042136367265257955}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:22,387] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 486, 'max_depth': 7, 'learning_rate': 0.06976936266963717}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:22,454] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 191, 'max_depth': 3, 'learning_rate': 0.07608698970770125}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:22,596] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 455, 'max_depth': 6, 'learning_rate': 0.04877742834764851}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:22,779] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 405, 'max_depth': 18, 'learning_rate': 0.09396466199180176}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:22,928] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 425, 'max_depth': 14, 'learning_rate': 0.014419856182319234}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:22,978] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 91, 'max_depth': 10, 'learning_rate': 0.24266071853790838}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:23,061] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 164, 'max_depth': 18, 'learning_rate': 0.014109328221961658}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:23,193] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 339, 'max_depth': 5, 'learning_rate': 0.07119389772020338}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:23,244] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 96, 'max_depth': 12, 'learning_rate': 0.06643846089762362}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:23,379] Trial 10 finished with value: 1.0 and parameters: {'n_estimators': 297, 'max_depth': 15, 'learning_rate': 0.03010822049618649}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:23,548] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 493, 'max_depth': 9, 'learning_rate': 0.15859496816149934}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:23,789] Trial 12 finished with value: 1.0 and parameters: {'n_estimators': 361, 'max_depth': 8, 'learning_rate': 0.03268365218782795}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:24,013] Trial 13 finished with value: 1.0 and parameters: {'n_estimators': 494, 'max_depth': 2, 'learning_rate': 0.028330359503738103}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:24,142] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 252, 'max_depth': 13, 'learning_rate': 0.10648261287537035}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:24,305] Trial 15 finished with value: 1.0 and parameters: {'n_estimators': 392, 'max_depth': 7, 'learning_rate': 0.0477375995943145}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:24,500] Trial 16 finished with value: 1.0 and parameters: {'n_estimators': 457, 'max_depth': 11, 'learning_rate': 0.1446968205414988}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:24,646] Trial 17 finished with value: 1.0 and parameters: {'n_estimators': 304, 'max_depth': 16, 'learning_rate': 0.040676491887592856}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:24,776] Trial 18 finished with value: 1.0 and parameters: {'n_estimators': 241, 'max_depth': 4, 'learning_rate': 0.018247341808051577}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:24,978] Trial 19 finished with value: 1.0 and parameters: {'n_estimators': 358, 'max_depth': 9, 'learning_rate': 0.022478997935965816}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:25,168] Trial 20 finished with value: 1.0 and parameters: {'n_estimators': 440, 'max_depth': 7, 'learning_rate': 0.28166108183165944}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:25,297] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 180, 'max_depth': 2, 'learning_rate': 0.07619589719393535}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:25,460] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 196, 'max_depth': 4, 'learning_rate': 0.11802926447315679}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:25,632] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 135, 'max_depth': 4, 'learning_rate': 0.010031909506737472}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:25,792] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 223, 'max_depth': 11, 'learning_rate': 0.05398792058655072}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:26,009] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 499, 'max_depth': 20, 'learning_rate': 0.03957547556454902}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:26,106] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 130, 'max_depth': 6, 'learning_rate': 0.18223064033895062}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:26,191] Trial 27 finished with value: 1.0 and parameters: {'n_estimators': 58, 'max_depth': 3, 'learning_rate': 0.08758844514117281}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:26,327] Trial 28 finished with value: 1.0 and parameters: {'n_estimators': 274, 'max_depth': 8, 'learning_rate': 0.06453132191849519}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:26,484] Trial 29 finished with value: 1.0 and parameters: {'n_estimators': 458, 'max_depth': 6, 'learning_rate': 0.04938540797706544}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:26,622] Trial 30 finished with value: 1.0 and parameters: {'n_estimators': 389, 'max_depth': 10, 'learning_rate': 0.0392176129824674}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:26,773] Trial 31 finished with value: 1.0 and parameters: {'n_estimators': 424, 'max_depth': 5, 'learning_rate': 0.09364755241196757}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:26,947] Trial 32 finished with value: 1.0 and parameters: {'n_estimators': 475, 'max_depth': 6, 'learning_rate': 0.05793346863657764}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:27,093] Trial 33 finished with value: 1.0 and parameters: {'n_estimators': 409, 'max_depth': 3, 'learning_rate': 0.08566461627372532}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:27,308] Trial 34 finished with value: 1.0 and parameters: {'n_estimators': 463, 'max_depth': 13, 'learning_rate': 0.11529710560112359}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:27,572] Trial 35 finished with value: 1.0 and parameters: {'n_estimators': 427, 'max_depth': 8, 'learning_rate': 0.024399598370651043}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:27,697] Trial 36 finished with value: 1.0 and parameters: {'n_estimators': 327, 'max_depth': 5, 'learning_rate': 0.04404345284084334}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:27,960] Trial 37 finished with value: 1.0 and parameters: {'n_estimators': 366, 'max_depth': 7, 'learning_rate': 0.060805303694366555}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:28,117] Trial 38 finished with value: 1.0 and parameters: {'n_estimators': 440, 'max_depth': 10, 'learning_rate': 0.03554921493742189}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:28,281] Trial 39 finished with value: 1.0 and parameters: {'n_estimators': 475, 'max_depth': 15, 'learning_rate': 0.07505251974078526}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:28,390] Trial 40 finished with value: 1.0 and parameters: {'n_estimators': 216, 'max_depth': 9, 'learning_rate': 0.13782109361506786}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:28,528] Trial 41 finished with value: 1.0 and parameters: {'n_estimators': 401, 'max_depth': 18, 'learning_rate': 0.07662088023236077}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:28,953] Trial 42 finished with value: 1.0 and parameters: {'n_estimators': 439, 'max_depth': 18, 'learning_rate': 0.1012985446041985}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:29,176] Trial 43 finished with value: 1.0 and parameters: {'n_estimators': 478, 'max_depth': 12, 'learning_rate': 0.05327548465496663}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:29,363] Trial 44 finished with value: 1.0 and parameters: {'n_estimators': 414, 'max_depth': 17, 'learning_rate': 0.06527047848363432}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:29,511] Trial 45 finished with value: 1.0 and parameters: {'n_estimators': 334, 'max_depth': 20, 'learning_rate': 0.17871070491290836}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:29,673] Trial 46 finished with value: 1.0 and parameters: {'n_estimators': 373, 'max_depth': 14, 'learning_rate': 0.03032623939962046}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:29,779] Trial 47 finished with value: 1.0 and parameters: {'n_estimators': 148, 'max_depth': 3, 'learning_rate': 0.04610110733782385}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:29,956] Trial 48 finished with value: 1.0 and parameters: {'n_estimators': 452, 'max_depth': 12, 'learning_rate': 0.12653344528075253}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3259171777.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-17 22:24:30,143] Trial 49 finished with value: 1.0 and parameters: {'n_estimators': 498, 'max_depth': 2, 'learning_rate': 0.026540083331947264}. Best is trial 0 with value: 1.0.
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 453, 'max_depth': 11, 'learning_rate': 0.042136367265257955}
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy: 1.0
#    - F1-score: 1.0
#  Modèle 'XGBoost' sauvegardé sous 'best_model_XGBoost.pkl'.
#  Itérations en cours: 100%|██████████| 2/2 [00:14<00:00,  7.45s/it]
#  Les nouveaux résultats sont disponible

# %%
import numpy as np
import pandas as pd
import json
import optuna
import pickle
import os
import time
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier

# Import collection des resultat
from resultat.collect_results import collect_results

# Import sécurisé de gmm_sampling
try:
    from sampling.gmm_sampling import gmm_sampling
except ModuleNotFoundError:
    raise ImportError(" Impossible d'importer gmm_sampling. Vérifiez le chemin du fichier.")

# Import sécurisé de ddbs_sampling
try:
    from sampling.ddbs_sampling import diversified_distance_based_sampling
except ModuleNotFoundError:
    raise ImportError("Impossible d'importer ddbs_sampling. Vérifiez le chemin du fichier.")


# Charger la configuration depuis config.json
with open("config.json", "r") as config_file:
    config = json.load(config_file)

file_path = config["file_path"]
model_save_path = config["model_save_path"]
num_iterations = config.get("num_iterations", 2)  #  Nombre d'itérations

# Charger le dataset CSV avec gestion des erreurs
df = pd.read_csv(file_path)
print(" Données chargées avec succès.")

# Définition de la colonne cible
target_column = config["target_column"]
if target_column not in df.columns:
    raise ValueError(f" La colonne cible '{target_column}' est absente des données.")

print(f" Colonne cible définie : {target_column}")

# Initialisation du DataFrame pour stocker les résultats
columns = [
    "Itération", "Échantillonnage","Tps Sampling","Entrain %", "Nbre Entrain", "Test %", "Nbre Test", "Modèle", "Paramètres Initiaux",
    "Tps Entrain Avant", "Accuracy Avant","F1-score Avant", "Tps Entrain Après", "Paramètres Optimisés", "Accuracy Après", "F1-score Après"    
]
results_df = pd.DataFrame(columns=columns)



#  Définition du fichier log pour les résultats
log_file = "results_log.txt"

def save_results(iteration_results):
    """
    Ajoute les résultats d'une itération dans `results_log.txt`
    sans recréer le fichier à chaque fois.
    """
    try:
        if not os.path.exists(log_file):
            with open(log_file, "w", encoding="utf-8") as f:
                f.write("Log des résultats\n\n")

        with open(log_file, "a", encoding="utf-8") as f:
            f.write(json.dumps(iteration_results, indent=4, ensure_ascii=False) + "\n\n")

        print(f"Résultats enregistrés dans {log_file}")

    except Exception as e:
        print(f" Erreur lors de l'enregistrement des résultats : {e}")






# Exécuter 30 itérations

for iteration in tqdm(range(1, num_iterations  + 1), desc=" Itérations en cours"):
    print(f"\n Exécution de l'itération {iteration}...\n")

     # Séparation des données en Train/Test avant sampling
    test_size = config["train_test_split"]["test_size"]
    X = df.drop(columns=[target_column])
    y = df[target_column]

    # Division des données
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

    # Récupérer le nombre d'échantillons avant sampling
    num_train = len(X_train)
    num_test = len(X_test) 

    #  Affichage de la répartition des données avant échantillonnage
    print(f"\nSéparation des données AVANT échantillonnage :")
    print(f" - Train: {num_train} échantillons ({(1 - test_size) * 100:.1f}%)")
    print(f" - Test: {num_test} échantillons ({test_size * 100:.1f}%)")

    
    #  Appliquer le sampling UNIQUEMENT sur les données d'entraînement
    start_sampling_time = time.time()
    
    # Appliquer le sampling si activé
    if config["sampling"]["enabled"]:
        # Si le sampling type est GMM, appliquer le sampling GMM
        if config["sampling"]["gmm"]["enabled"]:
            df_train_sampled = gmm_sampling(pd.concat([X_train, y_train], axis=1), target_column, config)
            X_train_sampled = df_train_sampled.drop(columns=[target_column])
            y_train_sampled = df_train_sampled[target_column]
            sampling_status = "Oui (GMM)"
            print("Échantillonnage GMM appliqué")
        
        # Si le sampling type est Random, utiliser Pandas sample()
        elif config["sampling"]["random"]["enabled"]:
            fraction = config["sampling"]["fraction"]
            sampled_indices = X_train.sample(frac=fraction).index
            X_train_sampled, y_train_sampled = X_train.loc[sampled_indices], y_train.loc[sampled_indices]
            sampling_status = "Oui (Random)"
            print(f" Échantillonnage aléatoire activé : {fraction*100:.1f}% des données utilisées.")
        
        # Si le sampling type est ddbs, utiliser Pandas sample()    
        elif config["sampling"]["ddbs"]["enabled"]:
            df_train_sampled = diversified_distance_based_sampling(pd.concat([X_train, y_train], axis=1), target_column, config)
            X_train_sampled = df_train_sampled.drop(columns=[target_column])
            y_train_sampled = df_train_sampled[target_column]
            sampling_status = f"Oui (DDBS - {config['sampling']['ddbs']['distance_metric']}, {config['sampling']['ddbs']['distribution_type']})"
            print("Échantillonnage DDBS appliqué.")
        
        # Si le type est inconnu, lever une erreur
        else:
            raise ValueError(f" Type d'échantillonnage inconnu : '{sampling_type}'")

    else:
        # Si le sampling est désactivé, utiliser le dataset original
        X_train_sampled, y_train_sampled = X_train, y_train
        sampling_status = "Non"
        print(" Aucun échantillonnage appliqué, utilisation des données complètes.")

    # Calcul du temps pris pour le sampling
    sampling_time = round(time.time() - start_sampling_time , 2) # Calcul du temps pris par le sampling
    print(f"\n Temps samping  : {sampling_time}.")
    
    #  Mise à jour du nombre d'échantillons après sampling
    num_train_sampled = len(X_train_sampled)
    num_test_sampled = len(X_test) # Le test set reste inchangé

    print(f"\nDonnées après échantillonnage (Train) : {num_train_sampled} échantillons.")
    print(f"Données de test non modifiées : {num_test_sampled} échantillons.")
    
    # Calcul du pourcentage des données après échantillonnage
    train_percent = (len(X_train_sampled) / len(df)) * 100
    test_percent = (len(X_test) / len(df)) * 100
    
    print(f"\n Pourcentage Entraînement : {train_percent:.2f}%")
    print(f" Pourcentage Test : {test_percent:.2f}%")

    # Initialiser les modèles
    models = {}
    for model_name, model_params in config["models"].items():
        if model_params["enabled"]:
            if model_name == "Decision Tree":
                models[model_name] = DecisionTreeClassifier(max_depth=model_params["max_depth"])
            elif model_name == "Random Forest":
                models[model_name] = RandomForestClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"]
                )
            elif model_name == "SVM":
                models[model_name] = SVC(C=model_params["C"], kernel=model_params["kernel"])
            elif model_name == "Neural Network":
                models[model_name] = MLPClassifier(
                    hidden_layer_sizes=tuple(model_params["hidden_layer_sizes"]),
                    learning_rate_init=model_params["learning_rate_init"],
                    max_iter=500
                )
            elif model_name == "XGBoost":
                models[model_name] = XGBClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"],
                    learning_rate=model_params["learning_rate"]    
                )

    # Entraînement et évaluation des modèles
    for model_name, model in models.items():
        start_train_time = time.time()  # Début du chronométrage de l'entraînement avant optimisation
        model.fit(X_train, y_train)
        train_time_before = round(time.time() - start_train_time , 2)  # Temps pris pour l'entraînement avant optimisation

        #  Calcul des scores sur TRAIN
        y_train_pred = model.predict(X_train)
        train_accuracy = accuracy_score(y_train, y_train_pred)
        train_f1 = f1_score(y_train, y_train_pred, average="weighted")

        #  Calcul des scores sur TEST
        y_pred = model.predict(X_test)
        accuracy_before = accuracy_score(y_test, y_pred)
        f1_before = f1_score(y_test, y_pred, average="weighted")
        
        print(f"\n Résultats du modèle '{model_name}' avant optimisation :")
        print(f"   - Accuracy Train: {train_accuracy:.4f}")
        print(f"   - Accuracy Test: {accuracy_before:.4f}")
        print(f"   - F1-score Train: {train_f1:.4f}")
        print(f"   - F1-score Test: {f1_before:.4f}")

        #  Vérification de l'overfitting / underfitting
        if train_accuracy > accuracy_before + 0.10:
            print(" Overfitting détecté !")
        elif train_accuracy < 0.7 and accuracy_before < 0.7:
            print(" Underfitting détecté !")
        else:
            print(" Bon équilibre entre biais et variance.")

        best_params = {}
        best_model = model
        accuracy_after, f1_after = "Non optimisé", "Non optimisé"

        # Optimisation avec Optuna
        if config["use_optuna"]:
            def objective(trial):
                if model_name == "Decision Tree":
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = DecisionTreeClassifier(max_depth=max_depth)
                elif model_name == "Random Forest":
                    n_estimators = trial.suggest_int("n_estimators", 10, 200)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
                elif model_name == "SVM":
                    C = trial.suggest_loguniform("C", 0.1, 10)
                    kernel = trial.suggest_categorical("kernel", ["linear", "rbf", "poly"])
                    model_opt = SVC(C=C, kernel=kernel)
                elif model_name == "Neural Network":
                    hidden_layer_sizes = trial.suggest_categorical("hidden_layer_sizes", [(50,), (100,), (50, 50)])
                    learning_rate_init = trial.suggest_loguniform("learning_rate_init", 0.0001, 0.1)
                    model_opt = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, learning_rate_init=learning_rate_init, max_iter=500)
                elif model_name == "XGBoost":
                    n_estimators = trial.suggest_int("n_estimators", 50, 500)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
                    model_opt = XGBClassifier(n_estimators=n_estimators, max_depth=max_depth, learning_rate=learning_rate)

                model_opt.fit(X_train, y_train)
                y_pred_opt = model_opt.predict(X_test)
                return accuracy_score(y_test, y_pred_opt)

            study = optuna.create_study(direction="maximize")
            study.optimize(objective, n_trials=config["n_trials"])

            best_params = study.best_trial.params
            print(f"\n Meilleurs paramètres trouvés pour '{model_name}' : {best_params}")

            # Réentraînement avec les meilleurs paramètres
            if config["retrain_with_best_params"]:
                start_train_time_after = time.time()  # Début du chronométrage de l'entraînement après optimisation
                best_model = model.__class__(**best_params)
                best_model.fit(X_train, y_train)
                train_time_after = round(time.time() - start_train_time_after, 2) # Temps pris pour l'entraînement après optimisation

                # #  Calcul des scores sur TRAIN apres optimisation 
                y_train_pred_opt = best_model.predict(X_train)
                train_accuracy_after = accuracy_score(y_train, y_train_pred_opt)
                train_f1_after = f1_score(y_train, y_train_pred_opt, average="weighted")
                
                #  Calcul des scores sur TEST apres optimisation 
                y_pred_opt = best_model.predict(X_test)
                accuracy_after = accuracy_score(y_test, y_pred_opt)
                f1_after = f1_score(y_test, y_pred_opt, average="weighted")

            print(f"\n Modèle après optimisation ({model_name}):")
            print(f"   - Accuracy Train: {train_accuracy_after:.4f}")
            print(f"   - Accuracy Test: {accuracy_after:.4f}")
            print(f"   - F1-score Train: {train_f1_after:.4f}")
            print(f"   - F1-score Test: {f1_after:.4f}")

            #  Vérification de l'overfitting / underfitting après optimisation
            if train_accuracy_after > accuracy_after + 0.10:
                print(" Overfitting détecté après optimisation !")
            elif train_accuracy_after < 0.7 and accuracy_after < 0.7:
                print(" Underfitting détecté après optimisation !")
            else:
                print(" Bon équilibre entre biais et variance après optimisation.")
                               

            # Sauvegarde du meilleur modèle
            if config["save_best_model"]:
                model_filename = f"best_model_{model_name}.pkl"
                with open(model_filename, "wb") as f:
                    pickle.dump(best_model, f)
                print(f" Modèle '{model_name}' sauvegardé sous '{model_filename}'.")

        # Stockage des résultats
        results_df = pd.concat([results_df, pd.DataFrame([{
            "Itération": iteration,
            "Échantillonnage": sampling_status,
            "Tps Sampling": sampling_time,
            "Entrain %": train_percent,
            "Nbre Entrain": num_train,
            "Test %": test_percent,
            "Nbre Test": num_test,
            "Modèle": model_name,
            "Paramètres Initiaux": {param: value for param, value in model.get_params().items() if param in model_params},
            "Tps Entrain Avant": train_time_before,
            "Accuracy Avant": accuracy_before,
            "F1-score Avant": f1_before,
            "Tps Entrain Après": train_time_after,
            "Paramètres Optimisés": best_params,
            "Accuracy Après": accuracy_after,
            "F1-score Après": f1_after
        }])], ignore_index=True)
        
        

        # 📌 Vérification si on est bien entré dans la collecte des résultats
        print(f" [DEBUG] Début de la collecte des résultats pour l'itération {iteration}...")
        
        #  Enregistrement des résultats dans results_log.txt avec collect_results
        iteration_results =collect_results(
            iteration, config, file_path, target_column, sampling_status, sampling_time,
            train_percent, num_train_sampled, test_percent, num_test_sampled,
            model_name, model, model.get_params(), train_time_before,
            accuracy_before, f1_before, train_time_after, best_params,
            accuracy_after, f1_after
        )

        
        #  Vérification si collect_results() a retourné un dictionnaire valide
        print(f" [DEBUG] Résultats collectés pour l'itération {iteration}:")
        print(json.dumps(iteration_results, indent=4, ensure_ascii=False))
        
        #  Enregistrement des résultats
        print(f" [DEBUG] Enregistrement des résultats dans results_log.txt...")
        save_results(iteration_results)
        print(f" [DEBUG] Résultats enregistrés avec succès !")



# Sauvegarde des résultats
# Définition du chemin du fichier Excel
excel_path = f"resultats_{model_name}_{sampling_status}_{os.path.basename(file_path).split('.')[0]}.xlsx"

# Vérifier si le fichier existe
if os.path.exists(excel_path):
    # Ajouter les nouveaux résultats sans charger les anciens
    with pd.ExcelWriter(excel_path, mode='a', if_sheet_exists='overlay') as writer:
        results_df.to_excel(writer, index=False, header=False, startrow=writer.sheets['Sheet1'].max_row)
else:
    # Si le fichier n'existe pas, on crée un nouveau fichier avec les nouveaux résultats
    results_df.to_excel(excel_path, index=False)

print("\n Les nouveaux résultats sont disponible")

# Réinitialisation du DataFrame après la sauvegarde (conserve les colonnes, supprime les lignes)
results_df.drop(results_df.index, inplace=True)
# Out:
#  Données chargées avec succès.
#  Colonne cible définie : species
#  Itérations en cours:   0%|          | 0/2 [00:00<?, ?it/s][I 2025-03-18 17:04:56,455] A new study created in memory with name: no-name-699474c6-aa2c-45fa-9e4d-88d385d9dbe2
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:56,524] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 163, 'max_depth': 7, 'learning_rate': 0.024739858555679808}. Best is trial 0 with value: 1.0.
#  Exécution de l'itération 1...
#
#
# Séparation des données AVANT échantillonnage :
#  - Train: 80 échantillons (80.0%)
#  - Test: 20 échantillons (20.0%)
# Échantillonnage DDBS appliqué.
#
#  Temps samping  : 0.01.
#
# Données après échantillonnage (Train) : 16 échantillons.
# Données de test non modifiées : 20 échantillons.
#
#  Pourcentage Entraînement : 16.00%
#  Pourcentage Test : 20.00%
#
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy: 1.0000
#    - F1-score: 1.0000
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:56,614] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 229, 'max_depth': 10, 'learning_rate': 0.09829292348021881}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:56,702] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 160, 'max_depth': 19, 'learning_rate': 0.012530199131746439}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:56,850] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 435, 'max_depth': 3, 'learning_rate': 0.015963410843806328}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:56,947] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 352, 'max_depth': 4, 'learning_rate': 0.24041162681323983}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:57,057] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 410, 'max_depth': 11, 'learning_rate': 0.13242559510320273}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:57,138] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 306, 'max_depth': 5, 'learning_rate': 0.05365679427228963}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:57,203] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 179, 'max_depth': 10, 'learning_rate': 0.058728682386537175}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:57,337] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 409, 'max_depth': 15, 'learning_rate': 0.013073665840611141}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:57,462] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 439, 'max_depth': 8, 'learning_rate': 0.22780414517538614}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:57,534] Trial 10 finished with value: 1.0 and parameters: {'n_estimators': 69, 'max_depth': 15, 'learning_rate': 0.029354229470828677}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:57,639] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 217, 'max_depth': 7, 'learning_rate': 0.07753778419955458}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:57,715] Trial 12 finished with value: 1.0 and parameters: {'n_estimators': 92, 'max_depth': 13, 'learning_rate': 0.038332710731477725}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:57,840] Trial 13 finished with value: 1.0 and parameters: {'n_estimators': 250, 'max_depth': 8, 'learning_rate': 0.023986757731490272}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:57,958] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 140, 'max_depth': 6, 'learning_rate': 0.11148831725977425}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:58,220] Trial 15 finished with value: 1.0 and parameters: {'n_estimators': 308, 'max_depth': 10, 'learning_rate': 0.02143691812212886}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:58,368] Trial 16 finished with value: 1.0 and parameters: {'n_estimators': 217, 'max_depth': 14, 'learning_rate': 0.1439016548301612}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:58,492] Trial 17 finished with value: 1.0 and parameters: {'n_estimators': 127, 'max_depth': 2, 'learning_rate': 0.0382473263175325}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:58,658] Trial 18 finished with value: 1.0 and parameters: {'n_estimators': 244, 'max_depth': 19, 'learning_rate': 0.08371505991815036}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:58,812] Trial 19 finished with value: 1.0 and parameters: {'n_estimators': 191, 'max_depth': 11, 'learning_rate': 0.0461472964406704}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:58,965] Trial 20 finished with value: 1.0 and parameters: {'n_estimators': 333, 'max_depth': 8, 'learning_rate': 0.16838196045987952}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:59,073] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 143, 'max_depth': 20, 'learning_rate': 0.015004090236112105}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:59,190] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 163, 'max_depth': 18, 'learning_rate': 0.010095985510233958}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:59,305] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 101, 'max_depth': 17, 'learning_rate': 0.020369826120334084}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:59,632] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 204, 'max_depth': 13, 'learning_rate': 0.010159739589897894}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:04:59,896] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 269, 'max_depth': 9, 'learning_rate': 0.027234531136934713}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:00,024] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 163, 'max_depth': 6, 'learning_rate': 0.079389807094591}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:00,259] Trial 27 finished with value: 1.0 and parameters: {'n_estimators': 482, 'max_depth': 12, 'learning_rate': 0.01664950463984779}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:00,376] Trial 28 finished with value: 1.0 and parameters: {'n_estimators': 115, 'max_depth': 16, 'learning_rate': 0.012581723922329133}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:00,472] Trial 29 finished with value: 1.0 and parameters: {'n_estimators': 67, 'max_depth': 4, 'learning_rate': 0.01813483174322191}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:00,647] Trial 30 finished with value: 1.0 and parameters: {'n_estimators': 250, 'max_depth': 10, 'learning_rate': 0.032109076954713885}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:00,852] Trial 31 finished with value: 1.0 and parameters: {'n_estimators': 376, 'max_depth': 2, 'learning_rate': 0.013682515899087084}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:01,025] Trial 32 finished with value: 1.0 and parameters: {'n_estimators': 482, 'max_depth': 3, 'learning_rate': 0.2862818274634514}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:01,169] Trial 33 finished with value: 1.0 and parameters: {'n_estimators': 292, 'max_depth': 5, 'learning_rate': 0.10547078758092183}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:01,312] Trial 34 finished with value: 1.0 and parameters: {'n_estimators': 371, 'max_depth': 4, 'learning_rate': 0.05880716616569567}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:01,422] Trial 35 finished with value: 1.0 and parameters: {'n_estimators': 168, 'max_depth': 6, 'learning_rate': 0.017342819717398626}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:01,535] Trial 36 finished with value: 1.0 and parameters: {'n_estimators': 227, 'max_depth': 11, 'learning_rate': 0.012324639093524421}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:01,725] Trial 37 finished with value: 1.0 and parameters: {'n_estimators': 429, 'max_depth': 7, 'learning_rate': 0.024677621917623356}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:01,836] Trial 38 finished with value: 1.0 and parameters: {'n_estimators': 192, 'max_depth': 9, 'learning_rate': 0.18164353720429083}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:01,976] Trial 39 finished with value: 1.0 and parameters: {'n_estimators': 319, 'max_depth': 5, 'learning_rate': 0.06166720151425681}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:02,122] Trial 40 finished with value: 1.0 and parameters: {'n_estimators': 272, 'max_depth': 3, 'learning_rate': 0.03472407317050092}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:02,265] Trial 41 finished with value: 1.0 and parameters: {'n_estimators': 355, 'max_depth': 4, 'learning_rate': 0.278162940132868}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:02,420] Trial 42 finished with value: 1.0 and parameters: {'n_estimators': 395, 'max_depth': 7, 'learning_rate': 0.21953440902728608}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:02,588] Trial 43 finished with value: 1.0 and parameters: {'n_estimators': 443, 'max_depth': 3, 'learning_rate': 0.11169615482619696}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:02,710] Trial 44 finished with value: 1.0 and parameters: {'n_estimators': 341, 'max_depth': 5, 'learning_rate': 0.04368083666553388}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:02,859] Trial 45 finished with value: 1.0 and parameters: {'n_estimators': 414, 'max_depth': 9, 'learning_rate': 0.02044613141704036}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:03,003] Trial 46 finished with value: 1.0 and parameters: {'n_estimators': 454, 'max_depth': 12, 'learning_rate': 0.14156276690222505}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:03,119] Trial 47 finished with value: 1.0 and parameters: {'n_estimators': 291, 'max_depth': 15, 'learning_rate': 0.06668045372865282}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:03,203] Trial 48 finished with value: 1.0 and parameters: {'n_estimators': 146, 'max_depth': 8, 'learning_rate': 0.011527535399637337}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:03,314] Trial 49 finished with value: 1.0 and parameters: {'n_estimators': 224, 'max_depth': 6, 'learning_rate': 0.014871891380847867}. Best is trial 0 with value: 1.0.
#  Itérations en cours:  50%|█████     | 1/2 [00:07<00:07,  7.01s/it][I 2025-03-18 17:05:03,443] A new study created in memory with name: no-name-fa031b9b-1ad6-4062-9795-400972972ede
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 163, 'max_depth': 7, 'learning_rate': 0.024739858555679808}
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy: 1.0
#    - F1-score: 1.0
# 🔍 [DEBUG] Début de la collecte des résultats pour l'itération 1...
#  Erreur lors de l'enregistrement des résultats : name 'json' is not defined
# ✅ [DEBUG] Résultats collectés pour l'itération 1:
# {
#     "Itération": 1,
#     "Dataset utilisé": "data/dataP/preprocessed_iris_dataset.csv",
#     "Colonne cible": "species",
#     "Échantillonnage": "Oui (DDBS - euclidean, geometric)",
#     "Tps Sampling": 0.01,
#     "Entrain %": 16.0,
#     "Nbre Entrain": 16,
#     "Test %": 20.0,
#     "Nbre Test": 20,
#     "Sampling DDBS": {
#         "distance_metric": "euclidean",
#         "distribution_type": "geometric",
#         "percentage_per_class": 0.2,
#         "total_selected_samples": 16
#     },
#     "Modèle": "XGBoost",
#     "Paramètres initiaux": {
#         "objective": "binary:logistic",
#         "base_score": null,
#         "booster": null,
#         "callbacks": null,
#         "colsample_bylevel": null,
#         "colsample_bynode": null,
#         "colsample_bytree": null,
#         "device": null,
#         "early_stopping_rounds": null,
#         "enable_categorical": false,
#         "eval_metric": null,
#         "feature_types": null,
#         "gamma": null,
#         "grow_policy": null,
#         "importance_type": null,
#         "interaction_constraints": null,
#         "learning_rate": 0.1,
#         "max_bin": null,
#         "max_cat_threshold": null,
#         "max_cat_to_onehot": null,
#         "max_delta_step": null,
#         "max_depth": 6,
#         "max_leaves": null,
#         "min_child_weight": null,
#         "missing": NaN,
#         "monotone_constraints": null,
#         "multi_strategy": null,
#         "n_estimators": 100,
#         "n_jobs": null,
#         "num_parallel_tree": null,
#         "random_state": null,
#         "reg_alpha": null,
#         "reg_lambda": null,
#         "sampling_method": null,
#         "scale_pos_weight": null,
#         "subsample": null,
#         "tree_method": null,
#         "validate_parameters": null,
#         "verbosity": null
#     },
#     "Tps Entrain Avant": 0.05,
#     "Accuracy Avant": 1.0,
#     "F1-score Avant": 1.0,
#     "Tps Entrain Après": 0.05,
#     "Paramètres optimisés": {
#         "n_estimators": 163,
#         "max_depth": 7,
#         "learning_rate": 0.024739858555679808
#     },
#     "Accuracy Après": 1.0,
#     "F1-score Après": 1.0
# }
# 💾 [DEBUG] Enregistrement des résultats dans results_log.txt...
# Résultats enregistrés dans results_log.txt
# ✅ [DEBUG] Résultats enregistrés avec succès !
#
#  Exécution de l'itération 2...
#
#
# Séparation des données AVANT échantillonnage :
#  - Train: 80 échantillons (80.0%)
#  - Test: 20 échantillons (20.0%)
# Échantillonnage DDBS appliqué.
#
#  Temps samping  : 0.01.
#
# Données après échantillonnage (Train) : 15 échantillons.
# Données de test non modifiées : 20 échantillons.
#
#  Pourcentage Entraînement : 15.00%
#  Pourcentage Test : 20.00%
#
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy: 0.9500
#    - F1-score: 0.9504
# [I 2025-03-18 17:05:03,526] Trial 0 finished with value: 0.95 and parameters: {'n_estimators': 270, 'max_depth': 20, 'learning_rate': 0.02738760482297254}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:03,577] Trial 1 finished with value: 0.95 and parameters: {'n_estimators': 69, 'max_depth': 11, 'learning_rate': 0.024890071519791866}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:03,676] Trial 2 finished with value: 0.95 and parameters: {'n_estimators': 309, 'max_depth': 17, 'learning_rate': 0.024253926605203344}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:03,712] Trial 3 finished with value: 0.95 and parameters: {'n_estimators': 72, 'max_depth': 18, 'learning_rate': 0.12892137668945547}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:03,860] Trial 4 finished with value: 0.95 and parameters: {'n_estimators': 432, 'max_depth': 16, 'learning_rate': 0.020378298016952824}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:03,967] Trial 5 finished with value: 0.95 and parameters: {'n_estimators': 382, 'max_depth': 7, 'learning_rate': 0.02927758548027444}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:04,059] Trial 6 finished with value: 0.95 and parameters: {'n_estimators': 260, 'max_depth': 4, 'learning_rate': 0.014905010164030591}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:04,105] Trial 7 finished with value: 0.95 and parameters: {'n_estimators': 93, 'max_depth': 14, 'learning_rate': 0.076918971070139}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:04,143] Trial 8 finished with value: 0.95 and parameters: {'n_estimators': 63, 'max_depth': 3, 'learning_rate': 0.22312729584470198}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:04,245] Trial 9 finished with value: 0.95 and parameters: {'n_estimators': 293, 'max_depth': 6, 'learning_rate': 0.11114331300484419}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:04,350] Trial 10 finished with value: 0.95 and parameters: {'n_estimators': 189, 'max_depth': 20, 'learning_rate': 0.04370994594427827}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:04,452] Trial 11 finished with value: 0.95 and parameters: {'n_estimators': 170, 'max_depth': 11, 'learning_rate': 0.010575351853995205}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:04,575] Trial 12 finished with value: 0.95 and parameters: {'n_estimators': 172, 'max_depth': 11, 'learning_rate': 0.04236386868080004}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:04,747] Trial 13 finished with value: 0.95 and parameters: {'n_estimators': 490, 'max_depth': 13, 'learning_rate': 0.03422993388013516}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:04,865] Trial 14 finished with value: 0.95 and parameters: {'n_estimators': 245, 'max_depth': 8, 'learning_rate': 0.06826245691533103}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:05,013] Trial 15 finished with value: 0.95 and parameters: {'n_estimators': 344, 'max_depth': 9, 'learning_rate': 0.017052554957376433}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:05,115] Trial 16 finished with value: 0.95 and parameters: {'n_estimators': 124, 'max_depth': 14, 'learning_rate': 0.010060363648708609}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:05,242] Trial 17 finished with value: 0.95 and parameters: {'n_estimators': 225, 'max_depth': 20, 'learning_rate': 0.04990154947941296}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:05,352] Trial 18 finished with value: 0.95 and parameters: {'n_estimators': 126, 'max_depth': 10, 'learning_rate': 0.02855193527377086}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:05,551] Trial 19 finished with value: 0.95 and parameters: {'n_estimators': 400, 'max_depth': 13, 'learning_rate': 0.013826395903727981}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:05,762] Trial 20 finished with value: 0.95 and parameters: {'n_estimators': 491, 'max_depth': 5, 'learning_rate': 0.020658092145365518}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:05,907] Trial 21 finished with value: 0.95 and parameters: {'n_estimators': 315, 'max_depth': 17, 'learning_rate': 0.02429006318040684}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:06,046] Trial 22 finished with value: 0.95 and parameters: {'n_estimators': 334, 'max_depth': 18, 'learning_rate': 0.032731237002480484}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:06,151] Trial 23 finished with value: 0.95 and parameters: {'n_estimators': 210, 'max_depth': 16, 'learning_rate': 0.02327718360625207}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:06,279] Trial 24 finished with value: 0.95 and parameters: {'n_estimators': 296, 'max_depth': 19, 'learning_rate': 0.06115747345964535}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:06,421] Trial 25 finished with value: 0.95 and parameters: {'n_estimators': 364, 'max_depth': 15, 'learning_rate': 0.018168084146046103}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:06,593] Trial 26 finished with value: 0.95 and parameters: {'n_estimators': 426, 'max_depth': 18, 'learning_rate': 0.0395345867708871}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:06,733] Trial 27 finished with value: 0.95 and parameters: {'n_estimators': 147, 'max_depth': 12, 'learning_rate': 0.013808801405376924}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:06,910] Trial 28 finished with value: 0.95 and parameters: {'n_estimators': 272, 'max_depth': 20, 'learning_rate': 0.027354180442523298}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:07,009] Trial 29 finished with value: 0.95 and parameters: {'n_estimators': 89, 'max_depth': 16, 'learning_rate': 0.08636688788213456}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:07,143] Trial 30 finished with value: 0.95 and parameters: {'n_estimators': 218, 'max_depth': 17, 'learning_rate': 0.2505094715212516}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:07,219] Trial 31 finished with value: 0.95 and parameters: {'n_estimators': 62, 'max_depth': 18, 'learning_rate': 0.14350805717908993}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:07,287] Trial 32 finished with value: 0.95 and parameters: {'n_estimators': 52, 'max_depth': 19, 'learning_rate': 0.12388866700256107}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:07,371] Trial 33 finished with value: 0.95 and parameters: {'n_estimators': 106, 'max_depth': 15, 'learning_rate': 0.18803712706068496}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:07,543] Trial 34 finished with value: 0.95 and parameters: {'n_estimators': 457, 'max_depth': 17, 'learning_rate': 0.05001056461681491}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:07,642] Trial 35 finished with value: 0.95 and parameters: {'n_estimators': 87, 'max_depth': 19, 'learning_rate': 0.0345174856671471}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:07,762] Trial 36 finished with value: 0.95 and parameters: {'n_estimators': 243, 'max_depth': 9, 'learning_rate': 0.08989230462747123}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:07,914] Trial 37 finished with value: 0.95 and parameters: {'n_estimators': 387, 'max_depth': 2, 'learning_rate': 0.16500670269560627}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:08,030] Trial 38 finished with value: 0.95 and parameters: {'n_estimators': 149, 'max_depth': 7, 'learning_rate': 0.021251253575327502}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:08,169] Trial 39 finished with value: 0.95 and parameters: {'n_estimators': 288, 'max_depth': 12, 'learning_rate': 0.016069327833489425}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:08,275] Trial 40 finished with value: 0.95 and parameters: {'n_estimators': 185, 'max_depth': 15, 'learning_rate': 0.29337488648167737}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:08,430] Trial 41 finished with value: 0.95 and parameters: {'n_estimators': 440, 'max_depth': 16, 'learning_rate': 0.026066683653846654}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:08,596] Trial 42 finished with value: 0.95 and parameters: {'n_estimators': 406, 'max_depth': 19, 'learning_rate': 0.019293280741769708}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:08,755] Trial 43 finished with value: 0.95 and parameters: {'n_estimators': 461, 'max_depth': 20, 'learning_rate': 0.03137787634611692}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:08,907] Trial 44 finished with value: 0.95 and parameters: {'n_estimators': 347, 'max_depth': 14, 'learning_rate': 0.012145293322007372}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:09,049] Trial 45 finished with value: 0.95 and parameters: {'n_estimators': 315, 'max_depth': 18, 'learning_rate': 0.04188326887119692}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:09,146] Trial 46 finished with value: 0.95 and parameters: {'n_estimators': 71, 'max_depth': 10, 'learning_rate': 0.022303522975051854}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:09,242] Trial 47 finished with value: 0.95 and parameters: {'n_estimators': 116, 'max_depth': 13, 'learning_rate': 0.016044829537516663}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:09,352] Trial 48 finished with value: 0.95 and parameters: {'n_estimators': 144, 'max_depth': 17, 'learning_rate': 0.06079901200676223}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3920293438.py:231: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-18 17:05:09,508] Trial 49 finished with value: 0.95 and parameters: {'n_estimators': 367, 'max_depth': 20, 'learning_rate': 0.03683676375881938}. Best is trial 0 with value: 0.95.
#  Itérations en cours: 100%|██████████| 2/2 [00:13<00:00,  6.63s/it]
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 270, 'max_depth': 20, 'learning_rate': 0.02738760482297254}
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy: 0.95
#    - F1-score: 0.9503836317135551
# 🔍 [DEBUG] Début de la collecte des résultats pour l'itération 2...
#  Erreur lors de l'enregistrement des résultats : name 'json' is not defined
# ✅ [DEBUG] Résultats collectés pour l'itération 2:
# {
#     "Itération": 2,
#     "Dataset utilisé": "data/dataP/preprocessed_iris_dataset.csv",
#     "Colonne cible": "species",
#     "Échantillonnage": "Oui (DDBS - euclidean, geometric)",
#     "Tps Sampling": 0.01,
#     "Entrain %": 15.0,
#     "Nbre Entrain": 15,
#     "Test %": 20.0,
#     "Nbre Test": 20,
#     "Sampling DDBS": {
#         "distance_metric": "euclidean",
#         "distribution_type": "geometric",
#         "percentage_per_class": 0.2,
#         "total_selected_samples": 15
#     },
#     "Modèle": "XGBoost",
#     "Paramètres initiaux": {
#         "objective": "binary:logistic",
#         "base_score": null,
#         "booster": null,
#         "callbacks": null,
#         "colsample_bylevel": null,
#         "colsample_bynode": null,
#         "colsample_bytree": null,
#         "device": null,
#         "early_stopping_rounds": null,
#         "enable_categorical": false,
#         "eval_metric": null,
#         "feature_types": null,
#         "gamma": null,
#         "grow_policy": null,
#         "importance_type": null,
#         "interaction_constraints": null,
#         "learning_rate": 0.1,
#         "max_bin": null,
#         "max_cat_threshold": null,
#         "max_cat_to_onehot": null,
#         "max_delta_step": null,
#         "max_depth": 6,
#         "max_leaves": null,
#         "min_child_weight": null,
#         "missing": NaN,
#         "monotone_constraints": null,
#         "multi_strategy": null,
#         "n_estimators": 100,
#         "n_jobs": null,
#         "num_parallel_tree": null,
#         "random_state": null,
#         "reg_alpha": null,
#         "reg_lambda": null,
#         "sampling_method": null,
#         "scale_pos_weight": null,
#         "subsample": null,
#         "tree_method": null,
#         "validate_parameters": null,
#         "verbosity": null
#     },
#     "Tps Entrain Avant": 0.04,
#     "Accuracy Avant": 0.95,
#     "F1-score Avant": 0.9503836317135551,
#     "Tps Entrain Après": 0.1,
#     "Paramètres optimisés": {
#         "n_estimators": 270,
#         "max_depth": 20,
#         "learning_rate": 0.02738760482297254
#     },
#     "Accuracy Après": 0.95,
#     "F1-score Après": 0.9503836317135551
# }
# 💾 [DEBUG] Enregistrement des résultats dans results_log.txt...
# Résultats enregistrés dans results_log.txt
# ✅ [DEBUG] Résultats enregistrés avec succès !
#
#  Les nouveaux résultats sont disponible

# %%
import numpy as np
import pandas as pd
import json
import optuna
import pickle
import os
import time
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier

# Import collection des resultat
from resultat.collect_results import collect_results

# Import sécurisé de gmm_sampling
try:
    from sampling.gmm_sampling import gmm_sampling
except ModuleNotFoundError:
    raise ImportError(" Impossible d'importer gmm_sampling. Vérifiez le chemin du fichier.")

# Import sécurisé de ddbs_sampling
try:
    from sampling.ddbs_sampling import diversified_distance_based_sampling
except ModuleNotFoundError:
    raise ImportError("Impossible d'importer ddbs_sampling. Vérifiez le chemin du fichier.")


# Charger la configuration depuis config.json
with open("config.json", "r") as config_file:
    config = json.load(config_file)

file_path = config["file_path"]
model_save_path = config["model_save_path"]
num_iterations = config.get("num_iterations", 2)  #  Nombre d'itérations

# Charger le dataset CSV avec gestion des erreurs
df = pd.read_csv(file_path)
print(" Données chargées avec succès.")

# Définition de la colonne cible
target_column = config["target_column"]
if target_column not in df.columns:
    raise ValueError(f" La colonne cible '{target_column}' est absente des données.")

print(f" Colonne cible définie : {target_column}")

# Initialisation du DataFrame pour stocker les résultats
columns = [
    "Itération", "Échantillonnage","Tps Sampling","Entrain %", "Nbre Entrain", "Test %", "Nbre Test", "Modèle", "Paramètres Initiaux",
    "Tps Entrain Avant", "Accuracy Avant","F1-score Avant", "Tps Entrain Après", "Paramètres Optimisés", "Accuracy Après", "F1-score Après"    
]
results_df = pd.DataFrame(columns=columns)



#  Définition du fichier log pour les résultats
log_file = "results_log.txt"

def save_results(iteration_results):
    """
    Ajoute les résultats d'une itération dans `results_log.txt`
    sans recréer le fichier à chaque fois.
    """
    try:
        if not os.path.exists(log_file):
            with open(log_file, "w", encoding="utf-8") as f:
                f.write("Log des résultats\n\n")

        with open(log_file, "a", encoding="utf-8") as f:
            f.write(json.dumps(iteration_results, indent=4, ensure_ascii=False) + "\n\n")

        print(f"Résultats enregistrés dans {log_file}")

    except Exception as e:
        print(f" Erreur lors de l'enregistrement des résultats : {e}")



# Exécuter 30 itérations

for iteration in tqdm(range(1, num_iterations  + 1), desc=" Itérations en cours"):
    print(f"\n Exécution de l'itération {iteration}...\n")

     # Séparation des données en Train/Test avant sampling
    test_size = config["train_test_split"]["test_size"]
    X = df.drop(columns=[target_column])
    y = df[target_column]

    # Division des données
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    
    #  Appliquer le sampling UNIQUEMENT sur les données d'entraînement
    start_sampling_time = time.time()
    
    # Appliquer le sampling si activé
    if config["sampling"]["enabled"]:
        # Si le sampling type est GMM, appliquer le sampling GMM
        if config["sampling"]["gmm"]["enabled"]:
            df_train_sampled = gmm_sampling(pd.concat([X_train, y_train], axis=1), target_column, config)
            X_train_sampled = df_train_sampled.drop(columns=[target_column])
            y_train_sampled = df_train_sampled[target_column]
            sampling_status = "Oui (GMM)"
            print("Échantillonnage GMM appliqué")
        
        # Si le sampling type est Random, utiliser Pandas sample()
        elif config["sampling"]["random"]["enabled"]:
            fraction = config["sampling"]["fraction"]
            sampled_indices = X_train.sample(frac=fraction).index
            X_train_sampled, y_train_sampled = X_train.loc[sampled_indices], y_train.loc[sampled_indices]
            sampling_status = "Oui (Random)"
            print(f" Échantillonnage aléatoire activé : {fraction*100:.1f}% des données utilisées.")
        
        # Si le sampling type est ddbs, utiliser Pandas sample()    
        elif config["sampling"]["ddbs"]["enabled"]:
            df_train_sampled = diversified_distance_based_sampling(pd.concat([X_train, y_train], axis=1), target_column, config)
            X_train_sampled = df_train_sampled.drop(columns=[target_column])
            y_train_sampled = df_train_sampled[target_column]
            sampling_status = f"Oui (DDBS - {config['sampling']['ddbs']['distance_metric']}, {config['sampling']['ddbs']['distribution_type']})"
            print("Échantillonnage DDBS appliqué.")
        
        # Si le type est inconnu, lever une erreur
        else:
            raise ValueError(f" Type d'échantillonnage inconnu : '{sampling_type}'")

    else:
        # Si le sampling est désactivé, utiliser le dataset original
        X_train_sampled, y_train_sampled = X_train, y_train
        sampling_status = "Non"
        print(" Aucun échantillonnage appliqué, utilisation des données complètes.")

    # Sélectionner les bonnes données d'entraînement (avec ou sans échantillonnage)
    X_train_used, y_train_used = (X_train_sampled, y_train_sampled) if config["sampling"]["enabled"] else (X_train, y_train)

    # Calcul du temps pris pour le sampling
    sampling_time = round(time.time() - start_sampling_time , 2) # Calcul du temps pris par le sampling
    print(f"\n Temps samping  : {sampling_time}.")
    
    #  Mise à jour du nombre d'échantillons après sampling
    num_train_used  = len(X_train_used)
    num_test_used  = len(X_test) # Le test set reste inchangé

    print(f"\nDonnées après échantillonnage (Train) : {num_train_used } échantillons.")
    print(f"Données de test non modifiées : {num_test_used } échantillons.")
    
    # Calcul du pourcentage des données après échantillonnage
    train_percent = (num_train_used / len(df)) * 100
    test_percent = (num_test_used / len(df)) * 100
    
    print(f"\n Pourcentage Entraînement : {train_percent:.2f}%")
    print(f" Pourcentage Test : {test_percent:.2f}%")



    # Initialiser les modèles
    models = {}
    for model_name, model_params in config["models"].items():
        if model_params["enabled"]:
            if model_name == "Decision Tree":
                models[model_name] = DecisionTreeClassifier(max_depth=model_params["max_depth"])
            elif model_name == "Random Forest":
                models[model_name] = RandomForestClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"]
                )
            elif model_name == "SVM":
                models[model_name] = SVC(C=model_params["C"], kernel=model_params["kernel"])
            elif model_name == "Neural Network":
                models[model_name] = MLPClassifier(
                    hidden_layer_sizes=tuple(model_params["hidden_layer_sizes"]),
                    learning_rate_init=model_params["learning_rate_init"],
                    max_iter=500
                )
            elif model_name == "XGBoost":
                models[model_name] = XGBClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"],
                    learning_rate=model_params["learning_rate"]    
                )

    # Entraînement et évaluation des modèles
    for model_name, model in models.items():

        # Entraînement du modèle avec les bonnes données
        start_train_time = time.time()  # Début du chronométrage de l'entraînement avant optimisation
        model.fit(X_train_used, y_train_used)
        train_time_before = round(time.time() - start_train_time , 2)  # Temps pris pour l'entraînement avant optimisation

        #  Calcul des scores sur TRAIN
        y_train_pred = model.predict(X_train)
        train_accuracy = accuracy_score(y_train, y_train_pred)
        train_f1 = f1_score(y_train, y_train_pred, average="weighted")

        #  Calcul des scores sur TEST
        y_pred = model.predict(X_test)
        accuracy_before = accuracy_score(y_test, y_pred)
        f1_before = f1_score(y_test, y_pred, average="weighted")
        
        print(f"\n Résultats du modèle '{model_name}' avant optimisation :")
        print(f"   - Accuracy Train: {train_accuracy:.4f}")
        print(f"   - Accuracy Test: {accuracy_before:.4f}")
        print(f"   - F1-score Train: {train_f1:.4f}")
        print(f"   - F1-score Test: {f1_before:.4f}")

        #  Vérification de l'overfitting / underfitting
        if train_accuracy > accuracy_before + 0.10:
            print(" Overfitting détecté !")
        elif train_accuracy < 0.7 and accuracy_before < 0.7:
            print(" Underfitting détecté !")
        else:
            print(" Bon équilibre entre biais et variance.")

        best_params = {}
        best_model = model
        accuracy_after, f1_after = "Non optimisé", "Non optimisé"

        # Optimisation avec Optuna
        if config["use_optuna"]:
            def objective(trial):
                if model_name == "Decision Tree":
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = DecisionTreeClassifier(max_depth=max_depth)
                elif model_name == "Random Forest":
                    n_estimators = trial.suggest_int("n_estimators", 10, 200)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
                elif model_name == "SVM":
                    C = trial.suggest_loguniform("C", 0.1, 10)
                    kernel = trial.suggest_categorical("kernel", ["linear", "rbf", "poly"])
                    model_opt = SVC(C=C, kernel=kernel)
                elif model_name == "Neural Network":
                    hidden_layer_sizes = trial.suggest_categorical("hidden_layer_sizes", [(50,), (100,), (50, 50)])
                    learning_rate_init = trial.suggest_loguniform("learning_rate_init", 0.0001, 0.1)
                    model_opt = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, learning_rate_init=learning_rate_init, max_iter=500)
                elif model_name == "XGBoost":
                    n_estimators = trial.suggest_int("n_estimators", 50, 500)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
                    model_opt = XGBClassifier(n_estimators=n_estimators, max_depth=max_depth, learning_rate=learning_rate)

                
                model_opt.fit(X_train_used, y_train_used)
                y_pred_opt = model_opt.predict(X_test)
                return accuracy_score(y_test, y_pred_opt)

            study = optuna.create_study(direction="maximize")
            study.optimize(objective, n_trials=config["n_trials"])

            best_params = study.best_trial.params
            print(f"\n Meilleurs paramètres trouvés pour '{model_name}' : {best_params}")

            # Réentraînement avec les meilleurs paramètres
            if config["retrain_with_best_params"]:
                start_train_time_after = time.time()  # Début du chronométrage de l'entraînement après optimisation
                best_model = model.__class__(**best_params)
                best_model.fit(X_train_used, y_train_used)
                train_time_after = round(time.time() - start_train_time_after, 2) # Temps pris pour l'entraînement après optimisation

                # #  Calcul des scores sur TRAIN apres optimisation 
                y_train_pred_opt = best_model.predict(X_train)
                train_accuracy_after = accuracy_score(y_train, y_train_pred_opt)
                train_f1_after = f1_score(y_train, y_train_pred_opt, average="weighted")
                
                #  Calcul des scores sur TEST apres optimisation 
                y_pred_opt = best_model.predict(X_test)
                accuracy_after = accuracy_score(y_test, y_pred_opt)
                f1_after = f1_score(y_test, y_pred_opt, average="weighted")

            print(f"\n Modèle après optimisation ({model_name}):")
            print(f"   - Accuracy Train: {train_accuracy_after:.4f}")
            print(f"   - Accuracy Test: {accuracy_after:.4f}")
            print(f"   - F1-score Train: {train_f1_after:.4f}")
            print(f"   - F1-score Test: {f1_after:.4f}")

            #  Vérification de l'overfitting / underfitting après optimisation
            if train_accuracy_after > accuracy_after + 0.10:
                print(" Overfitting détecté après optimisation !")
            elif train_accuracy_after < 0.7 and accuracy_after < 0.7:
                print(" Underfitting détecté après optimisation !")
            else:
                print(" Bon équilibre entre biais et variance après optimisation.")
                               

            # Sauvegarde du meilleur modèle
            if config["save_best_model"]:
                model_filename = f"best_model_{model_name}.pkl"
                with open(model_filename, "wb") as f:
                    pickle.dump(best_model, f)
                print(f" Modèle '{model_name}' sauvegardé sous '{model_filename}'.")

        # Stockage des résultats
        results_df = pd.concat([results_df, pd.DataFrame([{
            "Itération": iteration,
            "Échantillonnage": sampling_status,
            "Tps Sampling": sampling_time,
            "Entrain %": train_percent,
            "Nbre Entrain": num_train_used,
            "Test %": test_percent,
            "Nbre Test": num_test_used,
            "Modèle": model_name,
            "Paramètres Initiaux": {param: value for param, value in model.get_params().items() if param in model_params},
            "Tps Entrain Avant": train_time_before,
            "Accuracy Avant": accuracy_before,
            "F1-score Avant": f1_before,
            "Tps Entrain Après": train_time_after,
            "Paramètres Optimisés": best_params,
            "Accuracy Après": accuracy_after,
            "F1-score Après": f1_after
        }])], ignore_index=True)
        
        

        # 📌 Vérification si on est bien entré dans la collecte des résultats
        print(f" [DEBUG] Début de la collecte des résultats pour l'itération {iteration}...")
        
        #  Enregistrement des résultats dans results_log.txt avec collect_results
        iteration_results =collect_results(
            iteration, config, file_path, target_column, sampling_status, sampling_time,
            train_percent, num_train_sampled, test_percent, num_test_sampled,
            model_name, model, model.get_params(), train_time_before,
            accuracy_before, f1_before, train_time_after, best_params,
            accuracy_after, f1_after
        )

        
        #  Vérification si collect_results() a retourné un dictionnaire valide
        print(f" [DEBUG] Résultats collectés pour l'itération {iteration}:")
        print(json.dumps(iteration_results, indent=4, ensure_ascii=False))
        
        #  Enregistrement des résultats
        print(f" [DEBUG] Enregistrement des résultats dans results_log.txt...")
        save_results(iteration_results)
        print(f" [DEBUG] Résultats enregistrés avec succès !")



# Sauvegarde des résultats
# Définition du chemin du fichier Excel
excel_path = f"resultats_{model_name}_{sampling_status}_{os.path.basename(file_path).split('.')[0]}.xlsx"

# Vérifier si le fichier existe
if os.path.exists(excel_path):
    # Ajouter les nouveaux résultats sans charger les anciens
    with pd.ExcelWriter(excel_path, mode='a', if_sheet_exists='overlay') as writer:
        results_df.to_excel(writer, index=False, header=False, startrow=writer.sheets['Sheet1'].max_row)
else:
    # Si le fichier n'existe pas, on crée un nouveau fichier avec les nouveaux résultats
    results_df.to_excel(excel_path, index=False)

print("\n Les nouveaux résultats sont disponible")

# Réinitialisation du DataFrame après la sauvegarde (conserve les colonnes, supprime les lignes)
results_df.drop(results_df.index, inplace=True)
# Out:
#  Données chargées avec succès.
#  Colonne cible définie : species
#  Itérations en cours:   0%|          | 0/2 [00:00<?, ?it/s][I 2025-03-20 11:36:06,809] A new study created in memory with name: no-name-54d71ada-b583-4184-9b14-16a934e50b60
#  Exécution de l'itération 1...
#
# Échantillonnage DDBS appliqué.
#
#  Temps samping  : 0.03.
#
# Données après échantillonnage (Train) : 16 échantillons.
# Données de test non modifiées : 20 échantillons.
#
#  Pourcentage Entraînement : 16.00%
#  Pourcentage Test : 20.00%
#
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy Train: 0.9750
#    - Accuracy Test: 0.9500
#    - F1-score Train: 0.9750
#    - F1-score Test: 0.9499
#  Bon équilibre entre biais et variance.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:06,932] Trial 0 finished with value: 0.95 and parameters: {'n_estimators': 395, 'max_depth': 9, 'learning_rate': 0.0918265535647125}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:07,011] Trial 1 finished with value: 0.95 and parameters: {'n_estimators': 127, 'max_depth': 13, 'learning_rate': 0.038784218010050234}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:07,107] Trial 2 finished with value: 0.95 and parameters: {'n_estimators': 314, 'max_depth': 11, 'learning_rate': 0.026884669394473436}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:07,187] Trial 3 finished with value: 0.95 and parameters: {'n_estimators': 202, 'max_depth': 7, 'learning_rate': 0.06875070951947992}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:07,264] Trial 4 finished with value: 0.95 and parameters: {'n_estimators': 197, 'max_depth': 17, 'learning_rate': 0.05101503245988299}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:07,410] Trial 5 finished with value: 0.95 and parameters: {'n_estimators': 493, 'max_depth': 16, 'learning_rate': 0.01912894656493003}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:07,517] Trial 6 finished with value: 0.95 and parameters: {'n_estimators': 349, 'max_depth': 17, 'learning_rate': 0.014295038751004255}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:07,609] Trial 7 finished with value: 0.95 and parameters: {'n_estimators': 247, 'max_depth': 14, 'learning_rate': 0.015801941517455915}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:07,692] Trial 8 finished with value: 0.95 and parameters: {'n_estimators': 328, 'max_depth': 19, 'learning_rate': 0.12565083701486585}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:07,773] Trial 9 finished with value: 0.95 and parameters: {'n_estimators': 227, 'max_depth': 4, 'learning_rate': 0.012416303167018528}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:07,921] Trial 10 finished with value: 0.95 and parameters: {'n_estimators': 447, 'max_depth': 9, 'learning_rate': 0.18749639476288216}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:07,990] Trial 11 finished with value: 0.95 and parameters: {'n_estimators': 65, 'max_depth': 12, 'learning_rate': 0.05527960954054569}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:08,067] Trial 12 finished with value: 0.95 and parameters: {'n_estimators': 107, 'max_depth': 6, 'learning_rate': 0.09964216082306641}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:08,199] Trial 13 finished with value: 0.95 and parameters: {'n_estimators': 382, 'max_depth': 2, 'learning_rate': 0.2997912954452028}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:08,294] Trial 14 finished with value: 0.95 and parameters: {'n_estimators': 156, 'max_depth': 10, 'learning_rate': 0.032315446794898374}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:08,424] Trial 15 finished with value: 0.95 and parameters: {'n_estimators': 423, 'max_depth': 13, 'learning_rate': 0.04160709825168613}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:08,491] Trial 16 finished with value: 0.95 and parameters: {'n_estimators': 54, 'max_depth': 8, 'learning_rate': 0.07815654360506157}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:08,609] Trial 17 finished with value: 0.95 and parameters: {'n_estimators': 277, 'max_depth': 14, 'learning_rate': 0.15436472775553112}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:08,747] Trial 18 finished with value: 0.95 and parameters: {'n_estimators': 159, 'max_depth': 5, 'learning_rate': 0.023805839963075594}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:09,283] Trial 19 finished with value: 0.95 and parameters: {'n_estimators': 404, 'max_depth': 10, 'learning_rate': 0.04188732319332805}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:09,566] Trial 20 finished with value: 0.95 and parameters: {'n_estimators': 292, 'max_depth': 20, 'learning_rate': 0.2261491062113805}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:09,858] Trial 21 finished with value: 0.95 and parameters: {'n_estimators': 325, 'max_depth': 12, 'learning_rate': 0.028201529543355943}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:10,119] Trial 22 finished with value: 0.95 and parameters: {'n_estimators': 353, 'max_depth': 11, 'learning_rate': 0.09103128971151238}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:10,383] Trial 23 finished with value: 0.95 and parameters: {'n_estimators': 476, 'max_depth': 15, 'learning_rate': 0.034915064804326004}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:10,568] Trial 24 finished with value: 0.95 and parameters: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.020347919645737112}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:10,778] Trial 25 finished with value: 0.95 and parameters: {'n_estimators': 388, 'max_depth': 11, 'learning_rate': 0.010534129315208408}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:10,889] Trial 26 finished with value: 0.95 and parameters: {'n_estimators': 117, 'max_depth': 9, 'learning_rate': 0.06426544877893822}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:11,034] Trial 27 finished with value: 0.95 and parameters: {'n_estimators': 255, 'max_depth': 13, 'learning_rate': 0.1177192779903631}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:11,245] Trial 28 finished with value: 0.95 and parameters: {'n_estimators': 445, 'max_depth': 10, 'learning_rate': 0.04492613451750615}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:11,402] Trial 29 finished with value: 0.95 and parameters: {'n_estimators': 362, 'max_depth': 7, 'learning_rate': 0.0677517581959567}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:11,538] Trial 30 finished with value: 0.95 and parameters: {'n_estimators': 208, 'max_depth': 12, 'learning_rate': 0.026156859873571896}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:11,632] Trial 31 finished with value: 0.95 and parameters: {'n_estimators': 167, 'max_depth': 7, 'learning_rate': 0.053735904255055714}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:11,724] Trial 32 finished with value: 0.95 and parameters: {'n_estimators': 117, 'max_depth': 3, 'learning_rate': 0.07612566345543315}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:11,842] Trial 33 finished with value: 0.95 and parameters: {'n_estimators': 194, 'max_depth': 16, 'learning_rate': 0.034703042837671005}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:11,948] Trial 34 finished with value: 0.95 and parameters: {'n_estimators': 191, 'max_depth': 6, 'learning_rate': 0.01885839996137051}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:12,068] Trial 35 finished with value: 0.95 and parameters: {'n_estimators': 239, 'max_depth': 9, 'learning_rate': 0.05435441217193601}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:12,181] Trial 36 finished with value: 0.95 and parameters: {'n_estimators': 88, 'max_depth': 8, 'learning_rate': 0.10076256020342386}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:12,386] Trial 37 finished with value: 0.95 and parameters: {'n_estimators': 315, 'max_depth': 18, 'learning_rate': 0.15466258506364328}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:12,518] Trial 38 finished with value: 0.95 and parameters: {'n_estimators': 218, 'max_depth': 14, 'learning_rate': 0.04579310820896536}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:12,611] Trial 39 finished with value: 0.95 and parameters: {'n_estimators': 139, 'max_depth': 6, 'learning_rate': 0.06591570298088925}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:12,751] Trial 40 finished with value: 0.95 and parameters: {'n_estimators': 265, 'max_depth': 4, 'learning_rate': 0.015639805186858754}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:12,878] Trial 41 finished with value: 0.95 and parameters: {'n_estimators': 181, 'max_depth': 16, 'learning_rate': 0.03091529706408273}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:13,046] Trial 42 finished with value: 0.95 and parameters: {'n_estimators': 238, 'max_depth': 18, 'learning_rate': 0.0864419012691656}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:13,165] Trial 43 finished with value: 0.95 and parameters: {'n_estimators': 148, 'max_depth': 17, 'learning_rate': 0.050431495308128974}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:13,269] Trial 44 finished with value: 0.95 and parameters: {'n_estimators': 75, 'max_depth': 11, 'learning_rate': 0.039062573917535315}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:13,381] Trial 45 finished with value: 0.95 and parameters: {'n_estimators': 132, 'max_depth': 15, 'learning_rate': 0.11663303194230379}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:13,549] Trial 46 finished with value: 0.95 and parameters: {'n_estimators': 494, 'max_depth': 13, 'learning_rate': 0.022345167757514144}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:13,684] Trial 47 finished with value: 0.95 and parameters: {'n_estimators': 282, 'max_depth': 20, 'learning_rate': 0.06263716211170912}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:13,840] Trial 48 finished with value: 0.95 and parameters: {'n_estimators': 337, 'max_depth': 9, 'learning_rate': 0.03787007915344814}. Best is trial 0 with value: 0.95.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:13,938] Trial 49 finished with value: 0.95 and parameters: {'n_estimators': 92, 'max_depth': 10, 'learning_rate': 0.14136597435395837}. Best is trial 0 with value: 0.95.
#  Itérations en cours:  50%|█████     | 1/2 [00:07<00:07,  7.44s/it]
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 395, 'max_depth': 9, 'learning_rate': 0.0918265535647125}
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy Train: 0.9750
#    - Accuracy Test: 0.9500
#    - F1-score Train: 0.9750
#    - F1-score Test: 0.9499
#  Bon équilibre entre biais et variance après optimisation.
#  [DEBUG] Début de la collecte des résultats pour l'itération 1...
#  Erreur lors de l'enregistrement des résultats : name 'json' is not defined
#  [DEBUG] Résultats collectés pour l'itération 1:
# {
#     "Itération": 1,
#     "Dataset utilisé": "data/dataP/preprocessed_iris_dataset.csv",
#     "Colonne cible": "species",
#     "Échantillonnage": "Oui (DDBS - euclidean, geometric)",
#     "Tps Sampling": 0.03,
#     "Entrain %": 16.0,
#     "Nbre Entrain": 15,
#     "Test %": 20.0,
#     "Nbre Test": 20,
#     "Sampling DDBS": {
#         "distance_metric": "euclidean",
#         "distribution_type": "geometric",
#         "percentage_per_class": 0.2,
#         "total_selected_samples": 15
#     },
#     "Modèle": "XGBoost",
#     "Paramètres initiaux": {
#         "objective": "binary:logistic",
#         "base_score": null,
#         "booster": null,
#         "callbacks": null,
#         "colsample_bylevel": null,
#         "colsample_bynode": null,
#         "colsample_bytree": null,
#         "device": null,
#         "early_stopping_rounds": null,
#         "enable_categorical": false,
#         "eval_metric": null,
#         "feature_types": null,
#         "gamma": null,
#         "grow_policy": null,
#         "importance_type": null,
#         "interaction_constraints": null,
#         "learning_rate": 0.1,
#         "max_bin": null,
#         "max_cat_threshold": null,
#         "max_cat_to_onehot": null,
#         "max_delta_step": null,
#         "max_depth": 6,
#         "max_leaves": null,
#         "min_child_weight": null,
#         "missing": NaN,
#         "monotone_constraints": null,
#         "multi_strategy": null,
#         "n_estimators": 100,
#         "n_jobs": null,
#         "num_parallel_tree": null,
#         "random_state": null,
#         "reg_alpha": null,
#         "reg_lambda": null,
#         "sampling_method": null,
#         "scale_pos_weight": null,
#         "subsample": null,
#         "tree_method": null,
#         "validate_parameters": null,
#         "verbosity": null
#     },
#     "Tps Entrain Avant": 0.09,
#     "Accuracy Avant": 0.95,
#     "F1-score Avant": 0.949874686716792,
#     "Tps Entrain Après": 0.11,
#     "Paramètres optimisés": {
#         "n_estimators": 395,
#         "max_depth": 9,
#         "learning_rate": 0.0918265535647125
#     },
#     "Accuracy Après": 0.95,
#     "F1-score Après": 0.949874686716792
# }
#  [DEBUG] Enregistrement des résultats dans results_log.txt...
# Résultats enregistrés dans results_log.txt
#  [DEBUG] Résultats enregistrés avec succès !
#
#  Exécution de l'itération 2...
#
# Échantillonnage DDBS appliqué.
#
#  Temps samping  : 0.01.
#
# Données après échantillonnage (Train) : 15 échantillons.
# Données de test non modifiées : 20 échantillons.
#
#  Pourcentage Entraînement : 15.00%
#  Pourcentage Test : 20.00%
# [I 2025-03-20 11:36:14,169] A new study created in memory with name: no-name-90c3dea9-1a13-4c5e-887b-2fc7cbf9838c
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:14,278] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 494, 'max_depth': 10, 'learning_rate': 0.031203742369498855}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:14,344] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 258, 'max_depth': 17, 'learning_rate': 0.01153665222968155}. Best is trial 0 with value: 1.0.
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy Train: 1.0000
#    - Accuracy Test: 1.0000
#    - F1-score Train: 1.0000
#    - F1-score Test: 1.0000
#  Bon équilibre entre biais et variance.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:14,418] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 265, 'max_depth': 17, 'learning_rate': 0.11026968011860232}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:14,513] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 366, 'max_depth': 6, 'learning_rate': 0.07175892570067877}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:14,612] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 387, 'max_depth': 15, 'learning_rate': 0.1143168883049908}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:14,679] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 221, 'max_depth': 14, 'learning_rate': 0.020852467495887966}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:14,737] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 81, 'max_depth': 7, 'learning_rate': 0.021472652015953733}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:14,788] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 84, 'max_depth': 17, 'learning_rate': 0.031112335094717936}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:14,828] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 54, 'max_depth': 20, 'learning_rate': 0.019791486049641236}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:14,914] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 249, 'max_depth': 14, 'learning_rate': 0.01525474978038928}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:15,079] Trial 10 finished with value: 1.0 and parameters: {'n_estimators': 479, 'max_depth': 2, 'learning_rate': 0.23586014482879333}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:15,196] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 177, 'max_depth': 10, 'learning_rate': 0.010382398518091073}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:15,326] Trial 12 finished with value: 1.0 and parameters: {'n_estimators': 349, 'max_depth': 10, 'learning_rate': 0.03848467091838901}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:15,469] Trial 13 finished with value: 1.0 and parameters: {'n_estimators': 472, 'max_depth': 12, 'learning_rate': 0.012285127771158573}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:15,565] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 158, 'max_depth': 20, 'learning_rate': 0.03656162316771447}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:15,679] Trial 15 finished with value: 1.0 and parameters: {'n_estimators': 334, 'max_depth': 7, 'learning_rate': 0.06640250259132845}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:15,810] Trial 16 finished with value: 1.0 and parameters: {'n_estimators': 420, 'max_depth': 4, 'learning_rate': 0.04293222234520578}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:15,950] Trial 17 finished with value: 1.0 and parameters: {'n_estimators': 320, 'max_depth': 12, 'learning_rate': 0.02484107767248729}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:16,120] Trial 18 finished with value: 1.0 and parameters: {'n_estimators': 432, 'max_depth': 9, 'learning_rate': 0.014953354332815631}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:16,243] Trial 19 finished with value: 1.0 and parameters: {'n_estimators': 300, 'max_depth': 17, 'learning_rate': 0.2748448609587975}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:16,327] Trial 20 finished with value: 1.0 and parameters: {'n_estimators': 160, 'max_depth': 12, 'learning_rate': 0.0559904587559488}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:16,428] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 273, 'max_depth': 17, 'learning_rate': 0.12375835367439986}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:16,546] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 234, 'max_depth': 19, 'learning_rate': 0.13276577297717973}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:16,658] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 286, 'max_depth': 18, 'learning_rate': 0.09356297133475351}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:16,755] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 198, 'max_depth': 15, 'learning_rate': 0.1661502479515345}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:16,836] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 127, 'max_depth': 14, 'learning_rate': 0.18304456559518353}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:16,956] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 269, 'max_depth': 16, 'learning_rate': 0.08793067319525867}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:17,085] Trial 27 finished with value: 1.0 and parameters: {'n_estimators': 410, 'max_depth': 9, 'learning_rate': 0.04896119343434458}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:17,201] Trial 28 finished with value: 1.0 and parameters: {'n_estimators': 208, 'max_depth': 18, 'learning_rate': 0.015650066442044083}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:17,345] Trial 29 finished with value: 1.0 and parameters: {'n_estimators': 361, 'max_depth': 13, 'learning_rate': 0.030944273411680503}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:17,469] Trial 30 finished with value: 1.0 and parameters: {'n_estimators': 301, 'max_depth': 6, 'learning_rate': 0.06933862188484835}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:17,592] Trial 31 finished with value: 1.0 and parameters: {'n_estimators': 383, 'max_depth': 5, 'learning_rate': 0.09066670820587329}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:17,751] Trial 32 finished with value: 1.0 and parameters: {'n_estimators': 449, 'max_depth': 2, 'learning_rate': 0.07045733620524113}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:17,916] Trial 33 finished with value: 1.0 and parameters: {'n_estimators': 499, 'max_depth': 7, 'learning_rate': 0.10579938412973647}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:18,094] Trial 34 finished with value: 1.0 and parameters: {'n_estimators': 379, 'max_depth': 4, 'learning_rate': 0.1525939486656124}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:18,229] Trial 35 finished with value: 1.0 and parameters: {'n_estimators': 320, 'max_depth': 8, 'learning_rate': 0.05820878413248444}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:18,359] Trial 36 finished with value: 1.0 and parameters: {'n_estimators': 246, 'max_depth': 15, 'learning_rate': 0.02664942111757982}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:18,494] Trial 37 finished with value: 1.0 and parameters: {'n_estimators': 262, 'max_depth': 10, 'learning_rate': 0.018591972020957297}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:18,614] Trial 38 finished with value: 1.0 and parameters: {'n_estimators': 225, 'max_depth': 16, 'learning_rate': 0.08141848880142333}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:18,745] Trial 39 finished with value: 1.0 and parameters: {'n_estimators': 395, 'max_depth': 11, 'learning_rate': 0.0469647674374261}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:18,903] Trial 40 finished with value: 1.0 and parameters: {'n_estimators': 447, 'max_depth': 13, 'learning_rate': 0.011244420118305702}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:19,073] Trial 41 finished with value: 1.0 and parameters: {'n_estimators': 363, 'max_depth': 19, 'learning_rate': 0.11220998593624956}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:19,240] Trial 42 finished with value: 1.0 and parameters: {'n_estimators': 469, 'max_depth': 15, 'learning_rate': 0.18482567254146415}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:19,367] Trial 43 finished with value: 1.0 and parameters: {'n_estimators': 340, 'max_depth': 16, 'learning_rate': 0.14048315990059299}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:19,590] Trial 44 finished with value: 1.0 and parameters: {'n_estimators': 493, 'max_depth': 18, 'learning_rate': 0.2151878677871364}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:19,709] Trial 45 finished with value: 1.0 and parameters: {'n_estimators': 303, 'max_depth': 20, 'learning_rate': 0.07839454100609786}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:19,898] Trial 46 finished with value: 1.0 and parameters: {'n_estimators': 251, 'max_depth': 14, 'learning_rate': 0.10476437531323106}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:20,042] Trial 47 finished with value: 1.0 and parameters: {'n_estimators': 408, 'max_depth': 3, 'learning_rate': 0.031885997594245916}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:20,216] Trial 48 finished with value: 1.0 and parameters: {'n_estimators': 325, 'max_depth': 6, 'learning_rate': 0.022783789718532375}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\555027471.py:242: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-20 11:36:20,381] Trial 49 finished with value: 1.0 and parameters: {'n_estimators': 441, 'max_depth': 11, 'learning_rate': 0.018227586911638703}. Best is trial 0 with value: 1.0.
#  Itérations en cours: 100%|██████████| 2/2 [00:13<00:00,  6.95s/it]
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 494, 'max_depth': 10, 'learning_rate': 0.031203742369498855}
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy Train: 1.0000
#    - Accuracy Test: 1.0000
#    - F1-score Train: 1.0000
#    - F1-score Test: 1.0000
#  Bon équilibre entre biais et variance après optimisation.
#  [DEBUG] Début de la collecte des résultats pour l'itération 2...
#  Erreur lors de l'enregistrement des résultats : name 'json' is not defined
#  [DEBUG] Résultats collectés pour l'itération 2:
# {
#     "Itération": 2,
#     "Dataset utilisé": "data/dataP/preprocessed_iris_dataset.csv",
#     "Colonne cible": "species",
#     "Échantillonnage": "Oui (DDBS - euclidean, geometric)",
#     "Tps Sampling": 0.01,
#     "Entrain %": 15.0,
#     "Nbre Entrain": 15,
#     "Test %": 20.0,
#     "Nbre Test": 20,
#     "Sampling DDBS": {
#         "distance_metric": "euclidean",
#         "distribution_type": "geometric",
#         "percentage_per_class": 0.2,
#         "total_selected_samples": 15
#     },
#     "Modèle": "XGBoost",
#     "Paramètres initiaux": {
#         "objective": "binary:logistic",
#         "base_score": null,
#         "booster": null,
#         "callbacks": null,
#         "colsample_bylevel": null,
#         "colsample_bynode": null,
#         "colsample_bytree": null,
#         "device": null,
#         "early_stopping_rounds": null,
#         "enable_categorical": false,
#         "eval_metric": null,
#         "feature_types": null,
#         "gamma": null,
#         "grow_policy": null,
#         "importance_type": null,
#         "interaction_constraints": null,
#         "learning_rate": 0.1,
#         "max_bin": null,
#         "max_cat_threshold": null,
#         "max_cat_to_onehot": null,
#         "max_delta_step": null,
#         "max_depth": 6,
#         "max_leaves": null,
#         "min_child_weight": null,
#         "missing": NaN,
#         "monotone_constraints": null,
#         "multi_strategy": null,
#         "n_estimators": 100,
#         "n_jobs": null,
#         "num_parallel_tree": null,
#         "random_state": null,
#         "reg_alpha": null,
#         "reg_lambda": null,
#         "sampling_method": null,
#         "scale_pos_weight": null,
#         "subsample": null,
#         "tree_method": null,
#         "validate_parameters": null,
#         "verbosity": null
#     },
#     "Tps Entrain Avant": 0.05,
#     "Accuracy Avant": 1.0,
#     "F1-score Avant": 1.0,
#     "Tps Entrain Après": 0.12,
#     "Paramètres optimisés": {
#         "n_estimators": 494,
#         "max_depth": 10,
#         "learning_rate": 0.031203742369498855
#     },
#     "Accuracy Après": 1.0,
#     "F1-score Après": 1.0
# }
#  [DEBUG] Enregistrement des résultats dans results_log.txt...
# Résultats enregistrés dans results_log.txt
#  [DEBUG] Résultats enregistrés avec succès !
#  Les nouveaux résultats sont disponible

# %%
import numpy as np
import pandas as pd
import json
import optuna
import pickle
import os
import time
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier

# Import collection des resultat
from resultat.collect_results import collect_results

# Import sécurisé de gmm_sampling
try:
    from sampling.gmm_sampling import gmm_sampling
except ModuleNotFoundError:
    raise ImportError(" Impossible d'importer gmm_sampling. Vérifiez le chemin du fichier.")

# Import sécurisé de ddbs_sampling
try:
    from sampling.ddbs_sampling import diversified_distance_based_sampling
except ModuleNotFoundError:
    raise ImportError("Impossible d'importer ddbs_sampling. Vérifiez le chemin du fichier.")


# Charger la configuration depuis config.json
with open("config.json", "r") as config_file:
    config = json.load(config_file)

file_path = config["file_path"]
model_save_path = config["model_save_path"]
num_iterations = config.get("num_iterations", 2)  #  Nombre d'itérations

# Charger le dataset CSV avec gestion des erreurs
df = pd.read_csv(file_path)
print(" Données chargées avec succès.")

# Définition de la colonne cible
target_column = config["target_column"]
if target_column not in df.columns:
    raise ValueError(f" La colonne cible '{target_column}' est absente des données.")

print(f" Colonne cible définie : {target_column}")


# Fonction de sauvegarde dans un fichier texte
log_file = None

def save_results(iteration_results, log_path):
    try:
        with open(log_path, "a", encoding="utf-8") as f:
            f.write(f"### Itération {iteration_results['Itération']} - {iteration_results['Modèle']} ###\n")
            f.write(json.dumps(iteration_results, indent=4, ensure_ascii=False))
            f.write("\n\n")
        print(f" Résultats enregistrés dans '{log_path}'")
    except Exception as e:
        print(f" Erreur lors de l'enregistrement : {e}")


# Boucle d'itérations

for iteration in tqdm(range(1, num_iterations  + 1), desc=" Itérations en cours"):
    print(f"\n Exécution de l'itération {iteration}...\n")

     # Séparation des données en Train/Test avant sampling
    test_size = config["train_test_split"]["test_size"]
    X = df.drop(columns=[target_column])
    y = df[target_column]

    # Division des données
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

    # CONSERVER les données SANS échantillonnage pour les comparer plus tard
    X_train_no_sampling, y_train_no_sampling = X_train.copy(), y_train.copy()
    
    #  Appliquer le sampling UNIQUEMENT sur les données d'entraînement
    start_sampling_time = time.time()
    
    # Appliquer le sampling si activé
    if config["sampling"]["enabled"]:
        # Si le sampling type est GMM, appliquer le sampling GMM
        if config["sampling"]["gmm"]["enabled"]:
            df_train_sampled = gmm_sampling(pd.concat([X_train, y_train], axis=1), target_column, config)
            X_train_sampled = df_train_sampled.drop(columns=[target_column])
            y_train_sampled = df_train_sampled[target_column]
            sampling_status = "Oui (GMM)"
            print("Échantillonnage GMM appliqué")
        
        # Si le sampling type est Random, utiliser Pandas sample()
        elif config["sampling"]["random"]["enabled"]:
            fraction = config["sampling"]["fraction"]
            sampled_indices = X_train.sample(frac=fraction).index
            X_train_sampled, y_train_sampled = X_train.loc[sampled_indices], y_train.loc[sampled_indices]
            sampling_status = "Oui (Random)"
            print(f" Échantillonnage aléatoire activé : {fraction*100:.1f}% des données utilisées.")
        
        # Si le sampling type est ddbs, utiliser Pandas sample()    
        elif config["sampling"]["ddbs"]["enabled"]:
            df_train_sampled = diversified_distance_based_sampling(pd.concat([X_train, y_train], axis=1), target_column, config)
            X_train_sampled = df_train_sampled.drop(columns=[target_column])
            y_train_sampled = df_train_sampled[target_column]
            sampling_status = f"Oui (DDBS - {config['sampling']['ddbs']['distance_metric']}, {config['sampling']['ddbs']['distribution_type']})"
            print("Échantillonnage DDBS appliqué.")
        
        # Si le type est inconnu, lever une erreur
        else:
            raise ValueError(f" Type d'échantillonnage inconnu : '{sampling_type}'")

    else:
        # Si le sampling est désactivé, utiliser le dataset original
        X_train_sampled, y_train_sampled = X_train, y_train
        sampling_status = "Non"
        print(" Aucun échantillonnage appliqué, utilisation des données complètes.")


   # Sélectionner les bonnes données d'entraînement (avec ou sans échantillonnage)
    X_train_used, y_train_used = (X_train_sampled, y_train_sampled) if config["sampling"]["enabled"] else (X_train, y_train)
    

    # Sélectionner les bonnes données d'entraînement 
    X_train_sampling, y_train_sampling = X_train_sampled, y_train_sampled  # AVEC sampling


    # Calcul du temps pris pour le sampling
    sampling_time = round(time.time() - start_sampling_time , 2) # Calcul du temps pris par le sampling
    print(f"\n Temps samping  : {sampling_time}.")
    
    #  Mise à jour du nombre d'échantillons après sampling
    num_train_used  = len(X_train_used)
    num_test_used  = len(X_test) # Le test set reste inchangé

    num_train_no_sampling = len(X_train_no_sampling)  # Taille des données sans échantillonnage


    print(f"\nDonnées après échantillonnage (Train) : {num_train_used } échantillons.")
    print(f"Données de test non modifiées : {num_test_used } échantillons.")
    
    print(f" Données sans échantillonnage (Train) : {num_train_no_sampling} échantillons.")
    
    # Calcul du pourcentage des données après échantillonnage
    train_percent = (num_train_used / len(df)) * 100
    test_percent = (num_test_used / len(df)) * 100

    train_percent_no_sampling = (num_train_no_sampling / len(df)) * 100

    
    print(f"\n Pourcentage Entraînement : {train_percent:.2f}%")
    print(f" Pourcentage Test : {test_percent:.2f}%")
    print(f" Pourcentage Entraînement (Sans Sampling) : {train_percent_no_sampling:.2f}%")



    # Initialiser les modèles
    models_no_sampling = {}  # Modèles entraînés SANS échantillonnage
    models_sampling = {}  # Modèles entraînés AVEC échantillonnage
    models = {}
    for model_name, model_params in config["models"].items():
        if model_params["enabled"]:
            if model_name == "Decision Tree":
                models[model_name] = DecisionTreeClassifier(max_depth=model_params["max_depth"])
            elif model_name == "Random Forest":
                models[model_name] = RandomForestClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"]
                )
            elif model_name == "SVM":
                models[model_name] = SVC(C=model_params["C"], kernel=model_params["kernel"])
            elif model_name == "Neural Network":
                models[model_name] = MLPClassifier(
                    hidden_layer_sizes=tuple(model_params["hidden_layer_sizes"]),
                    learning_rate_init=model_params["learning_rate_init"],
                    max_iter=500
                )
            elif model_name == "XGBoost":
                models[model_name] = XGBClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"],
                    learning_rate=model_params["learning_rate"]    
                )

    # Entraînement et évaluation des modèles
    for model_name, model in models.items():

        # Entraînement du modèle avec les bonnes données
        start_train_time = time.time()  # Début du chronométrage de l'entraînement avant optimisation
        model.fit(X_train_used, y_train_used)
        train_time_before = round(time.time() - start_train_time , 2)  # Temps pris pour l'entraînement avant optimisation

        # Entraînement du modèle SANS échantillonnage
        model.fit(X_train_no_sampling, y_train_no_sampling)
        y_pred_no_sampling = model.predict(X_test)
        

        #  Entraînement du modèle AVEC échantillonnage
        model.fit(X_train_sampling, y_train_sampling)
        y_pred_sampling = model.predict(X_test)


        #  Comparaison des scores avant optimisation
        accuracy_no_sampling = accuracy_score(y_test, y_pred_no_sampling)
        f1_no_sampling = f1_score(y_test, y_pred_no_sampling, average="weighted")

        accuracy_sampling = accuracy_score(y_test, y_pred_sampling)
        f1_sampling = f1_score(y_test, y_pred_sampling, average="weighted")



        print(f"\n  Comparaison des résultats avant optimisation pour '{model_name}':")
        print(f"   - Accuracy (Sans Sampling) : {accuracy_no_sampling:.4f}")
        print(f"   - Accuracy (Avec Sampling) : {accuracy_sampling:.4f}")
        print(f"   - F1-score (Sans Sampling) : {f1_no_sampling:.4f}")
        print(f"   - F1-score (Avec Sampling) : {f1_sampling:.4f}")

        similarity_percentage = np.mean(y_pred_sampling == y_pred_no_sampling) * 100

        print(f"   - Similarité des prédictions entre modèles : {similarity_percentage:.2f}%")
        

        #  Calcul des scores sur TRAIN
        y_train_pred = model.predict(X_train_used)
        train_accuracy = accuracy_score(y_train_used, y_train_pred)
        train_f1 = f1_score(y_train_used, y_train_pred, average="weighted")

        #  Calcul des scores sur TEST
        y_pred = model.predict(X_test)
        accuracy_before = accuracy_score(y_test, y_pred)
        f1_before = f1_score(y_test, y_pred, average="weighted")
        
        print(f"\n Résultats du modèle '{model_name}' avant optimisation :")
        print(f"   - Accuracy Train: {train_accuracy:.4f}")
        print(f"   - Accuracy Test: {accuracy_before:.4f}")
        print(f"   - F1-score Train: {train_f1:.4f}")
        print(f"   - F1-score Test: {f1_before:.4f}")

        #  Vérification de l'overfitting / underfitting
        if train_accuracy > accuracy_before + 0.10:
            print(" Overfitting détecté !")
        elif train_accuracy < 0.7 and accuracy_before < 0.7:
            print(" Underfitting détecté !")
        else:
            print(" Bon équilibre entre biais et variance.")

        best_params = {}
        best_model = model
        accuracy_after, f1_after = "Non optimisé", "Non optimisé"

        # Optimisation avec Optuna
        if config["use_optuna"]:
            def objective(trial):
                if model_name == "Decision Tree":
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = DecisionTreeClassifier(max_depth=max_depth)
                elif model_name == "Random Forest":
                    n_estimators = trial.suggest_int("n_estimators", 10, 200)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
                elif model_name == "SVM":
                    C = trial.suggest_loguniform("C", 0.1, 10)
                    kernel = trial.suggest_categorical("kernel", ["linear", "rbf", "poly"])
                    model_opt = SVC(C=C, kernel=kernel)
                elif model_name == "Neural Network":
                    hidden_layer_sizes = trial.suggest_categorical("hidden_layer_sizes", [(50,), (100,), (50, 50)])
                    learning_rate_init = trial.suggest_loguniform("learning_rate_init", 0.0001, 0.1)
                    model_opt = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, learning_rate_init=learning_rate_init, max_iter=500)
                elif model_name == "XGBoost":
                    n_estimators = trial.suggest_int("n_estimators", 50, 500)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
                    model_opt = XGBClassifier(n_estimators=n_estimators, max_depth=max_depth, learning_rate=learning_rate)

                
                model_opt.fit(X_train_no_sampling, y_train_no_sampling)
                model_opt.fit(X_train_sampling, y_train_sampling)
                model_opt.fit(X_train_used, y_train_used)
                y_pred_opt = model_opt.predict(X_test)
                return accuracy_score(y_test, y_pred_opt)

            study = optuna.create_study(direction="maximize")
            study.optimize(objective, n_trials=config["n_trials"])

            best_params = study.best_trial.params
            print(f"\n Meilleurs paramètres trouvés pour '{model_name}' : {best_params}")

            # Réentraînement avec les meilleurs paramètres
            if config["retrain_with_best_params"]:
                start_train_time_after = time.time()  # Début du chronométrage de l'entraînement après optimisation
                best_model = model.__class__(**best_params)
                best_model.fit(X_train_used, y_train_used)
                train_time_after = round(time.time() - start_train_time_after, 2) # Temps pris pour l'entraînement après optimisation

                
                # Entraînement du modèle SANS échantillonnage
                best_model.fit(X_train_no_sampling, y_train_no_sampling)
                y_pred_no_sampling_opt =  best_model.predict(X_test)
                
        
                #  Entraînement du modèle AVEC échantillonnage
                best_model.fit(X_train_sampling, y_train_sampling)
                y_pred_sampling_opt =  best_model.predict(X_test)
        
        
                #  Comparaison des scores aprés optimisation
                accuracy_no_sampling_opt = accuracy_score(y_test, y_pred_no_sampling)
                f1_no_sampling_opt = f1_score(y_test, y_pred_no_sampling, average="weighted")
        
                accuracy_sampling_opt = accuracy_score(y_test, y_pred_sampling)
                f1_sampling_opt = f1_score(y_test, y_pred_sampling, average="weighted")
        
    
                print(f"\n  Comparaison des résultats avant optimisation pour '{model_name}':")
                print(f"   - Accuracy (Sans Sampling) : {accuracy_no_sampling_opt:.4f}")
                print(f"   - Accuracy (Avec Sampling) : {accuracy_sampling_opt:.4f}")
                print(f"   - F1-score (Sans Sampling) : {f1_no_sampling_opt:.4f}")
                print(f"   - F1-score (Avec Sampling) : {f1_sampling_opt:.4f}")
        
                similarity_percentage_opt = np.mean(y_pred_sampling_opt == y_pred_no_sampling_opt) * 100
        
                print(f"   - Similarité des prédictions entre modèles : {similarity_percentage_opt:.2f}%")
                
                
                #  Calcul des scores sur TRAIN apres optimisation 
                y_train_pred_opt = best_model.predict(X_train_used)
                train_accuracy_after = accuracy_score(y_train_used, y_train_pred_opt)
                train_f1_after = f1_score(y_train_used, y_train_pred_opt, average="weighted")
                
                #  Calcul des scores sur TEST apres optimisation 
                y_pred_opt = best_model.predict(X_test)
                accuracy_after = accuracy_score(y_test, y_pred_opt)
                f1_after = f1_score(y_test, y_pred_opt, average="weighted")

            print(f"\n Modèle après optimisation ({model_name}):")
            print(f"   - Accuracy Train: {train_accuracy_after:.4f}")
            print(f"   - Accuracy Test: {accuracy_after:.4f}")
            print(f"   - F1-score Train: {train_f1_after:.4f}")
            print(f"   - F1-score Test: {f1_after:.4f}")

            #  Vérification de l'overfitting / underfitting après optimisation
            if train_accuracy_after > accuracy_after + 0.10:
                print(" Overfitting détecté après optimisation !")
            elif train_accuracy_after < 0.7 and accuracy_after < 0.7:
                print(" Underfitting détecté après optimisation !")
            else:
                print(" Bon équilibre entre biais et variance après optimisation.")
                               

            # Sauvegarde du meilleur modèle
            if config["save_best_model"]:
                model_filename = f"best_model_{model_name}.pkl"
                with open(model_filename, "wb") as f:
                    pickle.dump(best_model, f)
                print(f" Modèle '{model_name}' sauvegardé sous '{model_filename}'.")

    
            #  Appel à collect_results enrichi
            iteration_results = collect_results(
                iteration, config, file_path, target_column, sampling_status, sampling_time,
                train_percent, num_train_used, test_percent, num_test_used,
                model_name, model, model.get_params(), train_time_before,
                accuracy_before, f1_before, train_time_after, best_params,
                accuracy_after, f1_after,
                train_accuracy=train_accuracy,
                train_f1=train_f1,
                accuracy_no_sampling=accuracy_no_sampling,
                f1_no_sampling=f1_no_sampling,
                accuracy_sampling=accuracy_sampling,
                f1_sampling=f1_sampling,
                similarity_percentage=similarity_percentage,
                accuracy_no_sampling_opt=accuracy_no_sampling_opt if 'accuracy_no_sampling_opt' in locals() else None,
                f1_no_sampling_opt=f1_no_sampling_opt if 'f1_no_sampling_opt' in locals() else None,
                accuracy_sampling_opt=accuracy_sampling_opt if 'accuracy_sampling_opt' in locals() else None,
                f1_sampling_opt=f1_sampling_opt if 'f1_sampling_opt' in locals() else None,
                similarity_percentage_opt=similarity_percentage_opt if 'similarity_percentage_opt' in locals() else None,
                train_accuracy_after=train_accuracy_after if 'train_accuracy_after' in locals() else None,
                train_f1_after=train_f1_after if 'train_f1_after' in locals() else None
            )

            print(json.dumps(iteration_results, indent=4, ensure_ascii=False))
            save_results(iteration_results, log_file)

print("\n Toutes les itérations sont terminées.")

# Initialisation du fichier log à la première itération/modèle
if log_file is None:
    log_file = f"resultats_{model_name}_{sampling_status}_{os.path.basename(file_path).split('.')[0]}.txt"

# Réinitialisation du DataFrame après la sauvegarde (conserve les colonnes, supprime les lignes)
results_df.drop(iteration_results.index, inplace=True)
# Out:
#  Données chargées avec succès.
#  Colonne cible définie : species
#  Itérations en cours:   0%|          | 0/2 [00:00<?, ?it/s][I 2025-03-24 13:26:50,814] A new study created in memory with name: no-name-f7759409-e2a0-485a-b17a-46152492958d
#  Exécution de l'itération 1...
#
# Échantillonnage DDBS appliqué.
#
#  Temps samping  : 0.01.
#
# Données après échantillonnage (Train) : 15 échantillons.
# Données de test non modifiées : 20 échantillons.
#  Données sans échantillonnage (Train) : 80 échantillons.
#
#  Pourcentage Entraînement : 15.00%
#  Pourcentage Test : 20.00%
#  Pourcentage Entraînement (Sans Sampling) : 80.00%
#
#   Comparaison des résultats avant optimisation pour 'XGBoost':
#    - Accuracy (Sans Sampling) : 1.0000
#    - Accuracy (Avec Sampling) : 1.0000
#    - F1-score (Sans Sampling) : 1.0000
#    - F1-score (Avec Sampling) : 1.0000
#    - Similarité des prédictions entre modèles : 100.00%
#
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy Train: 1.0000
#    - Accuracy Test: 1.0000
#    - F1-score Train: 1.0000
#    - F1-score Test: 1.0000
#  Bon équilibre entre biais et variance.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:51,086] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 335, 'max_depth': 10, 'learning_rate': 0.2240354563983002}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:51,467] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 474, 'max_depth': 20, 'learning_rate': 0.12758992146943005}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:51,709] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 443, 'max_depth': 18, 'learning_rate': 0.05347762337157773}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:51,845] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 185, 'max_depth': 7, 'learning_rate': 0.05205979431608606}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:52,136] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 476, 'max_depth': 9, 'learning_rate': 0.10556158013372892}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:52,253] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 102, 'max_depth': 13, 'learning_rate': 0.026551905498788615}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:52,339] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 89, 'max_depth': 15, 'learning_rate': 0.09732036420609491}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:52,700] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 447, 'max_depth': 16, 'learning_rate': 0.01215513654160743}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:53,046] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 304, 'max_depth': 10, 'learning_rate': 0.22965343570524016}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:53,432] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 281, 'max_depth': 8, 'learning_rate': 0.027304538732544778}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:53,840] Trial 10 finished with value: 1.0 and parameters: {'n_estimators': 367, 'max_depth': 4, 'learning_rate': 0.2984021969717768}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:54,350] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 325, 'max_depth': 20, 'learning_rate': 0.15073854541123133}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:54,821] Trial 12 finished with value: 1.0 and parameters: {'n_estimators': 387, 'max_depth': 12, 'learning_rate': 0.17928244102222107}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:55,252] Trial 13 finished with value: 1.0 and parameters: {'n_estimators': 228, 'max_depth': 2, 'learning_rate': 0.11023891391583561}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:55,710] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 393, 'max_depth': 6, 'learning_rate': 0.163629402719606}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:56,294] Trial 15 finished with value: 1.0 and parameters: {'n_estimators': 496, 'max_depth': 14, 'learning_rate': 0.07616020783004342}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:56,628] Trial 16 finished with value: 1.0 and parameters: {'n_estimators': 196, 'max_depth': 20, 'learning_rate': 0.29770079225042423}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:57,149] Trial 17 finished with value: 1.0 and parameters: {'n_estimators': 343, 'max_depth': 11, 'learning_rate': 0.03674618040564728}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:57,729] Trial 18 finished with value: 1.0 and parameters: {'n_estimators': 415, 'max_depth': 17, 'learning_rate': 0.14531998317743783}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:57,926] Trial 19 finished with value: 1.0 and parameters: {'n_estimators': 228, 'max_depth': 6, 'learning_rate': 0.0713881961935404}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:58,234] Trial 20 finished with value: 1.0 and parameters: {'n_estimators': 258, 'max_depth': 18, 'learning_rate': 0.20948736249109517}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:58,560] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 434, 'max_depth': 18, 'learning_rate': 0.050486742090359533}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:58,966] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 464, 'max_depth': 20, 'learning_rate': 0.06636963911906342}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:59,333] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 498, 'max_depth': 18, 'learning_rate': 0.03715540229863712}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:59,658] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 425, 'max_depth': 15, 'learning_rate': 0.12067087210833963}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:26:59,981] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 367, 'max_depth': 12, 'learning_rate': 0.012226251142435465}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:00,368] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 411, 'max_depth': 19, 'learning_rate': 0.018818161376436167}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:01,201] Trial 27 finished with value: 1.0 and parameters: {'n_estimators': 458, 'max_depth': 16, 'learning_rate': 0.08804821720480054}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:01,521] Trial 28 finished with value: 1.0 and parameters: {'n_estimators': 337, 'max_depth': 10, 'learning_rate': 0.22444321500146217}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:01,706] Trial 29 finished with value: 1.0 and parameters: {'n_estimators': 127, 'max_depth': 7, 'learning_rate': 0.04965473137812487}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:02,040] Trial 30 finished with value: 1.0 and parameters: {'n_estimators': 384, 'max_depth': 14, 'learning_rate': 0.12929744350560607}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:02,291] Trial 31 finished with value: 1.0 and parameters: {'n_estimators': 157, 'max_depth': 9, 'learning_rate': 0.059064723826677656}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:02,495] Trial 32 finished with value: 1.0 and parameters: {'n_estimators': 142, 'max_depth': 4, 'learning_rate': 0.04013761215837533}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:02,638] Trial 33 finished with value: 1.0 and parameters: {'n_estimators': 55, 'max_depth': 9, 'learning_rate': 0.02814618933855589}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:03,086] Trial 34 finished with value: 1.0 and parameters: {'n_estimators': 465, 'max_depth': 8, 'learning_rate': 0.08955179460269871}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:03,391] Trial 35 finished with value: 1.0 and parameters: {'n_estimators': 196, 'max_depth': 5, 'learning_rate': 0.044838678915159406}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:03,739] Trial 36 finished with value: 1.0 and parameters: {'n_estimators': 273, 'max_depth': 11, 'learning_rate': 0.10006110772620243}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:04,082] Trial 37 finished with value: 1.0 and parameters: {'n_estimators': 301, 'max_depth': 8, 'learning_rate': 0.020905527279121327}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:04,313] Trial 38 finished with value: 1.0 and parameters: {'n_estimators': 176, 'max_depth': 13, 'learning_rate': 0.187373528896573}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:04,769] Trial 39 finished with value: 1.0 and parameters: {'n_estimators': 444, 'max_depth': 19, 'learning_rate': 0.2596258874142117}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:04,959] Trial 40 finished with value: 1.0 and parameters: {'n_estimators': 102, 'max_depth': 16, 'learning_rate': 0.030671891689825037}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:05,413] Trial 41 finished with value: 1.0 and parameters: {'n_estimators': 476, 'max_depth': 10, 'learning_rate': 0.08274571683067047}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:05,820] Trial 42 finished with value: 1.0 and parameters: {'n_estimators': 489, 'max_depth': 7, 'learning_rate': 0.062486738689983716}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:06,233] Trial 43 finished with value: 1.0 and parameters: {'n_estimators': 443, 'max_depth': 9, 'learning_rate': 0.11428188247264943}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:06,671] Trial 44 finished with value: 1.0 and parameters: {'n_estimators': 407, 'max_depth': 12, 'learning_rate': 0.14071697315017914}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:07,090] Trial 45 finished with value: 1.0 and parameters: {'n_estimators': 362, 'max_depth': 7, 'learning_rate': 0.1789679247437532}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:07,400] Trial 46 finished with value: 1.0 and parameters: {'n_estimators': 301, 'max_depth': 3, 'learning_rate': 0.10078563134165808}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:07,709] Trial 47 finished with value: 1.0 and parameters: {'n_estimators': 238, 'max_depth': 6, 'learning_rate': 0.07521884310762435}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:08,259] Trial 48 finished with value: 1.0 and parameters: {'n_estimators': 472, 'max_depth': 10, 'learning_rate': 0.2417916999763122}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\3534486474.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 13:27:08,837] Trial 49 finished with value: 1.0 and parameters: {'n_estimators': 486, 'max_depth': 11, 'learning_rate': 0.057485456274782264}. Best is trial 0 with value: 1.0.
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 335, 'max_depth': 10, 'learning_rate': 0.2240354563983002}
#  Itérations en cours:   0%|          | 0/2 [00:18<?, ?it/s]
#   Comparaison des résultats avant optimisation pour 'XGBoost':
#    - Accuracy (Sans Sampling) : 1.0000
#    - Accuracy (Avec Sampling) : 1.0000
#    - F1-score (Sans Sampling) : 1.0000
#    - F1-score (Avec Sampling) : 1.0000
#    - Similarité des prédictions entre modèles : 100.00%
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy Train: 1.0000
#    - Accuracy Test: 1.0000
#    - F1-score Train: 1.0000
#    - F1-score Test: 1.0000
#  Bon équilibre entre biais et variance après optimisation.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 362
#     358     print(f" Modèle '{model_name}' sauvegardé sous '{model_filename}'.")
#     361 #  Appel à collect_results enrichi
# --> 362 iteration_results = collect_results(
#     363     iteration, config, file_path, target_column, sampling_status, sampling_time,
#     364     train_percent, num_train_used, test_percent, num_test_used,
#     365     model_name, model, model.get_params(), train_time_before,
#     366     accuracy_before, f1_before, train_time_after, best_params,
#     367     accuracy_after, f1_after,
#     368     train_accuracy=train_accuracy,
#     369     train_f1=train_f1,
#     370     accuracy_no_sampling=accuracy_no_sampling,
#     371     f1_no_sampling=f1_no_sampling,
#     372     accuracy_sampling=accuracy_sampling,
#     373     f1_sampling=f1_sampling,
#     374     similarity_percentage=similarity_percentage,
#     375     accuracy_no_sampling_opt=accuracy_no_sampling_opt if 'accuracy_no_sampling_opt' in locals() else None,
#     376     f1_no_sampling_opt=f1_no_sampling_opt if 'f1_no_sampling_opt' in locals() else None,
#     377     accuracy_sampling_opt=accuracy_sampling_opt if 'accuracy_sampling_opt' in locals() else None,
#     378     f1_sampling_opt=f1_sampling_opt if 'f1_sampling_opt' in locals() else None,
#     379     similarity_percentage_opt=similarity_percentage_opt if 'similarity_percentage_opt' in locals() else None,
#     380     train_accuracy_after=train_accuracy_after if 'train_accuracy_after' in locals() else None,
#     381     train_f1_after=train_f1_after if 'train_f1_after' in locals() else None
#     382 )
#     384 print(json.dumps(iteration_results, indent=4, ensure_ascii=False))
#     385 save_results(iteration_results, log_file)
#
# TypeError: collect_results() got an unexpected keyword argument 'train_accuracy'

# %%
import numpy as np
import pandas as pd
import json
import optuna
import pickle
import os
import time
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier

# Import collection des resultat
from resultat.collect_results import collect_results

# Import sécurisé de gmm_sampling
try:
    from sampling.gmm_sampling import gmm_sampling
except ModuleNotFoundError:
    raise ImportError(" Impossible d'importer gmm_sampling. Vérifiez le chemin du fichier.")

# Import sécurisé de ddbs_sampling
try:
    from sampling.ddbs_sampling import diversified_distance_based_sampling
except ModuleNotFoundError:
    raise ImportError("Impossible d'importer ddbs_sampling. Vérifiez le chemin du fichier.")


# Charger la configuration depuis config.json
with open("config.json", "r") as config_file:
    config = json.load(config_file)

file_path = config["file_path"]
model_save_path = config["model_save_path"]
num_iterations = config.get("num_iterations", 2)  #  Nombre d'itérations

# Charger le dataset CSV avec gestion des erreurs
df = pd.read_csv(file_path)
print(" Données chargées avec succès.")

# Définition de la colonne cible
target_column = config["target_column"]
if target_column not in df.columns:
    raise ValueError(f" La colonne cible '{target_column}' est absente des données.")

print(f" Colonne cible définie : {target_column}")


# Fonction de sauvegarde dans un fichier texte
log_file = None

def save_results(iteration_results, log_path):
    try:
        with open(log_path, "a", encoding="utf-8") as f:
            f.write(f"### Itération {iteration_results['Itération']} - {iteration_results['Modèle']} ###\n")
            f.write(json.dumps(iteration_results, indent=4, ensure_ascii=False))
            f.write("\n\n")
        print(f" Résultats enregistrés dans '{log_path}'")
    except Exception as e:
        print(f" Erreur lors de l'enregistrement : {e}")


# Boucle d'itérations

for iteration in tqdm(range(1, num_iterations  + 1), desc=" Itérations en cours"):
    print(f"\n Exécution de l'itération {iteration}...\n")

     # Séparation des données en Train/Test avant sampling
    test_size = config["train_test_split"]["test_size"]
    X = df.drop(columns=[target_column])
    y = df[target_column]

    # Division des données
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

    # CONSERVER les données SANS échantillonnage pour les comparer plus tard
    X_train_no_sampling, y_train_no_sampling = X_train.copy(), y_train.copy()
    
    #  Appliquer le sampling UNIQUEMENT sur les données d'entraînement
    start_sampling_time = time.time()
    
    # Appliquer le sampling si activé
    if config["sampling"]["enabled"]:
        # Si le sampling type est GMM, appliquer le sampling GMM
        if config["sampling"]["gmm"]["enabled"]:
            df_train_sampled = gmm_sampling(pd.concat([X_train, y_train], axis=1), target_column, config)
            X_train_sampled = df_train_sampled.drop(columns=[target_column])
            y_train_sampled = df_train_sampled[target_column]
            sampling_status = "Oui (GMM)"
            print("Échantillonnage GMM appliqué")
        
        # Si le sampling type est Random, utiliser Pandas sample()
        elif config["sampling"]["random"]["enabled"]:
            fraction = config["sampling"]["fraction"]
            sampled_indices = X_train.sample(frac=fraction).index
            X_train_sampled, y_train_sampled = X_train.loc[sampled_indices], y_train.loc[sampled_indices]
            sampling_status = "Oui (Random)"
            print(f" Échantillonnage aléatoire activé : {fraction*100:.1f}% des données utilisées.")
        
        # Si le sampling type est ddbs, utiliser Pandas sample()    
        elif config["sampling"]["ddbs"]["enabled"]:
            df_train_sampled = diversified_distance_based_sampling(pd.concat([X_train, y_train], axis=1), target_column, config)
            X_train_sampled = df_train_sampled.drop(columns=[target_column])
            y_train_sampled = df_train_sampled[target_column]
            sampling_status = f"Oui (DDBS - {config['sampling']['ddbs']['distance_metric']}, {config['sampling']['ddbs']['distribution_type']})"
            print("Échantillonnage DDBS appliqué.")
        
        # Si le type est inconnu, lever une erreur
        else:
            raise ValueError(f" Type d'échantillonnage inconnu : '{sampling_type}'")

    else:
        # Si le sampling est désactivé, utiliser le dataset original
        X_train_sampled, y_train_sampled = X_train, y_train
        sampling_status = "Non"
        print(" Aucun échantillonnage appliqué, utilisation des données complètes.")


   # Sélectionner les bonnes données d'entraînement (avec ou sans échantillonnage)
    X_train_used, y_train_used = (X_train_sampled, y_train_sampled) if config["sampling"]["enabled"] else (X_train, y_train)
    

    # Sélectionner les bonnes données d'entraînement 
    X_train_sampling, y_train_sampling = X_train_sampled, y_train_sampled  # AVEC sampling


    # Calcul du temps pris pour le sampling
    sampling_time = round(time.time() - start_sampling_time , 2) # Calcul du temps pris par le sampling
    print(f"\n Temps samping  : {sampling_time}.")
    
    #  Mise à jour du nombre d'échantillons après sampling
    num_train_used  = len(X_train_used)
    num_test_used  = len(X_test) # Le test set reste inchangé

    num_train_no_sampling = len(X_train_no_sampling)  # Taille des données sans échantillonnage


    print(f"\nDonnées après échantillonnage (Train) : {num_train_used } échantillons.")
    print(f"Données de test non modifiées : {num_test_used } échantillons.")
    
    print(f" Données sans échantillonnage (Train) : {num_train_no_sampling} échantillons.")
    
    # Calcul du pourcentage des données après échantillonnage
    train_percent = (num_train_used / len(df)) * 100
    test_percent = (num_test_used / len(df)) * 100

    train_percent_no_sampling = (num_train_no_sampling / len(df)) * 100

    
    print(f"\n Pourcentage Entraînement : {train_percent:.2f}%")
    print(f" Pourcentage Test : {test_percent:.2f}%")
    print(f" Pourcentage Entraînement (Sans Sampling) : {train_percent_no_sampling:.2f}%")



    # Initialiser les modèles
    models_no_sampling = {}  # Modèles entraînés SANS échantillonnage
    models_sampling = {}  # Modèles entraînés AVEC échantillonnage
    models = {}
    for model_name, model_params in config["models"].items():
        if model_params["enabled"]:
            if model_name == "Decision Tree":
                models[model_name] = DecisionTreeClassifier(max_depth=model_params["max_depth"])
            elif model_name == "Random Forest":
                models[model_name] = RandomForestClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"]
                )
            elif model_name == "SVM":
                models[model_name] = SVC(C=model_params["C"], kernel=model_params["kernel"])
            elif model_name == "Neural Network":
                models[model_name] = MLPClassifier(
                    hidden_layer_sizes=tuple(model_params["hidden_layer_sizes"]),
                    learning_rate_init=model_params["learning_rate_init"],
                    max_iter=500
                )
            elif model_name == "XGBoost":
                models[model_name] = XGBClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"],
                    learning_rate=model_params["learning_rate"]    
                )

    # Entraînement et évaluation des modèles
    for model_name, model in models.items():

        # Entraînement du modèle avec les bonnes données
        start_train_time = time.time()  # Début du chronométrage de l'entraînement avant optimisation
        model.fit(X_train_used, y_train_used)
        train_time_before = round(time.time() - start_train_time , 2)  # Temps pris pour l'entraînement avant optimisation

        # Entraînement du modèle SANS échantillonnage
        model.fit(X_train_no_sampling, y_train_no_sampling)
        y_pred_no_sampling = model.predict(X_test)
        

        #  Entraînement du modèle AVEC échantillonnage
        model.fit(X_train_sampling, y_train_sampling)
        y_pred_sampling = model.predict(X_test)


        #  Comparaison des scores avant optimisation
        accuracy_no_sampling = accuracy_score(y_test, y_pred_no_sampling)
        f1_no_sampling = f1_score(y_test, y_pred_no_sampling, average="weighted")

        accuracy_sampling = accuracy_score(y_test, y_pred_sampling)
        f1_sampling = f1_score(y_test, y_pred_sampling, average="weighted")



        print(f"\n  Comparaison des résultats avant optimisation pour '{model_name}':")
        print(f"   - Accuracy (Sans Sampling) : {accuracy_no_sampling:.4f}")
        print(f"   - Accuracy (Avec Sampling) : {accuracy_sampling:.4f}")
        print(f"   - F1-score (Sans Sampling) : {f1_no_sampling:.4f}")
        print(f"   - F1-score (Avec Sampling) : {f1_sampling:.4f}")

        similarity_percentage = np.mean(y_pred_sampling == y_pred_no_sampling) * 100

        print(f"   - Similarité des prédictions entre modèles : {similarity_percentage:.2f}%")
        

        #  Calcul des scores sur TRAIN
        y_train_pred = model.predict(X_train_used)
        train_accuracy = accuracy_score(y_train_used, y_train_pred)
        train_f1 = f1_score(y_train_used, y_train_pred, average="weighted")

        #  Calcul des scores sur TEST
        y_pred = model.predict(X_test)
        accuracy_before = accuracy_score(y_test, y_pred)
        f1_before = f1_score(y_test, y_pred, average="weighted")
        
        print(f"\n Résultats du modèle '{model_name}' avant optimisation :")
        print(f"   - Accuracy Train: {train_accuracy:.4f}")
        print(f"   - Accuracy Test: {accuracy_before:.4f}")
        print(f"   - F1-score Train: {train_f1:.4f}")
        print(f"   - F1-score Test: {f1_before:.4f}")

        #  Vérification de l'overfitting / underfitting
        if train_accuracy > accuracy_before + 0.10:
            print(" Overfitting détecté !")
        elif train_accuracy < 0.7 and accuracy_before < 0.7:
            print(" Underfitting détecté !")
        else:
            print(" Bon équilibre entre biais et variance.")

        best_params = {}
        best_model = model
        accuracy_after, f1_after = "Non optimisé", "Non optimisé"

        # Optimisation avec Optuna
        if config["use_optuna"]:
            def objective(trial):
                if model_name == "Decision Tree":
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = DecisionTreeClassifier(max_depth=max_depth)
                elif model_name == "Random Forest":
                    n_estimators = trial.suggest_int("n_estimators", 10, 200)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
                elif model_name == "SVM":
                    C = trial.suggest_loguniform("C", 0.1, 10)
                    kernel = trial.suggest_categorical("kernel", ["linear", "rbf", "poly"])
                    model_opt = SVC(C=C, kernel=kernel)
                elif model_name == "Neural Network":
                    hidden_layer_sizes = trial.suggest_categorical("hidden_layer_sizes", [(50,), (100,), (50, 50)])
                    learning_rate_init = trial.suggest_loguniform("learning_rate_init", 0.0001, 0.1)
                    model_opt = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, learning_rate_init=learning_rate_init, max_iter=500)
                elif model_name == "XGBoost":
                    n_estimators = trial.suggest_int("n_estimators", 50, 500)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
                    model_opt = XGBClassifier(n_estimators=n_estimators, max_depth=max_depth, learning_rate=learning_rate)

                
                model_opt.fit(X_train_no_sampling, y_train_no_sampling)
                model_opt.fit(X_train_sampling, y_train_sampling)
                model_opt.fit(X_train_used, y_train_used)
                y_pred_opt = model_opt.predict(X_test)
                return accuracy_score(y_test, y_pred_opt)

            study = optuna.create_study(direction="maximize")
            study.optimize(objective, n_trials=config["n_trials"])

            best_params = study.best_trial.params
            print(f"\n Meilleurs paramètres trouvés pour '{model_name}' : {best_params}")

            # Réentraînement avec les meilleurs paramètres
            if config["retrain_with_best_params"]:
                start_train_time_after = time.time()  # Début du chronométrage de l'entraînement après optimisation
                best_model = model.__class__(**best_params)
                best_model.fit(X_train_used, y_train_used)
                train_time_after = round(time.time() - start_train_time_after, 2) # Temps pris pour l'entraînement après optimisation

                
                # Entraînement du modèle SANS échantillonnage
                best_model.fit(X_train_no_sampling, y_train_no_sampling)
                y_pred_no_sampling_opt =  best_model.predict(X_test)
                
        
                #  Entraînement du modèle AVEC échantillonnage
                best_model.fit(X_train_sampling, y_train_sampling)
                y_pred_sampling_opt =  best_model.predict(X_test)
        
        
                #  Comparaison des scores aprés optimisation
                accuracy_no_sampling_opt = accuracy_score(y_test, y_pred_no_sampling)
                f1_no_sampling_opt = f1_score(y_test, y_pred_no_sampling, average="weighted")
        
                accuracy_sampling_opt = accuracy_score(y_test, y_pred_sampling)
                f1_sampling_opt = f1_score(y_test, y_pred_sampling, average="weighted")
        
    
                print(f"\n  Comparaison des résultats avant optimisation pour '{model_name}':")
                print(f"   - Accuracy (Sans Sampling) : {accuracy_no_sampling_opt:.4f}")
                print(f"   - Accuracy (Avec Sampling) : {accuracy_sampling_opt:.4f}")
                print(f"   - F1-score (Sans Sampling) : {f1_no_sampling_opt:.4f}")
                print(f"   - F1-score (Avec Sampling) : {f1_sampling_opt:.4f}")
        
                similarity_percentage_opt = np.mean(y_pred_sampling_opt == y_pred_no_sampling_opt) * 100
        
                print(f"   - Similarité des prédictions entre modèles : {similarity_percentage_opt:.2f}%")
                
                
                #  Calcul des scores sur TRAIN apres optimisation 
                y_train_pred_opt = best_model.predict(X_train_used)
                train_accuracy_after = accuracy_score(y_train_used, y_train_pred_opt)
                train_f1_after = f1_score(y_train_used, y_train_pred_opt, average="weighted")
                
                #  Calcul des scores sur TEST apres optimisation 
                y_pred_opt = best_model.predict(X_test)
                accuracy_after = accuracy_score(y_test, y_pred_opt)
                f1_after = f1_score(y_test, y_pred_opt, average="weighted")

            print(f"\n Modèle après optimisation ({model_name}):")
            print(f"   - Accuracy Train: {train_accuracy_after:.4f}")
            print(f"   - Accuracy Test: {accuracy_after:.4f}")
            print(f"   - F1-score Train: {train_f1_after:.4f}")
            print(f"   - F1-score Test: {f1_after:.4f}")

            #  Vérification de l'overfitting / underfitting après optimisation
            if train_accuracy_after > accuracy_after + 0.10:
                print(" Overfitting détecté après optimisation !")
            elif train_accuracy_after < 0.7 and accuracy_after < 0.7:
                print(" Underfitting détecté après optimisation !")
            else:
                print(" Bon équilibre entre biais et variance après optimisation.")
                               

            # Sauvegarde du meilleur modèle
            if config["save_best_model"]:
                model_filename = f"best_model_{model_name}.pkl"
                with open(model_filename, "wb") as f:
                    pickle.dump(best_model, f)
                print(f" Modèle '{model_name}' sauvegardé sous '{model_filename}'.")

    
            #  Appel à collect_results enrichi
            # Construction manuelle du dictionnaire iteration_results
            iteration_results = {
                "Itération": iteration,
                "Dataset utilisé": file_path,
                "Colonne cible": target_column,
                "Échantillonnage": sampling_status,
                "Tps Sampling": sampling_time,
                "Entrain %": train_percent,
                "Nbre Entrain": num_train_used,
                "Test %": test_percent,
                "Nbre Test": num_test_used,
                "Modèle": model_name,
                "Paramètres initiaux": {
                    param: value for param, value in model.get_params().items() if param in model_params
                },
                "Tps Entrain Avant": train_time_before,
                "Accuracy Avant": accuracy_before,
                "F1-score Avant": f1_before,
                "Tps Entrain Après": train_time_after if 'train_time_after' in locals() else None,
                "Paramètres optimisés": best_params,
                "Accuracy Après": accuracy_after,
                "F1-score Après": f1_after,
            
                # Résultats complémentaires
                "Accuracy Train Avant": train_accuracy,
                "F1-score Train Avant": train_f1,
                "Accuracy Test (Sans Sampling)": accuracy_no_sampling,
                "F1-score Test (Sans Sampling)": f1_no_sampling,
                "Accuracy Test (Avec Sampling)": accuracy_sampling,
                "F1-score Test (Avec Sampling)": f1_sampling,
                "Similarité Prédictions (Avant Opti)": similarity_percentage,
                "Accuracy Test (Sans Sampling - Opti)": accuracy_no_sampling_opt if 'accuracy_no_sampling_opt' in locals() else None,
                "F1-score Test (Sans Sampling - Opti)": f1_no_sampling_opt if 'f1_no_sampling_opt' in locals() else None,
                "Accuracy Test (Avec Sampling - Opti)": accuracy_sampling_opt if 'accuracy_sampling_opt' in locals() else None,
                "F1-score Test (Avec Sampling - Opti)": f1_sampling_opt if 'f1_sampling_opt' in locals() else None,
                "Similarité Prédictions (Après Opti)": similarity_percentage_opt if 'similarity_percentage_opt' in locals() else None,
                "Accuracy Train Après": train_accuracy_after if 'train_accuracy_after' in locals() else None,
                "F1-score Train Après": train_f1_after if 'train_f1_after' in locals() else None
            }
            
            # Ajouter les infos spécifiques au sampling
            if config["sampling"]["gmm"]["enabled"]:
                iteration_results["Sampling GMM"] = {
                    "n_components_range": config["sampling"]["gmm"]["n_components_range"],
                    "covariance_types": config["sampling"]["gmm"]["covariance_types"],
                    "reduction_rate": config["sampling"]["gmm"].get("reduction_rate", "Non spécifié"),
                    "best_bic": globals().get("best_bic", "Non spécifié"),
                    "best_gmm": str(globals().get("best_gmm", "Non spécifié")),
                    "n_samples_generated": globals().get("n_samples", "Non spécifié")
                }
            elif config["sampling"]["ddbs"]["enabled"]:
                iteration_results["Sampling DDBS"] = {
                    "distance_metric": config["sampling"]["ddbs"]["distance_metric"],
                    "distribution_type": config["sampling"]["ddbs"]["distribution_type"],
                    "percentage_per_class": config["sampling"]["ddbs"]["percentage_per_class"],
                    "total_selected_samples": num_train_used
                }
            elif config["sampling"]["random"]["enabled"]:
                iteration_results["Sampling Random"] = {
                    "fraction": config["sampling"]["fraction"],
                    "total_selected_samples": num_train_used
                }
            
            # Initialisation du fichier log à la première itération
            if log_file is None:
                base_name = os.path.basename(file_path).split('.')[0]
                log_file = f"resultat/log/resultats_{model_name}_{sampling_status.replace(' ', '_').replace('(', '').replace(')', '').replace('-', '')}_{base_name}.txt"

            
            # Affichage et sauvegarde
            print(json.dumps(iteration_results, indent=4, ensure_ascii=False))
            save_results(iteration_results, log_file)

print("\n  Toutes les itérations sont terminées.")
# Out:
#  Données chargées avec succès.
#  Colonne cible définie : species
#  Itérations en cours:   0%|          | 0/2 [00:00<?, ?it/s][I 2025-03-24 16:05:26,240] A new study created in memory with name: no-name-b1932da9-dd02-4d23-8dcf-0b3bcc4955e3
#  Exécution de l'itération 1...
#
# Échantillonnage DDBS appliqué.
#
#  Temps samping  : 0.01.
#
# Données après échantillonnage (Train) : 15 échantillons.
# Données de test non modifiées : 20 échantillons.
#  Données sans échantillonnage (Train) : 80 échantillons.
#
#  Pourcentage Entraînement : 15.00%
#  Pourcentage Test : 20.00%
#  Pourcentage Entraînement (Sans Sampling) : 80.00%
#
#   Comparaison des résultats avant optimisation pour 'XGBoost':
#    - Accuracy (Sans Sampling) : 1.0000
#    - Accuracy (Avec Sampling) : 1.0000
#    - F1-score (Sans Sampling) : 1.0000
#    - F1-score (Avec Sampling) : 1.0000
#    - Similarité des prédictions entre modèles : 100.00%
#
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy Train: 1.0000
#    - Accuracy Test: 1.0000
#    - F1-score Train: 1.0000
#    - F1-score Test: 1.0000
#  Bon équilibre entre biais et variance.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:26,360] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 63, 'max_depth': 20, 'learning_rate': 0.0705152196281784}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:26,517] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 66, 'max_depth': 13, 'learning_rate': 0.01010786821499513}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:27,363] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 380, 'max_depth': 13, 'learning_rate': 0.02450667007963505}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:27,833] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 311, 'max_depth': 17, 'learning_rate': 0.010920582230340328}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:28,184] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 225, 'max_depth': 15, 'learning_rate': 0.05903678337413773}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:28,718] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 496, 'max_depth': 4, 'learning_rate': 0.06308658255030931}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:28,918] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 141, 'max_depth': 19, 'learning_rate': 0.14410700723060632}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:29,185] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 213, 'max_depth': 8, 'learning_rate': 0.09022362197085004}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:29,551] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 225, 'max_depth': 12, 'learning_rate': 0.015556936979303783}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:30,035] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 383, 'max_depth': 20, 'learning_rate': 0.026031681359411883}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:30,200] Trial 10 finished with value: 1.0 and parameters: {'n_estimators': 62, 'max_depth': 8, 'learning_rate': 0.29096857810775256}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:30,403] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 63, 'max_depth': 9, 'learning_rate': 0.03245383785793423}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:30,670] Trial 12 finished with value: 1.0 and parameters: {'n_estimators': 150, 'max_depth': 3, 'learning_rate': 0.1307991705397439}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:30,928] Trial 13 finished with value: 1.0 and parameters: {'n_estimators': 112, 'max_depth': 15, 'learning_rate': 0.044095614264961426}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:31,134] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 50, 'max_depth': 17, 'learning_rate': 0.016604872126781176}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:31,385] Trial 15 finished with value: 1.0 and parameters: {'n_estimators': 118, 'max_depth': 5, 'learning_rate': 0.09873432047108748}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:31,681] Trial 16 finished with value: 1.0 and parameters: {'n_estimators': 174, 'max_depth': 10, 'learning_rate': 0.2883957385489428}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:32,276] Trial 17 finished with value: 1.0 and parameters: {'n_estimators': 293, 'max_depth': 14, 'learning_rate': 0.01015765550349683}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:32,488] Trial 18 finished with value: 1.0 and parameters: {'n_estimators': 95, 'max_depth': 18, 'learning_rate': 0.18728184362300415}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:32,813] Trial 19 finished with value: 1.0 and parameters: {'n_estimators': 184, 'max_depth': 11, 'learning_rate': 0.04091904245974229}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:33,267] Trial 20 finished with value: 1.0 and parameters: {'n_estimators': 345, 'max_depth': 6, 'learning_rate': 0.07964853028165068}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:33,819] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 441, 'max_depth': 13, 'learning_rate': 0.021144478765744556}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:34,544] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 414, 'max_depth': 16, 'learning_rate': 0.014793464857344984}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:34,962] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 267, 'max_depth': 13, 'learning_rate': 0.02623039821947593}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:35,482] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 361, 'max_depth': 20, 'learning_rate': 0.03648680209663464}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:36,121] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 458, 'max_depth': 12, 'learning_rate': 0.019300950027350498}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:36,342] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 89, 'max_depth': 7, 'learning_rate': 0.01241558733797507}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:36,699] Trial 27 finished with value: 1.0 and parameters: {'n_estimators': 258, 'max_depth': 2, 'learning_rate': 0.054635059958708515}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:37,110] Trial 28 finished with value: 1.0 and parameters: {'n_estimators': 312, 'max_depth': 10, 'learning_rate': 0.02272208309873722}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:37,589] Trial 29 finished with value: 1.0 and parameters: {'n_estimators': 333, 'max_depth': 17, 'learning_rate': 0.011898474899645973}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:38,442] Trial 30 finished with value: 1.0 and parameters: {'n_estimators': 413, 'max_depth': 15, 'learning_rate': 0.030299599650507755}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:39,306] Trial 31 finished with value: 1.0 and parameters: {'n_estimators': 386, 'max_depth': 18, 'learning_rate': 0.010736980570242709}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:39,765] Trial 32 finished with value: 1.0 and parameters: {'n_estimators': 307, 'max_depth': 16, 'learning_rate': 0.06535515628400405}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:40,196] Trial 33 finished with value: 1.0 and parameters: {'n_estimators': 220, 'max_depth': 19, 'learning_rate': 0.013326439104559882}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:40,830] Trial 34 finished with value: 1.0 and parameters: {'n_estimators': 490, 'max_depth': 14, 'learning_rate': 0.055713682744083504}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:41,276] Trial 35 finished with value: 1.0 and parameters: {'n_estimators': 255, 'max_depth': 19, 'learning_rate': 0.01651890260128533}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:41,593] Trial 36 finished with value: 1.0 and parameters: {'n_estimators': 146, 'max_depth': 16, 'learning_rate': 0.0189560927587046}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:42,274] Trial 37 finished with value: 1.0 and parameters: {'n_estimators': 377, 'max_depth': 20, 'learning_rate': 0.010108957333337498}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:42,760] Trial 38 finished with value: 1.0 and parameters: {'n_estimators': 337, 'max_depth': 18, 'learning_rate': 0.07590872130058428}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:42,971] Trial 39 finished with value: 1.0 and parameters: {'n_estimators': 77, 'max_depth': 12, 'learning_rate': 0.04565528281908887}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:43,258] Trial 40 finished with value: 1.0 and parameters: {'n_estimators': 113, 'max_depth': 14, 'learning_rate': 0.11121097494395354}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:43,537] Trial 41 finished with value: 1.0 and parameters: {'n_estimators': 172, 'max_depth': 15, 'learning_rate': 0.05232512939924983}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:43,869] Trial 42 finished with value: 1.0 and parameters: {'n_estimators': 231, 'max_depth': 17, 'learning_rate': 0.06887648599303045}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:44,194] Trial 43 finished with value: 1.0 and parameters: {'n_estimators': 201, 'max_depth': 12, 'learning_rate': 0.08718781274776768}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:44,477] Trial 44 finished with value: 1.0 and parameters: {'n_estimators': 132, 'max_depth': 13, 'learning_rate': 0.02877167135912852}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:44,896] Trial 45 finished with value: 1.0 and parameters: {'n_estimators': 291, 'max_depth': 11, 'learning_rate': 0.1294988025613806}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:45,081] Trial 46 finished with value: 1.0 and parameters: {'n_estimators': 59, 'max_depth': 15, 'learning_rate': 0.03661660118650793}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:45,405] Trial 47 finished with value: 1.0 and parameters: {'n_estimators': 97, 'max_depth': 19, 'learning_rate': 0.013867390076645406}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:45,997] Trial 48 finished with value: 1.0 and parameters: {'n_estimators': 237, 'max_depth': 14, 'learning_rate': 0.10157559061021228}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:46,948] Trial 49 finished with value: 1.0 and parameters: {'n_estimators': 406, 'max_depth': 17, 'learning_rate': 0.02409296792707456}. Best is trial 0 with value: 1.0.
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 63, 'max_depth': 20, 'learning_rate': 0.0705152196281784}
#  Itérations en cours:  50%|█████     | 1/2 [00:21<00:21, 21.36s/it]
#   Comparaison des résultats avant optimisation pour 'XGBoost':
#    - Accuracy (Sans Sampling) : 1.0000
#    - Accuracy (Avec Sampling) : 1.0000
#    - F1-score (Sans Sampling) : 1.0000
#    - F1-score (Avec Sampling) : 1.0000
#    - Similarité des prédictions entre modèles : 100.00%
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy Train: 1.0000
#    - Accuracy Test: 1.0000
#    - F1-score Train: 1.0000
#    - F1-score Test: 1.0000
#  Bon équilibre entre biais et variance après optimisation.
# {
#     "Itération": 1,
#     "Dataset utilisé": "data/dataP/preprocessed_iris_dataset.csv",
#     "Colonne cible": "species",
#     "Échantillonnage": "Oui (DDBS - euclidean, geometric)",
#     "Tps Sampling": 0.01,
#     "Entrain %": 15.0,
#     "Nbre Entrain": 15,
#     "Test %": 20.0,
#     "Nbre Test": 20,
#     "Modèle": "XGBoost",
#     "Paramètres initiaux": {
#         "learning_rate": 0.1,
#         "max_depth": 6,
#         "n_estimators": 100
#     },
#     "Tps Entrain Avant": 0.04,
#     "Accuracy Avant": 1.0,
#     "F1-score Avant": 1.0,
#     "Tps Entrain Après": 0.31,
#     "Paramètres optimisés": {
#         "n_estimators": 63,
#         "max_depth": 20,
#         "learning_rate": 0.0705152196281784
#     },
#     "Accuracy Après": 1.0,
#     "F1-score Après": 1.0,
#     "Accuracy Train Avant": 1.0,
#     "F1-score Train Avant": 1.0,
#     "Accuracy Test (Sans Sampling)": 1.0,
#     "F1-score Test (Sans Sampling)": 1.0,
#     "Accuracy Test (Avec Sampling)": 1.0,
#     "F1-score Test (Avec Sampling)": 1.0,
#     "Similarité Prédictions (Avant Opti)": 100.0,
#     "Accuracy Test (Sans Sampling - Opti)": 1.0,
#     "F1-score Test (Sans Sampling - Opti)": 1.0,
#     "Accuracy Test (Avec Sampling - Opti)": 1.0,
#     "F1-score Test (Avec Sampling - Opti)": 1.0,
#     "Similarité Prédictions (Après Opti)": 100.0,
#     "Accuracy Train Après": 1.0,
#     "F1-score Train Après": 1.0,
#     "Sampling DDBS": {
#         "distance_metric": "euclidean",
#         "distribution_type": "geometric",
#         "percentage_per_class": 0.2,
#         "total_selected_samples": 15
#     }
# }
#  Résultats enregistrés dans 'resultat/log/resultats_XGBoost_Oui_DDBS__euclidean,_geometric_preprocessed_iris_dataset.txt'
#
#  Exécution de l'itération 2...
#
# Échantillonnage DDBS appliqué.
#
#  Temps samping  : 0.01.
#
# Données après échantillonnage (Train) : 15 échantillons.
# Données de test non modifiées : 20 échantillons.
#  Données sans échantillonnage (Train) : 80 échantillons.
#
#  Pourcentage Entraînement : 15.00%
#  Pourcentage Test : 20.00%
#  Pourcentage Entraînement (Sans Sampling) : 80.00%
# [I 2025-03-24 16:05:47,760] A new study created in memory with name: no-name-e3f68215-178c-47b1-866f-b75310493b3b
#   Comparaison des résultats avant optimisation pour 'XGBoost':
#    - Accuracy (Sans Sampling) : 1.0000
#    - Accuracy (Avec Sampling) : 1.0000
#    - F1-score (Sans Sampling) : 1.0000
#    - F1-score (Avec Sampling) : 1.0000
#    - Similarité des prédictions entre modèles : 100.00%
#
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy Train: 1.0000
#    - Accuracy Test: 1.0000
#    - F1-score Train: 1.0000
#    - F1-score Test: 1.0000
#  Bon équilibre entre biais et variance.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:48,458] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 422, 'max_depth': 12, 'learning_rate': 0.02174508768250832}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:48,990] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 275, 'max_depth': 5, 'learning_rate': 0.014875066745497765}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:49,531] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 418, 'max_depth': 5, 'learning_rate': 0.03576352057615038}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:50,195] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 497, 'max_depth': 8, 'learning_rate': 0.10381401110790038}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:50,917] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 119, 'max_depth': 10, 'learning_rate': 0.012649694375886792}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:51,362] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 160, 'max_depth': 18, 'learning_rate': 0.1943925658917844}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:51,961] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 486, 'max_depth': 2, 'learning_rate': 0.12032881811989148}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:52,634] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 408, 'max_depth': 11, 'learning_rate': 0.07245435833399569}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:52,857] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 167, 'max_depth': 14, 'learning_rate': 0.2970128094953546}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:53,308] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 253, 'max_depth': 16, 'learning_rate': 0.05376601600771631}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:53,882] Trial 10 finished with value: 1.0 and parameters: {'n_estimators': 362, 'max_depth': 20, 'learning_rate': 0.02509169533670867}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:54,339] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 277, 'max_depth': 5, 'learning_rate': 0.011817044674691708}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:54,835] Trial 12 finished with value: 1.0 and parameters: {'n_estimators': 290, 'max_depth': 14, 'learning_rate': 0.018215320537839835}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:55,417] Trial 13 finished with value: 1.0 and parameters: {'n_estimators': 337, 'max_depth': 7, 'learning_rate': 0.03311502701776453}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:55,828] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 226, 'max_depth': 2, 'learning_rate': 0.019330748602241092}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:56,000] Trial 15 finished with value: 1.0 and parameters: {'n_estimators': 56, 'max_depth': 14, 'learning_rate': 0.010614002256419711}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:56,514] Trial 16 finished with value: 1.0 and parameters: {'n_estimators': 339, 'max_depth': 9, 'learning_rate': 0.0182621985315835}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:57,576] Trial 17 finished with value: 1.0 and parameters: {'n_estimators': 432, 'max_depth': 12, 'learning_rate': 0.045431849205732074}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:58,064] Trial 18 finished with value: 1.0 and parameters: {'n_estimators': 210, 'max_depth': 6, 'learning_rate': 0.02742519135595964}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:05:58,555] Trial 19 finished with value: 1.0 and parameters: {'n_estimators': 310, 'max_depth': 4, 'learning_rate': 0.015750049309962356}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:01,815] Trial 20 finished with value: 1.0 and parameters: {'n_estimators': 378, 'max_depth': 13, 'learning_rate': 0.024525460431800757}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:02,670] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 442, 'max_depth': 4, 'learning_rate': 0.04093775902587155}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:03,298] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 402, 'max_depth': 8, 'learning_rate': 0.030491793514227292}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:04,076] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 455, 'max_depth': 10, 'learning_rate': 0.03783788891323965}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:04,668] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 320, 'max_depth': 6, 'learning_rate': 0.02234217491007001}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:05,672] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 375, 'max_depth': 4, 'learning_rate': 0.06775644205039931}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:08,804] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 413, 'max_depth': 3, 'learning_rate': 0.013556669880633625}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:10,953] Trial 27 finished with value: 1.0 and parameters: {'n_estimators': 460, 'max_depth': 16, 'learning_rate': 0.01699689533920874}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:12,584] Trial 28 finished with value: 1.0 and parameters: {'n_estimators': 250, 'max_depth': 7, 'learning_rate': 0.010161585441730351}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:13,760] Trial 29 finished with value: 1.0 and parameters: {'n_estimators': 499, 'max_depth': 8, 'learning_rate': 0.06597630341345373}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:14,175] Trial 30 finished with value: 1.0 and parameters: {'n_estimators': 353, 'max_depth': 10, 'learning_rate': 0.12137787568799516}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:14,740] Trial 31 finished with value: 1.0 and parameters: {'n_estimators': 484, 'max_depth': 8, 'learning_rate': 0.11474728509016799}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:15,256] Trial 32 finished with value: 1.0 and parameters: {'n_estimators': 465, 'max_depth': 6, 'learning_rate': 0.14715733457909544}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:15,745] Trial 33 finished with value: 1.0 and parameters: {'n_estimators': 392, 'max_depth': 11, 'learning_rate': 0.08954217314892515}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:16,652] Trial 34 finished with value: 1.0 and parameters: {'n_estimators': 427, 'max_depth': 9, 'learning_rate': 0.049957628606216435}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:16,910] Trial 35 finished with value: 1.0 and parameters: {'n_estimators': 159, 'max_depth': 5, 'learning_rate': 0.2598387821599454}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:17,591] Trial 36 finished with value: 1.0 and parameters: {'n_estimators': 474, 'max_depth': 3, 'learning_rate': 0.013691905500272286}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:18,083] Trial 37 finished with value: 1.0 and parameters: {'n_estimators': 303, 'max_depth': 12, 'learning_rate': 0.08726474386155988}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:18,661] Trial 38 finished with value: 1.0 and parameters: {'n_estimators': 497, 'max_depth': 16, 'learning_rate': 0.18957933168449323}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:19,456] Trial 39 finished with value: 1.0 and parameters: {'n_estimators': 189, 'max_depth': 7, 'learning_rate': 0.03568178087060704}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:20,434] Trial 40 finished with value: 1.0 and parameters: {'n_estimators': 259, 'max_depth': 5, 'learning_rate': 0.023150028326487555}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:21,749] Trial 41 finished with value: 1.0 and parameters: {'n_estimators': 100, 'max_depth': 10, 'learning_rate': 0.013809569421527234}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:27,348] Trial 42 finished with value: 1.0 and parameters: {'n_estimators': 127, 'max_depth': 11, 'learning_rate': 0.020619253473250002}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:27,703] Trial 43 finished with value: 1.0 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.012739742837275242}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:28,121] Trial 44 finished with value: 1.0 and parameters: {'n_estimators': 138, 'max_depth': 12, 'learning_rate': 0.01623972166843263}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:28,381] Trial 45 finished with value: 1.0 and parameters: {'n_estimators': 80, 'max_depth': 20, 'learning_rate': 0.029509757356827565}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:29,788] Trial 46 finished with value: 1.0 and parameters: {'n_estimators': 423, 'max_depth': 2, 'learning_rate': 0.026531351835320082}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:31,926] Trial 47 finished with value: 1.0 and parameters: {'n_estimators': 202, 'max_depth': 15, 'learning_rate': 0.061376608136020534}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:33,654] Trial 48 finished with value: 1.0 and parameters: {'n_estimators': 444, 'max_depth': 13, 'learning_rate': 0.011188425016035236}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\1850268137.py:275: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-24 16:06:34,242] Trial 49 finished with value: 1.0 and parameters: {'n_estimators': 350, 'max_depth': 5, 'learning_rate': 0.020643213809337247}. Best is trial 0 with value: 1.0.
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 422, 'max_depth': 12, 'learning_rate': 0.02174508768250832}
#  Itérations en cours: 100%|██████████| 2/2 [01:09<00:00, 34.70s/it]
#   Comparaison des résultats avant optimisation pour 'XGBoost':
#    - Accuracy (Sans Sampling) : 1.0000
#    - Accuracy (Avec Sampling) : 1.0000
#    - F1-score (Sans Sampling) : 1.0000
#    - F1-score (Avec Sampling) : 1.0000
#    - Similarité des prédictions entre modèles : 100.00%
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy Train: 1.0000
#    - Accuracy Test: 1.0000
#    - F1-score Train: 1.0000
#    - F1-score Test: 1.0000
#  Bon équilibre entre biais et variance après optimisation.
# {
#     "Itération": 2,
#     "Dataset utilisé": "data/dataP/preprocessed_iris_dataset.csv",
#     "Colonne cible": "species",
#     "Échantillonnage": "Oui (DDBS - euclidean, geometric)",
#     "Tps Sampling": 0.01,
#     "Entrain %": 15.0,
#     "Nbre Entrain": 15,
#     "Test %": 20.0,
#     "Nbre Test": 20,
#     "Modèle": "XGBoost",
#     "Paramètres initiaux": {
#         "learning_rate": 0.1,
#         "max_depth": 6,
#         "n_estimators": 100
#     },
#     "Tps Entrain Avant": 0.07,
#     "Accuracy Avant": 1.0,
#     "F1-score Avant": 1.0,
#     "Tps Entrain Après": 0.16,
#     "Paramètres optimisés": {
#         "n_estimators": 422,
#         "max_depth": 12,
#         "learning_rate": 0.02174508768250832
#     },
#     "Accuracy Après": 1.0,
#     "F1-score Après": 1.0,
#     "Accuracy Train Avant": 1.0,
#     "F1-score Train Avant": 1.0,
#     "Accuracy Test (Sans Sampling)": 1.0,
#     "F1-score Test (Sans Sampling)": 1.0,
#     "Accuracy Test (Avec Sampling)": 1.0,
#     "F1-score Test (Avec Sampling)": 1.0,
#     "Similarité Prédictions (Avant Opti)": 100.0,
#     "Accuracy Test (Sans Sampling - Opti)": 1.0,
#     "F1-score Test (Sans Sampling - Opti)": 1.0,
#     "Accuracy Test (Avec Sampling - Opti)": 1.0,
#     "F1-score Test (Avec Sampling - Opti)": 1.0,
#     "Similarité Prédictions (Après Opti)": 100.0,
#     "Accuracy Train Après": 1.0,
#     "F1-score Train Après": 1.0,
#     "Sampling DDBS": {
#         "distance_metric": "euclidean",
#         "distribution_type": "geometric",
#         "percentage_per_class": 0.2,
#         "total_selected_samples": 15
#     }
# }
#  Résultats enregistrés dans 'resultat/log/resultats_XGBoost_Oui_DDBS__euclidean,_geometric_preprocessed_iris_dataset.txt'
#
#   Toutes les itérations sont terminées.

# %%
import numpy as np
import pandas as pd
import json
import optuna
import pickle
import os
import time
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier

# Import collection des resultat
from resultat.collect_results import collect_results

# Import sécurisé de gmm_sampling
try:
    from sampling.gmm_sampling import gmm_sampling
except ModuleNotFoundError:
    raise ImportError(" Impossible d'importer gmm_sampling. Vérifiez le chemin du fichier.")

# Import sécurisé de ddbs_sampling
try:
    from sampling.ddbs_sampling import diversified_distance_based_sampling
except ModuleNotFoundError:
    raise ImportError("Impossible d'importer ddbs_sampling. Vérifiez le chemin du fichier.")


# Charger la configuration depuis config.json
with open("config.json", "r") as config_file:
    config = json.load(config_file)

file_path = config["file_path"]
model_save_path = config["model_save_path"]
num_iterations = config.get("num_iterations", 2)  #  Nombre d'itérations

# Charger le dataset CSV avec gestion des erreurs
df = pd.read_csv(file_path)
print(" Données chargées avec succès.")

# Définition de la colonne cible
target_column = config["target_column"]
if target_column not in df.columns:
    raise ValueError(f" La colonne cible '{target_column}' est absente des données.")

print(f" Colonne cible définie : {target_column}")

# Initialisation du DataFrame pour stocker les résultats
columns = [
    "Itération", "Échantillonnage","Tps Sampling","Entrain %", "Nbre Entrain", "Test %", "Nbre Test", "Modèle", "Paramètres Initiaux",
    "Tps Entrain Avant", "Accuracy Avant","F1-score Avant", "Tps Entrain Après", "Paramètres Optimisés", "Accuracy Après", "F1-score Après"    
]
results_df = pd.DataFrame(columns=columns)


# Exécuter 30 itérations

for iteration in tqdm(range(1, num_iterations  + 1), desc=" Itérations en cours"):
    print(f"\n Exécution de l'itération {iteration}...\n")

     # Séparation des données en Train/Test avant sampling
    test_size = config["train_test_split"]["test_size"]
    X = df.drop(columns=[target_column])
    y = df[target_column]

    # Division des données
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    
    #  Appliquer le sampling UNIQUEMENT sur les données d'entraînement
    start_sampling_time = time.time()
    
    # Appliquer le sampling si activé
    if config["sampling"]["enabled"]:
        # Si le sampling type est GMM, appliquer le sampling GMM
        if config["sampling"]["gmm"]["enabled"]:
            df_train_sampled = gmm_sampling(pd.concat([X_train, y_train], axis=1), target_column, config)
            X_train_sampled = df_train_sampled.drop(columns=[target_column])
            y_train_sampled = df_train_sampled[target_column]
            sampling_status = "Oui (GMM)"
            print("Échantillonnage GMM appliqué")
        
        # Si le sampling type est Random, utiliser Pandas sample()
        elif config["sampling"]["random"]["enabled"]:
            fraction = config["sampling"]["fraction"]
            sampled_indices = X_train.sample(frac=fraction).index
            X_train_sampled, y_train_sampled = X_train.loc[sampled_indices], y_train.loc[sampled_indices]
            sampling_status = "Oui (Random)"
            print(f" Échantillonnage aléatoire activé : {fraction*100:.1f}% des données utilisées.")
        
        # Si le sampling type est ddbs, utiliser Pandas sample()    
        elif config["sampling"]["ddbs"]["enabled"]:
            df_train_sampled = diversified_distance_based_sampling(pd.concat([X_train, y_train], axis=1), target_column, config)
            X_train_sampled = df_train_sampled.drop(columns=[target_column])
            y_train_sampled = df_train_sampled[target_column]
            sampling_status = f"Oui (DDBS - {config['sampling']['ddbs']['distance_metric']}, {config['sampling']['ddbs']['distribution_type']})"
            print("Échantillonnage DDBS appliqué.")
        
        # Si le type est inconnu, lever une erreur
        else:
            raise ValueError(f" Type d'échantillonnage inconnu : '{sampling_type}'")

    else:
        # Si le sampling est désactivé, utiliser le dataset original
        X_train_sampled, y_train_sampled = X_train, y_train
        sampling_status = "Non"
        print(" Aucun échantillonnage appliqué, utilisation des données complètes.")

    # Sélectionner les bonnes données d'entraînement (avec ou sans échantillonnage)
    X_train_used, y_train_used = (X_train_sampled, y_train_sampled) if config["sampling"]["enabled"] else (X_train, y_train)

    # Calcul du temps pris pour le sampling
    sampling_time = round(time.time() - start_sampling_time , 2) # Calcul du temps pris par le sampling
    print(f"\n Temps samping  : {sampling_time}.")
    
    #  Mise à jour du nombre d'échantillons après sampling
    num_train_used  = len(X_train_used)
    num_test_used  = len(X_test) # Le test set reste inchangé

    print(f"\nDonnées après échantillonnage (Train) : {num_train_used } échantillons.")
    print(f"Données de test non modifiées : {num_test_used } échantillons.")
    
    # Calcul du pourcentage des données après échantillonnage
    train_percent = (num_train_used / len(df)) * 100
    test_percent = (num_test_used / len(df)) * 100
    
    print(f"\n Pourcentage Entraînement : {train_percent:.2f}%")
    print(f" Pourcentage Test : {test_percent:.2f}%")


    # Initialiser les modèles
    models = {}
    for model_name, model_params in config["models"].items():
        if model_params["enabled"]:
            if model_name == "Decision Tree":
                models[model_name] = DecisionTreeClassifier(max_depth=model_params["max_depth"])
            elif model_name == "Random Forest":
                models[model_name] = RandomForestClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"]
                )
            elif model_name == "SVM":
                models[model_name] = SVC(C=model_params["C"], kernel=model_params["kernel"])
            elif model_name == "Neural Network":
                models[model_name] = MLPClassifier(
                    hidden_layer_sizes=tuple(model_params["hidden_layer_sizes"]),
                    learning_rate_init=model_params["learning_rate_init"],
                    max_iter=500
                )
            elif model_name == "XGBoost":
                models[model_name] = XGBClassifier(
                    n_estimators=model_params["n_estimators"],
                    max_depth=model_params["max_depth"],
                    learning_rate=model_params["learning_rate"]    
                )

    # Entraînement et évaluation des modèles
    for model_name, model in models.items():

        # Entraînement du modèle avec les bonnes données
        start_train_time = time.time()  # Début du chronométrage de l'entraînement avant optimisation
        model.fit(X_train_used, y_train_used)
        train_time_before = round(time.time() - start_train_time , 2)  # Temps pris pour l'entraînement avant optimisation
        y_pred = model.predict(X_test)
        accuracy_before = accuracy_score(y_test, y_pred)
        f1_before = f1_score(y_test, y_pred, average="weighted")
        
        print(f"\n Résultats du modèle '{model_name}' avant optimisation :")
        print(f"   - Accuracy Test: {accuracy_before:.4f}")
        print(f"   - F1-score Test: {f1_before:.4f}")


        best_params = {}
        best_model = model
        accuracy_after, f1_after = "Non optimisé", "Non optimisé"

        # Optimisation avec Optuna
        if config["use_optuna"]:
            def objective(trial):
                if model_name == "Decision Tree":
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = DecisionTreeClassifier(max_depth=max_depth)
                elif model_name == "Random Forest":
                    n_estimators = trial.suggest_int("n_estimators", 10, 200)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    model_opt = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)
                elif model_name == "SVM":
                    C = trial.suggest_loguniform("C", 0.1, 10)
                    kernel = trial.suggest_categorical("kernel", ["linear", "rbf", "poly"])
                    model_opt = SVC(C=C, kernel=kernel)
                elif model_name == "Neural Network":
                    hidden_layer_sizes = trial.suggest_categorical("hidden_layer_sizes", [(50,), (100,), (50, 50)])
                    learning_rate_init = trial.suggest_loguniform("learning_rate_init", 0.0001, 0.1)
                    model_opt = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, learning_rate_init=learning_rate_init, max_iter=500)
                elif model_name == "XGBoost":
                    n_estimators = trial.suggest_int("n_estimators", 50, 500)
                    max_depth = trial.suggest_int("max_depth", 2, 20)
                    learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
                    model_opt = XGBClassifier(n_estimators=n_estimators, max_depth=max_depth, learning_rate=learning_rate)

                
                model_opt.fit(X_train_used, y_train_used)
                y_pred_opt = model_opt.predict(X_test)
                return accuracy_score(y_test, y_pred_opt)

            study = optuna.create_study(direction="maximize")
            study.optimize(objective, n_trials=config["n_trials"])

            best_params = study.best_trial.params
            print(f"\n Meilleurs paramètres trouvés pour '{model_name}' : {best_params}")

            # Réentraînement avec les meilleurs paramètres
            if config["retrain_with_best_params"]:
                start_train_time_after = time.time()  # Début du chronométrage de l'entraînement après optimisation
                best_model = model.__class__(**best_params)
                best_model.fit(X_train_used, y_train_used)
                train_time_after = round(time.time() - start_train_time_after, 2) # Temps pris pour l'entraînement après optimisation
                y_pred_opt = best_model.predict(X_test)
                
                accuracy_after = accuracy_score(y_test, y_pred_opt)
                f1_after = f1_score(y_test, y_pred_opt, average="weighted")

            print(f"\n Modèle après optimisation ({model_name}):")
            print(f"   - Accuracy Test: {accuracy_after:.4f}")
            print(f"   - F1-score Test: {f1_after:.4f}")  
    

            # Sauvegarde du meilleur modèle
            if config["save_best_model"]:
                model_filename = f"best_model_{model_name}.pkl"
                with open(model_filename, "wb") as f:
                    pickle.dump(best_model, f)
                print(f" Modèle '{model_name}' sauvegardé sous '{model_filename}'.")

        # Stockage des résultats
        results_df = pd.concat([results_df, pd.DataFrame([{
            "Itération": iteration,
            "Échantillonnage": sampling_status,
            "Tps Sampling": sampling_time,
            "Entrain %": train_percent,
            "Nbre Entrain": num_train_used,
            "Test %": test_percent,
            "Nbre Test": num_test_used,
            "Modèle": model_name,
            "Paramètres Initiaux": {param: value for param, value in model.get_params().items() if param in model_params},
            "Tps Entrain Avant": train_time_before,
            "Accuracy Avant": accuracy_before,
            "F1-score Avant": f1_before,
            "Tps Entrain Après": train_time_after,
            "Paramètres Optimisés": best_params,
            "Accuracy Après": accuracy_after,
            "F1-score Après": f1_after
        }])], ignore_index=True)
        
# Sauvegarde des résultats
# Définition du chemin du fichier Excel
excel_path = f"resultat/excel/resultats_{model_name}_{os.path.basename(file_path).split('.')[0]}.xlsx"

# Vérifier si le fichier existe
if os.path.exists(excel_path):
    # Ajouter les nouveaux résultats sans charger les anciens
    with pd.ExcelWriter(excel_path, mode='a', if_sheet_exists='overlay') as writer:
        results_df.to_excel(writer, index=False, header=False, startrow=writer.sheets['Sheet1'].max_row)
else:
    # Si le fichier n'existe pas, on crée un nouveau fichier avec les nouveaux résultats
    results_df.to_excel(excel_path, index=False)

print("\n Les nouveaux résultats sont disponible")

# Réinitialisation du DataFrame après la sauvegarde (conserve les colonnes, supprime les lignes)
results_df.drop(results_df.index, inplace=True)
# Out:
#  Données chargées avec succès.
#  Colonne cible définie : species
#  Itérations en cours:   0%|          | 0/15 [00:00<?, ?it/s]
#  Exécution de l'itération 1...
#
#  Aucun échantillonnage appliqué, utilisation des données complètes.
#
#  Temps samping  : 0.0.
#
# Données après échantillonnage (Train) : 80 échantillons.
# Données de test non modifiées : 20 échantillons.
#
#  Pourcentage Entraînement : 80.00%
#  Pourcentage Test : 20.00%
#
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy Test: 1.0000
#    - F1-score Test: 1.0000
# [I 2025-03-25 09:25:18,563] A new study created in memory with name: no-name-60d6483d-f212-41cb-8499-5f55d46ea822
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:18,626] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 63, 'max_depth': 11, 'learning_rate': 0.039012056558080266}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:18,722] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 234, 'max_depth': 19, 'learning_rate': 0.05074799091651506}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:18,844] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 330, 'max_depth': 18, 'learning_rate': 0.13320180932662604}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:19,028] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 494, 'max_depth': 4, 'learning_rate': 0.012844764527644763}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:19,082] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 129, 'max_depth': 11, 'learning_rate': 0.19057265555343186}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:19,164] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 227, 'max_depth': 15, 'learning_rate': 0.0584536579668587}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:19,234] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 179, 'max_depth': 5, 'learning_rate': 0.20750129367310557}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:19,434] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 446, 'max_depth': 7, 'learning_rate': 0.01656218252689054}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:19,535] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 194, 'max_depth': 14, 'learning_rate': 0.06440206210018151}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:19,724] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 482, 'max_depth': 4, 'learning_rate': 0.03806844704848177}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:19,868] Trial 10 finished with value: 1.0 and parameters: {'n_estimators': 62, 'max_depth': 9, 'learning_rate': 0.02732366723149593}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:20,108] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 328, 'max_depth': 20, 'learning_rate': 0.08254994537859961}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:20,204] Trial 12 finished with value: 1.0 and parameters: {'n_estimators': 53, 'max_depth': 14, 'learning_rate': 0.030674736847950905}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:20,464] Trial 13 finished with value: 1.0 and parameters: {'n_estimators': 300, 'max_depth': 11, 'learning_rate': 0.11066591810691201}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:20,728] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 125, 'max_depth': 15, 'learning_rate': 0.021476967652635195}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:21,057] Trial 15 finished with value: 1.0 and parameters: {'n_estimators': 385, 'max_depth': 8, 'learning_rate': 0.04067716133906712}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:21,291] Trial 16 finished with value: 1.0 and parameters: {'n_estimators': 256, 'max_depth': 18, 'learning_rate': 0.047201261933228315}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:21,466] Trial 17 finished with value: 1.0 and parameters: {'n_estimators': 156, 'max_depth': 12, 'learning_rate': 0.07886646696179178}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:21,585] Trial 18 finished with value: 1.0 and parameters: {'n_estimators': 110, 'max_depth': 2, 'learning_rate': 0.2888664598181653}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:21,848] Trial 19 finished with value: 1.0 and parameters: {'n_estimators': 389, 'max_depth': 20, 'learning_rate': 0.021112601949799845}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:22,049] Trial 20 finished with value: 1.0 and parameters: {'n_estimators': 221, 'max_depth': 9, 'learning_rate': 0.010269734294801306}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:22,251] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 334, 'max_depth': 16, 'learning_rate': 0.11736172734009809}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:22,461] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 381, 'max_depth': 18, 'learning_rate': 0.12640254793518887}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:22,952] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 280, 'max_depth': 18, 'learning_rate': 0.08615959667011173}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:23,108] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 341, 'max_depth': 17, 'learning_rate': 0.05145681621131844}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:23,301] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 422, 'max_depth': 13, 'learning_rate': 0.16111572109059458}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:23,452] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 242, 'max_depth': 20, 'learning_rate': 0.03807064970913865}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:23,615] Trial 27 finished with value: 1.0 and parameters: {'n_estimators': 302, 'max_depth': 10, 'learning_rate': 0.06474558743879529}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:23,740] Trial 28 finished with value: 1.0 and parameters: {'n_estimators': 87, 'max_depth': 17, 'learning_rate': 0.02707755453006499}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:23,862] Trial 29 finished with value: 1.0 and parameters: {'n_estimators': 191, 'max_depth': 19, 'learning_rate': 0.10353729645487227}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:24,060] Trial 30 finished with value: 1.0 and parameters: {'n_estimators': 364, 'max_depth': 13, 'learning_rate': 0.29655591461125125}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:24,292] Trial 31 finished with value: 1.0 and parameters: {'n_estimators': 486, 'max_depth': 2, 'learning_rate': 0.012667349140229222}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:24,546] Trial 32 finished with value: 1.0 and parameters: {'n_estimators': 449, 'max_depth': 5, 'learning_rate': 0.16605378204504678}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:24,684] Trial 33 finished with value: 1.0 and parameters: {'n_estimators': 147, 'max_depth': 6, 'learning_rate': 0.016984055599285154}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:24,818] Trial 34 finished with value: 1.0 and parameters: {'n_estimators': 210, 'max_depth': 16, 'learning_rate': 0.2259332099854429}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:25,070] Trial 35 finished with value: 1.0 and parameters: {'n_estimators': 418, 'max_depth': 3, 'learning_rate': 0.014187077976181543}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:25,231] Trial 36 finished with value: 1.0 and parameters: {'n_estimators': 168, 'max_depth': 6, 'learning_rate': 0.06072201796834872}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:25,514] Trial 37 finished with value: 1.0 and parameters: {'n_estimators': 500, 'max_depth': 10, 'learning_rate': 0.02148345714787462}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:25,784] Trial 38 finished with value: 1.0 and parameters: {'n_estimators': 457, 'max_depth': 7, 'learning_rate': 0.030699622423183578}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:25,968] Trial 39 finished with value: 1.0 and parameters: {'n_estimators': 262, 'max_depth': 15, 'learning_rate': 0.07369917122732479}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:26,093] Trial 40 finished with value: 1.0 and parameters: {'n_estimators': 86, 'max_depth': 19, 'learning_rate': 0.049117156084840255}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:26,222] Trial 41 finished with value: 1.0 and parameters: {'n_estimators': 128, 'max_depth': 11, 'learning_rate': 0.15918075403966142}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:26,339] Trial 42 finished with value: 1.0 and parameters: {'n_estimators': 74, 'max_depth': 12, 'learning_rate': 0.0967005062922737}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:26,436] Trial 43 finished with value: 1.0 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.19216733530737376}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:26,561] Trial 44 finished with value: 1.0 and parameters: {'n_estimators': 110, 'max_depth': 14, 'learning_rate': 0.21854379245768038}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:26,757] Trial 45 finished with value: 1.0 and parameters: {'n_estimators': 295, 'max_depth': 4, 'learning_rate': 0.1267339769238698}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:26,891] Trial 46 finished with value: 1.0 and parameters: {'n_estimators': 132, 'max_depth': 8, 'learning_rate': 0.03305351368871843}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:27,045] Trial 47 finished with value: 1.0 and parameters: {'n_estimators': 180, 'max_depth': 13, 'learning_rate': 0.04004077861773873}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:27,165] Trial 48 finished with value: 1.0 and parameters: {'n_estimators': 102, 'max_depth': 12, 'learning_rate': 0.24197868317475474}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:27,418] Trial 49 finished with value: 1.0 and parameters: {'n_estimators': 236, 'max_depth': 11, 'learning_rate': 0.13634946495055641}. Best is trial 0 with value: 1.0.
#  Itérations en cours:   7%|▋         | 1/15 [00:09<02:08,  9.17s/it]
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 63, 'max_depth': 11, 'learning_rate': 0.039012056558080266}
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy Test: 1.0000
#    - F1-score Test: 1.0000
#
#  Exécution de l'itération 2...
#
#  Aucun échantillonnage appliqué, utilisation des données complètes.
#
#  Temps samping  : 0.0.
#
# Données après échantillonnage (Train) : 80 échantillons.
# Données de test non modifiées : 20 échantillons.
#
#  Pourcentage Entraînement : 80.00%
#  Pourcentage Test : 20.00%
# [I 2025-03-25 09:25:27,668] A new study created in memory with name: no-name-e8b3f892-4c36-49e0-9c36-241c6764ce8b
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:27,779] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 191, 'max_depth': 2, 'learning_rate': 0.11131765858451852}. Best is trial 0 with value: 1.0.
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy Test: 1.0000
#    - F1-score Test: 1.0000
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:27,963] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 371, 'max_depth': 6, 'learning_rate': 0.0281539705895921}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:28,192] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 442, 'max_depth': 19, 'learning_rate': 0.16301730797491318}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:28,440] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 341, 'max_depth': 20, 'learning_rate': 0.08067329224375966}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:28,647] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 385, 'max_depth': 17, 'learning_rate': 0.041687802733924535}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:28,699] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 63, 'max_depth': 3, 'learning_rate': 0.01082581923051958}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:28,854] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 425, 'max_depth': 5, 'learning_rate': 0.16060797490764087}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:28,945] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 130, 'max_depth': 8, 'learning_rate': 0.2644052054334567}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:29,057] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 112, 'max_depth': 14, 'learning_rate': 0.027002797853838488}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:29,180] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 118, 'max_depth': 10, 'learning_rate': 0.011416685810815222}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:29,345] Trial 10 finished with value: 1.0 and parameters: {'n_estimators': 223, 'max_depth': 2, 'learning_rate': 0.08206964881420836}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:29,621] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 258, 'max_depth': 6, 'learning_rate': 0.024472140923748855}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:29,789] Trial 12 finished with value: 1.0 and parameters: {'n_estimators': 325, 'max_depth': 6, 'learning_rate': 0.05396453325377421}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:29,968] Trial 13 finished with value: 1.0 and parameters: {'n_estimators': 213, 'max_depth': 2, 'learning_rate': 0.02285238765781657}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:30,135] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 308, 'max_depth': 11, 'learning_rate': 0.10126237431064279}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:30,531] Trial 15 finished with value: 1.0 and parameters: {'n_estimators': 183, 'max_depth': 8, 'learning_rate': 0.0449326115810341}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:30,777] Trial 16 finished with value: 1.0 and parameters: {'n_estimators': 495, 'max_depth': 5, 'learning_rate': 0.018157459332578497}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:30,925] Trial 17 finished with value: 1.0 and parameters: {'n_estimators': 276, 'max_depth': 13, 'learning_rate': 0.12688785755509246}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:31,114] Trial 18 finished with value: 1.0 and parameters: {'n_estimators': 383, 'max_depth': 4, 'learning_rate': 0.034588535865950606}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:31,229] Trial 19 finished with value: 1.0 and parameters: {'n_estimators': 179, 'max_depth': 8, 'learning_rate': 0.2684765660521353}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:31,368] Trial 20 finished with value: 1.0 and parameters: {'n_estimators': 259, 'max_depth': 10, 'learning_rate': 0.06363677503982726}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:31,548] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 478, 'max_depth': 19, 'learning_rate': 0.1732701532212352}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:31,717] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 427, 'max_depth': 16, 'learning_rate': 0.17603988843856136}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:31,915] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 451, 'max_depth': 13, 'learning_rate': 0.12644311493344362}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:32,084] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 374, 'max_depth': 4, 'learning_rate': 0.07071710726149083}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:32,284] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 428, 'max_depth': 16, 'learning_rate': 0.11105191371418989}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:32,512] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 344, 'max_depth': 7, 'learning_rate': 0.23057124013776634}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:32,734] Trial 27 finished with value: 1.0 and parameters: {'n_estimators': 299, 'max_depth': 2, 'learning_rate': 0.015936421925439783}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:32,969] Trial 28 finished with value: 1.0 and parameters: {'n_estimators': 464, 'max_depth': 18, 'learning_rate': 0.20146087974340235}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:33,176] Trial 29 finished with value: 1.0 and parameters: {'n_estimators': 405, 'max_depth': 4, 'learning_rate': 0.09308934638753674}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:33,371] Trial 30 finished with value: 1.0 and parameters: {'n_estimators': 331, 'max_depth': 20, 'learning_rate': 0.03303345382700185}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:33,574] Trial 31 finished with value: 1.0 and parameters: {'n_estimators': 375, 'max_depth': 18, 'learning_rate': 0.1439166208016589}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:33,800] Trial 32 finished with value: 1.0 and parameters: {'n_estimators': 361, 'max_depth': 20, 'learning_rate': 0.05126838594020383}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:34,066] Trial 33 finished with value: 1.0 and parameters: {'n_estimators': 413, 'max_depth': 16, 'learning_rate': 0.07676087310577631}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:34,193] Trial 34 finished with value: 1.0 and parameters: {'n_estimators': 78, 'max_depth': 18, 'learning_rate': 0.06090286743640976}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:34,415] Trial 35 finished with value: 1.0 and parameters: {'n_estimators': 352, 'max_depth': 14, 'learning_rate': 0.09073457173648569}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:25:34,640] Trial 36 finished with value: 1.0 and parameters: {'n_estimators': 397, 'max_depth': 20, 'learning_rate': 0.03853974936051716}. Best is trial 0 with value: 1.0.
# ...
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:04,353] Trial 49 finished with value: 1.0 and parameters: {'n_estimators': 500, 'max_depth': 13, 'learning_rate': 0.04407201233292063}. Best is trial 0 with value: 1.0.
#  Itérations en cours:  33%|███▎      | 5/15 [00:46<01:33,  9.40s/it]
#  Meilleurs paramètres trouvés pour 'XGBoost' : {'n_estimators': 408, 'max_depth': 11, 'learning_rate': 0.06338272829415083}
#
#  Modèle après optimisation (XGBoost):
#    - Accuracy Test: 1.0000
#    - F1-score Test: 1.0000
# [I 2025-03-25 09:26:04,609] A new study created in memory with name: no-name-e670460a-f334-4d79-bca9-6a4581f3995e
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
#  Exécution de l'itération 6...
#
#  Aucun échantillonnage appliqué, utilisation des données complètes.
#
#  Temps samping  : 0.0.
#
# Données après échantillonnage (Train) : 80 échantillons.
# Données de test non modifiées : 20 échantillons.
#
#  Pourcentage Entraînement : 80.00%
#  Pourcentage Test : 20.00%
#
#  Résultats du modèle 'XGBoost' avant optimisation :
#    - Accuracy Test: 1.0000
#    - F1-score Test: 1.0000
# [I 2025-03-25 09:26:04,760] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 239, 'max_depth': 5, 'learning_rate': 0.014427687576865637}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:04,812] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 72, 'max_depth': 17, 'learning_rate': 0.20340619267632745}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:04,971] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 421, 'max_depth': 5, 'learning_rate': 0.0655253609530777}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:05,128] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 315, 'max_depth': 7, 'learning_rate': 0.01879269955043446}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:05,247] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 273, 'max_depth': 3, 'learning_rate': 0.1359853140563596}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:05,354] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 225, 'max_depth': 4, 'learning_rate': 0.15508081458610848}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:05,442] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 129, 'max_depth': 14, 'learning_rate': 0.01506272690965455}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:05,680] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 486, 'max_depth': 5, 'learning_rate': 0.014263968390293568}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:05,776] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 262, 'max_depth': 19, 'learning_rate': 0.08646642221952545}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:05,827] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 57, 'max_depth': 5, 'learning_rate': 0.028683606045919793}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:05,946] Trial 10 finished with value: 1.0 and parameters: {'n_estimators': 179, 'max_depth': 11, 'learning_rate': 0.034996373873605366}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:06,020] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 53, 'max_depth': 20, 'learning_rate': 0.26470343523145334}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:06,178] Trial 12 finished with value: 1.0 and parameters: {'n_estimators': 360, 'max_depth': 16, 'learning_rate': 0.03540813756541317}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:06,296] Trial 13 finished with value: 1.0 and parameters: {'n_estimators': 142, 'max_depth': 9, 'learning_rate': 0.26802717575881935}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:06,444] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 183, 'max_depth': 14, 'learning_rate': 0.010379203785176252}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:06,541] Trial 15 finished with value: 1.0 and parameters: {'n_estimators': 99, 'max_depth': 9, 'learning_rate': 0.1128696205486749}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:06,724] Trial 16 finished with value: 1.0 and parameters: {'n_estimators': 333, 'max_depth': 16, 'learning_rate': 0.048090454923408646}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:06,903] Trial 17 finished with value: 1.0 and parameters: {'n_estimators': 216, 'max_depth': 12, 'learning_rate': 0.02399427007310747}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:07,088] Trial 18 finished with value: 1.0 and parameters: {'n_estimators': 385, 'max_depth': 2, 'learning_rate': 0.18816354742784488}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:07,189] Trial 19 finished with value: 1.0 and parameters: {'n_estimators': 107, 'max_depth': 18, 'learning_rate': 0.05774397476356394}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:07,415] Trial 20 finished with value: 1.0 and parameters: {'n_estimators': 493, 'max_depth': 8, 'learning_rate': 0.08408234325696048}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:07,678] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 428, 'max_depth': 6, 'learning_rate': 0.052353681155363485}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:07,964] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 438, 'max_depth': 2, 'learning_rate': 0.07747848101122647}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:08,205] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 310, 'max_depth': 11, 'learning_rate': 0.20363755667271455}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:08,454] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 409, 'max_depth': 6, 'learning_rate': 0.10644685874254753}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:08,621] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 250, 'max_depth': 9, 'learning_rate': 0.06318767236146652}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# [I 2025-03-25 09:26:08,768] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 186, 'max_depth': 17, 'learning_rate': 0.03971619075256148}. Best is trial 0 with value: 1.0.
# C:\Users\yando\AppData\Local\Temp\ipykernel_6284\4098249849.py:201: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
